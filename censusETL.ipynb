# %%
import requests
import json
import pandas as pd
import time

# %%
root_url = 'http://www.nomisweb.co.uk'

# api_url = '/api/v01/dataset/NM_1_1/geography.def.sdmx.json' # list all possible geography sets
api_url = '/api/v01/dataset/NM_1_1/geography/2092957697.def.sdmx.json' # list of all geography sets in UK
# api_url = '/api/v01/dataset/NM_1_1/geography/2092957697TYPE441.def.sdmx.json' # major towns and cities within United Kingdom

url = root_url + api_url

response = requests.get(url)
json.loads(response.text)
# Out:
# {'structure': {'codelists': {'codelist': [{'agencyid': 'NOMIS',
#      'id': 'CL_1_1_GEOGRAPHY',
#      'code': [{'annotations': {'annotation': [{'annotationtext': 'countries',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 499, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'K02000001', 'annotationtitle': 'GeogCode'}]},
#        'description': {'value': 'United Kingdom', 'lang': 'en'},
#        'value': 2092957697},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 1, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '1991 frozen wards',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 11330, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '1991 frozen wards within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE1'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 8, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'parliamentary constituencies 1983 revision',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 2498, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'parliamentary constituencies 1983 revision within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE8'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 18, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'tecs / lecs as of 1989',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 394, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'tecs / lecs as of 1989 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE18'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 27, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'english learning partnerships',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 101, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'english learning partnerships within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE27'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 33, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '1981 frozen wards',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 11083, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '1981 frozen wards within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE33'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 45, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'parliamentary constituencies 1983 revision',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 651, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'parliamentary constituencies 1983 revision within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE45'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 61, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'postcode towns', 'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 466, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'postcode towns within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE61'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 62, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'postcode districts',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 11451, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'postcode districts within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE62'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 63, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'postcode sectors', 'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 47389, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'postcode sectors within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE63'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 65, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'jobcentre plus offices',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 3795, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'jobcentre plus offices within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE65'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 66, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'jobcentre plus districts prior to April 2011',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 192, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'jobcentre plus districts prior to April 2011 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE66'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 83, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'jobcentre plus group as of April 2019',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 44, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'jobcentre plus group as of April 2019 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE83'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 84, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'jobcentre plus district as of April 2019',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 144, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'jobcentre plus district as of April 2019 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE84'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 86, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'live jobcentre plus offices',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 2708, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'live jobcentre plus offices within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE86'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 236, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2011 census frozen wards',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 9481, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2011 census frozen wards within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE236'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 241, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'scottish parliamentary regions',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 16, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'scottish parliamentary regions within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE241'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 267, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'built-up areas including subdivisions',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 6622, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'built-up areas including subdivisions within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE267'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 269, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'built-up areas', 'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 5493, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'built-up areas within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE269'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 297, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2011 super output areas - middle layer',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 7201, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2011 super output areas - middle layer within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE297'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 304, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2001 super output areas - lower layer',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 34378, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2001 super output areas - lower layer within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE304'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 305, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2001 super output areas - middle layer',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 7194, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2001 super output areas - middle layer within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE305'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 307, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2001 scottish data zones',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 6505, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2001 scottish data zones within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE307'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 308, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2001 northern ireland - super output areas',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 890, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2001 northern ireland - super output areas within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE308'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 312, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2003 CAS wards', 'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 10654, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2003 CAS wards within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE312'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 317, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2001 scottish intermediate zones',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 1235, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2001 scottish intermediate zones within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE317'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 324, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2005 statistical wards',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 35412, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2005 statistical wards within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE324'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 331, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'travel to work areas 2001-based',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 243, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'travel to work areas 2001-based within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE331'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 337, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2009 statistical wards',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 8483, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2009 statistical wards within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE337'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 338, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'output area classification group',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 63, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'output area classification group within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE338'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 339, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'output area classification sub group',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 156, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'output area classification sub group within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE339'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 340, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'output area classification super group',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 21, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'output area classification super group within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE340'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 347, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'scottish index of multiple deprivation 2009 - deciles',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 30, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'scottish index of multiple deprivation 2009 - deciles within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE347'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 349, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'welsh index of multiple deprivation 2008 - deciles',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 40, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'welsh index of multiple deprivation 2008 - deciles within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE349'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 351, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'northern ireland index of multiple deprivation 2010 - deciles',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 10, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'northern ireland index of multiple deprivation 2010 - deciles within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE351'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 355, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'welsh index of multiple deprivation 2011 - deciles',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 40, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'welsh index of multiple deprivation 2011 - deciles within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE355'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 362, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'scottish index of multiple deprivation 2012 - deciles',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 30, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'scottish index of multiple deprivation 2012 - deciles within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE362'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 395, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2019 electoral ward',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 8407, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2019 electoral ward within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE395'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 396, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2018 electoral ward',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 8634, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2018 electoral ward within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE396'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 397, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2017 electoral ward',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 8651, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2017 electoral ward within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE397'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 399, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2015 electoral ward',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 9298, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2015 electoral ward within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE399'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 400, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2014 electoral ward',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 9438, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2014 electoral ward within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE400'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 431, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'local authorities: county / unitary (as of April 2021)',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 217, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'local authorities: county / unitary (as of April 2021) within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE431'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 432, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'local authorities: district / unitary (as of April 2021)',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 374, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'local authorities: district / unitary (as of April 2021) within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE432'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 433, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'local authorities: county / unitary (as of April 2019)',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 216, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'local authorities: county / unitary (as of April 2019) within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE433'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 434, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'local authorities: district / unitary (as of April 2019)',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 382, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'local authorities: district / unitary (as of April 2019) within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE434'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 437, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'nuts 2016 level 3',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 179, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'nuts 2016 level 3 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE437'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 438, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'nuts 2016 level 2',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 41, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'nuts 2016 level 2 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE438'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 439, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'nuts 2016 level 1',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 12, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'nuts 2016 level 1 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE439'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 440, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'local administrative units 2016 level 1',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 400, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'local administrative units 2016 level 1 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE440'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 112, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'major towns and cities within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE441'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 442, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'combined authorities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 10, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'combined authorities within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE442'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 444, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'travel to work areas 2001-based',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 243, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'travel to work areas 2001-based within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE444'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 446, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'local authorities: county / unitary (as of April 2015)',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 217, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'local authorities: county / unitary (as of April 2015) within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE446'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 447, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'travel to work areas 2011-based',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 228, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'travel to work areas 2011-based within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE447'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 448, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'local authorities: district / unitary (as of April 2015)',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 391, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'local authorities: district / unitary (as of April 2015) within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE448'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 449, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'nuts 2013 level 3',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 173, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'nuts 2013 level 3 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE449'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 450, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'nuts 2013 level 2',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 40, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'nuts 2013 level 2 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE450'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 451, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'nuts 2013 level 1',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 12, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'nuts 2013 level 1 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE451'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 452, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'Northern Ireland local government districts (as of 2014)',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 11, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'Northern Ireland local government districts (as of 2014) within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE452'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 454, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'nuts 2010 level 1',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 12, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'nuts 2010 level 1 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE454'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 455, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'nuts 2010 level 2',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 37, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'nuts 2010 level 2 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE455'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 456, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'nuts 2010 level 3',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 139, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'nuts 2010 level 3 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE456'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 458, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'scottish parliamentary constituencies 2011 revision',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 73, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'scottish parliamentary constituencies 2011 revision within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE458'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 459, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'local enterprise partnerships (as of April 2021)',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 38, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'local enterprise partnerships (as of April 2021) within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE459'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 460, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'parliamentary constituencies 2010',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 650, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'parliamentary constituencies 2010 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE460'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 462, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'former metropolitan counties',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 8, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'former metropolitan counties within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE462'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 463, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'local authorities: county / unitary (prior to April 2015)',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 232, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'local authorities: county / unitary (prior to April 2015) within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE463'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 464, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'local authorities: district / unitary (prior to April 2015)',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 406, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'local authorities: district / unitary (prior to April 2015) within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE464'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 466, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'national assembly for wales constituencies',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 40, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'national assembly for wales constituencies within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE466'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 467, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'scottish local enterprise companies',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 21, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'scottish local enterprise companies within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE467'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 468, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'parliamentary constituencies 2005 revision',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 646, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'parliamentary constituencies 2005 revision within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE468'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 469, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'english counties', 'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 42, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'english counties within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE469'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 473, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'ELWAs', 'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 4, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'ELWAs within United Kingdom', 'lang': 'en'},
#        'value': '2092957697TYPE473'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 474, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'scottish local enterprise companies',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 22, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'scottish local enterprise companies within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE474'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 476, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'english local learning and skills councils',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 47, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'english local learning and skills councils within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE476'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 477, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'nuts 2003 level 1',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 12, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'nuts 2003 level 1 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE477'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 478, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'nuts 2003 level 2',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 37, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'nuts 2003 level 2 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE478'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 479, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'nuts 2003 level 3',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 133, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'nuts 2003 level 3 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE479'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 480, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'regions', 'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 12, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'regions within United Kingdom', 'lang': 'en'},
#        'value': '2092957697TYPE480'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 481, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'travel to work areas 1984 revision',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 334, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'travel to work areas 1984 revision within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE481'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 482, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'pre-2009 local authorities: county / unitary',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 229, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'pre-2009 local authorities: county / unitary within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE482'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 483, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'new deal units of delivery',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 144, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'new deal units of delivery within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE483'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 484, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'parliamentary constituencies 1995 revision',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 659, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'parliamentary constituencies 1995 revision within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE484'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 486, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'pre-2009 local authorities: district / unitary',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 434, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'pre-2009 local authorities: district / unitary within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE486'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 487, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'unitary authority areas',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 167, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'unitary authority areas within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE487'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 488, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'travel to work areas 1998 revision',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 308, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'travel to work areas 1998 revision within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE488'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 489, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'tecs / lecs', 'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 98, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'tecs / lecs within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE489'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 490, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'government office regions tec / lec based',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 13, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'government office regions tec / lec based within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE490'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 491, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'government office regions (former inc. Merseyside)',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 13, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'government office regions (former inc. Merseyside) within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE491'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 492, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'standard statistical regions',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 12, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'standard statistical regions within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE492'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 496, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'pre-1996 local authority districts',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 485, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'pre-1996 local authority districts within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE496'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 498, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'pre-1996 counties / scottish regions',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 66, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'pre-1996 counties / scottish regions within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE498'}],
#      'name': {'value': 'geography', 'lang': 'en'},
#      'uri': ''}]},
#   'header': {'id': 'NM_1_1',
#    'prepared': '2024-03-27T11:19:24Z',
#    'sender': {'contact': {'email': 'support@nomisweb.co.uk',
#      'name': 'Nomis',
#      'telephone': '+44(0) 191 3342680',
#      'uri': 'https://www.nomisweb.co.uk'},
#     'id': 'NOMIS'},
#    'test': 'false'},
#   'xmlns': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message',
#   'common': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common',
#   'structure': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure',
#   'xsi': 'http://www.w3.org/2001/XMLSchema-instance',
#   'schemalocation': 'http://sdmx.org/docs/2_0/SDMXMessage.xsd'}}

# %%
api_url = '/api/v01/dataset/NM_1_1/geography/2092957697TYPE441.def.sdmx.json' # major towns and cities within United Kingdom
url = root_url + api_url

response = requests.get(url)
cities_json = json.loads(response.text)
cities_json = cities_json['structure']['codelists']['codelist'][0]['code']
cities_list = []
for city in cities_json:
    geog_code = city['annotations']['annotation'][2]['annotationtext']
    name = city['description']['value']
    id = city['value']
    city_dict = {
        'id': id,
        'name': name,
        'geog_code': geog_code
    }
    cities_list.append(city_dict)
cities_df = pd.DataFrame(cities_list)
cities_df
# Out:
#              id           name  geog_code
# 0    1849688065       Barnsley  J01000001
# 1    1849688066       Basildon  J01000002
# 2    1849688067    Basingstoke  J01000003
# 3    1849688068           Bath  J01000004
# 4    1849688069        Bedford  J01000005
# ..          ...            ...        ...
# 107  1849688172         Woking  J01000108
# 108  1849688173  Wolverhampton  J01000109
# 109  1849688174      Worcester  J01000110
# 110  1849688175       Worthing  J01000111
# 111  1849688176           York  J01000112
#
# [112 rows x 3 columns]

# %%
c2011_lookup = pd.read_csv(r'data\raw\geoportal\Middle_Layer_Super_Output_Area_(2011)_to_Major_Towns_and_Cities_(December_2015)_Lookup_in_England_and_Wales.csv')
c2011_lookup = c2011_lookup.dropna(subset=['TCITY15NM'])
c2011_lookup
# Out:
#        MSOA11CD        MSOA11NM  TCITY15CD   TCITY15NM   FID
# 0     E02000053      Barnet 030  J01000055      London     1
# 1     E02000209     Croydon 016  J01000055      London     2
# 2     E02000054      Barnet 031  J01000055      London     3
# 3     E02000055      Barnet 032  J01000055      London     4
# 4     E02000056      Barnet 033  J01000055      London     5
# ...         ...             ...        ...         ...   ...
# 7196  E02003999    Carlisle 013  J01000021    Carlisle  7197
# 7197  E02005068   Maidstone 001  J01000022     Chatham  7198
# 7198  E02004497  Chelmsford 013  J01000023  Chelmsford  7199
# 7199  E02004493  Chelmsford 009  J01000023  Chelmsford  7200
# 7200  E02002792        York 021  J01000112        York  7201
#
# [3260 rows x 5 columns]

# %%
c2021_lookup = pd.read_csv(r'data\raw\geoportal\MSOA_(2011)_to_MSOA_(2021)_to_Local_Authority_District_(2022)_Lookup_for_England_and_Wales_(Version_2).csv')
c2021_lookup = c2021_lookup[['MSOA11CD', 'MSOA21CD']]
c2021_lookup = c2021_lookup.merge(c2011_lookup, on='MSOA11CD', how='inner')
c2021_lookup = c2021_lookup.drop('MSOA11CD', axis=1)
c2021_lookup = c2021_lookup.rename(columns={'MSOA11NM': 'MSOA21NM'})
c2021_lookup
# Out:
#        MSOA21CD       MSOA21NM  TCITY15CD TCITY15NM   FID
# 0     E02000308    Enfield 032  J01000055    London   336
# 1     E02000309    Enfield 033  J01000055    London   337
# 2     E02000311    Enfield 035  J01000055    London   338
# 3     E02000312    Enfield 036  J01000055    London    77
# 4     E02000313  Greenwich 001  J01000055    London    81
# ...         ...            ...        ...       ...   ...
# 3255  W02000193    Swansea 026  J01000098   Swansea  7002
# 3256  W02000194    Swansea 027  J01000098   Swansea  7047
# 3257  W02000196    Swansea 029  J01000098   Swansea  7055
# 3258  W02000198    Swansea 031  J01000098   Swansea  7063
# 3259  W02000423    Cardiff 049  J01000020   Cardiff  7178
#
# [3260 rows x 5 columns]

# %%
# api_url = '/api/v01/dataset/def.sdmx.json' # view all datasets
api_url = '/api/v01/dataset/def.sdmx.json?search=C2021TS*'
# api_url = '/api/v01/dataset/NM_2021_1/def.sdmx.json'


url = root_url + api_url

response = requests.get(url)
json.loads(response.text)
# Out:
# {'structure': {'header': {'id': 'none',
#    'prepared': '2024-03-27T11:19:30Z',
#    'sender': {'contact': {'email': 'support@nomisweb.co.uk',
#      'name': 'Nomis',
#      'telephone': '+44(0) 191 3342680',
#      'uri': 'https://www.nomisweb.co.uk'},
#     'id': 'NOMIS'},
#    'test': 'false'},
#   'keyfamilies': {'keyfamily': [{'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Age', 'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts007a', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents in England and Wales by five-year age bands. The estimates are as at Census Day, 21 March 2021',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2020_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2020_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2020_1_C2021_AGE_19', 'conceptref': 'C2021_AGE_19'},
#        {'codelist': 'CL_2020_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2020_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2020_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS007A - Age by five-year age bands', 'lang': 'en'},
#      'uri': 'Nm-2020d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Persons,Households', 'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts001', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents in England and Wales by whether they resided in households and communal establishments. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2021_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2021_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2021_1_C2021_RESTYPE_3',
#         'conceptref': 'C2021_RESTYPE_3'},
#        {'codelist': 'CL_2021_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2021_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2021_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS001 - Number of usual residents in households and communal establishments',
#       'lang': 'en'},
#      'uri': 'Nm-2021d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Married,Separated,Divorced,Widowed',
#         'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents aged 16 and over',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts002', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents aged 16 years and over in England and Wales by their legal partnership status. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2022_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2022_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2022_1_C2021_LPSTAT_12',
#         'conceptref': 'C2021_LPSTAT_12'},
#        {'codelist': 'CL_2022_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2022_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2022_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS002 - Legal partnership status', 'lang': 'en'},
#      'uri': 'Nm-2022d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Dependent child,Household,Household composition,Lone parent,Cohabiting couple family,Married or civil partnership couple,Single-family household,Same-sex civil partnership couple,Students,Schoolchildren',
#         'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Households', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All households',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts003', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify households in England and Wales by the relationships between household members (household composition). The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2023_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2023_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2023_1_C2021_HHCOMP_15',
#         'conceptref': 'C2021_HHCOMP_15'},
#        {'codelist': 'CL_2023_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2023_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2023_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS003 - Household composition', 'lang': 'en'},
#      'uri': 'Nm-2023d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Country of Birth,Usual Resident',
#         'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts004', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents in England and Wales by their country of birth. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2024_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2024_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2024_1_C2021_COB_12', 'conceptref': 'C2021_COB_12'},
#        {'codelist': 'CL_2024_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2024_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2024_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS004 - Country of birth', 'lang': 'en'},
#      'uri': 'Nm-2024d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Passports Held', 'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts005', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents in England and Wales by passports held. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2025_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2025_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2025_1_C2021_PASS_27', 'conceptref': 'C2021_PASS_27'},
#        {'codelist': 'CL_2025_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2025_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2025_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS005 - Passports held', 'lang': 'en'},
#      'uri': 'Nm-2025d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Population density', 'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts006', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents in England and Wales by population density (number of usual residents per square kilometre). The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2026_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2026_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2026_1_CELL', 'conceptref': 'CELL'},
#        {'codelist': 'CL_2026_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2026_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2026_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS006 - Population density', 'lang': 'en'},
#      'uri': 'Nm-2026d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Age,Usual Resident', 'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts007', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents in England and Wales by single year of age. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2027_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2027_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2027_1_C2021_AGE_102', 'conceptref': 'C2021_AGE_102'},
#        {'codelist': 'CL_2027_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2027_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2027_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS007 - Age by single year', 'lang': 'en'},
#      'uri': 'Nm-2027d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Sex', 'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts008', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents in England and Wales by sex. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2028_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2028_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2028_1_C_SEX', 'conceptref': 'C_SEX'},
#        {'codelist': 'CL_2028_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2028_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2028_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS008 - Sex', 'lang': 'en'},
#      'uri': 'Nm-2028d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Age,Usual Resident,Sex',
#         'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'la', 'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts009', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents in England and Wales by sex and single year of age. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2029_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2029_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2029_1_C_SEX', 'conceptref': 'C_SEX'},
#        {'codelist': 'CL_2029_1_C2021_AGE_92', 'conceptref': 'C2021_AGE_92'},
#        {'codelist': 'CL_2029_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2029_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2029_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS009 - Sex by single year of age', 'lang': 'en'},
#      'uri': 'Nm-2029d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Sex', 'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents aged 16 years and over in households',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts010', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents aged 16 years and over in households in England and Wales by their living arrangements. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2030_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2030_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2030_1_C2021_LIVING_11',
#         'conceptref': 'C2021_LIVING_11'},
#        {'codelist': 'CL_2030_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2030_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2030_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS010 - Living arrangements', 'lang': 'en'},
#      'uri': 'Nm-2030d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Sex', 'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Households', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All households',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts011', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify households in England and Wales by four dimensions of deprivation: Employment, education, health and disability, and household overcrowding. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2031_1',
# ...
#      'name': {'value': 'TS075 - Multi religion households', 'lang': 'en'},
#      'uri': 'Nm-2097d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'la', 'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents aged 3 and over',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts076', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-12-06 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-12-06 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents in Wales by their ability to speak Welsh by age. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2098_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2098_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2098_1_C2021_WLANGS_3',
#         'conceptref': 'C2021_WLANGS_3'},
#        {'codelist': 'CL_2098_1_C2021_AGE_86', 'conceptref': 'C2021_AGE_86'},
#        {'codelist': 'CL_2098_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2098_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2098_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS076 - Welsh language skills (speaking) by single year of age',
#       'lang': 'en'},
#      'uri': 'Nm-2098d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'All usual residents in communal establishments',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts048np', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify communal establishment residents in national parks in England and Wales by the type of communal establishment they live in. The estimates are as at Census Day, 21 March 2021. \n\n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2099_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2099_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2099_1_C2021_COMEST_12',
#         'conceptref': 'C2021_COMEST_12'},
#        {'codelist': 'CL_2099_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2099_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2099_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS048NP - Communal establishment management and type - National Parks',
#       'lang': 'en'},
#      'uri': 'Nm-2099d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'All usual residents aged 16 years and over in employment the week before the census',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts060np', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents aged 16 years and over in employment the week before the census in national parks in England and Wales by industry. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2100_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2100_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2100_1_C2021_IND_16', 'conceptref': 'C2021_IND_16'},
#        {'codelist': 'CL_2100_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2100_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2100_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS060NP - Industry - National Parks', 'lang': 'en'},
#      'uri': 'Nm-2100d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Cars', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'All cars or vans available for use by household members in the area',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts045a', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates on the total number of cars or vans available to members of households in England and Wales. The estimates are as at Census Day, 21 March 2021.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2324_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2324_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2324_1_C2021_CARS_TOTAL',
#         'conceptref': 'C2021_CARS_TOTAL'},
#        {'codelist': 'CL_2324_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2324_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2324_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS045A - Number of cars or vans in the area',
#       'lang': 'en'},
#      'uri': 'Nm-2324d1',
#      'version': 1.0}]},
#   'xmlns': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message',
#   'common': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common',
#   'structure': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure',
#   'xsi': 'http://www.w3.org/2001/XMLSchema-instance',
#   'schemalocation': 'http://sdmx.org/docs/2_0/SDMXMessage.xsd'}}

# %%
api_url = '/api/v01/dataset/def.sdmx.json?search=C2021TS*'
url = root_url + api_url
response = requests.get(url)

c2021_datasets_json = json.loads(response.text)
c2021_datasets_json = c2021_datasets_json['structure']['keyfamilies']['keyfamily']
c2021_datasets_metadata_list = []
for dataset in c2021_datasets_json:
    annotations = dataset['annotations']['annotation']
    for annotation in annotations:
        if annotation['annotationtitle'] == 'contenttype/geoglevel':
            geoglevel = annotation['annotationtext']
        if annotation['annotationtitle'] == 'Mnemonic':
            mnemonic = annotation['annotationtext']
        if annotation['annotationtitle'] == 'MetadataText0':
            description = annotation['annotationtext']
    id = dataset['id']
    metadata = {
        'id': id,
        'mnemonic': mnemonic,
        'description': description,
        'geoglevel': geoglevel
    }
    c2021_datasets_metadata_list.append(metadata)
c2021_datasets_metadata_df = pd.DataFrame(c2021_datasets_metadata_list)
c2021_datasets_metadata_df.to_csv('./data/raw/api/c2021/metadata.csv')
c2021_datasets_metadata_df
# Out:
#            id      mnemonic  \
# 0   NM_2020_1   c2021ts007a
# 1   NM_2021_1    c2021ts001
# 2   NM_2022_1    c2021ts002
# 3   NM_2023_1    c2021ts003
# 4   NM_2024_1    c2021ts004
# ..        ...           ...
# 75  NM_2097_1    c2021ts075
# 76  NM_2098_1    c2021ts076
# 77  NM_2099_1  c2021ts048np
# 78  NM_2100_1  c2021ts060np
# 79  NM_2324_1   c2021ts045a
#
#                                           description   geoglevel
# 0   This dataset provides Census 2021 estimates th...  oa,msoa,la
# 1   This dataset provides Census 2021 estimates th...  oa,msoa,la
# 2   This dataset provides Census 2021 estimates th...  oa,msoa,la
# 3   This dataset provides Census 2021 estimates th...  oa,msoa,la
# 4   This dataset provides Census 2021 estimates th...  oa,msoa,la
# ..                                                ...         ...
# 75  This dataset provides Census 2021 estimates th...  oa,msoa,la
# 76  This dataset provides Census 2021 estimates th...          la
# 77  This dataset provides Census 2021 estimates th...          la
# 78  This dataset provides Census 2021 estimates th...          la
# 79  This dataset provides Census 2021 estimates on...          la
#
# [80 rows x 4 columns]

# %%
c2021_datasets_metadata_df["id"][0]
# Out:
# 'NM_2020_1'

# %%
# record_limit = 25000
# offset = 0

# for dataset in c2021_datasets_metadata_list[8:]:
#     id = dataset['id']
#     mnemonic = dataset['mnemonic']
#     # if mnemonic != 'c2021ts007a':
#     #     continue
#     geoglevel = dataset['geoglevel'].split(',')
#     if 'msoa' not in geoglevel:
#         continue

#     print("downloading", mnemonic)
#     api_url = f'/api/v01/dataset/{id}.data.csv?recordlimit=10'
#     url = root_url + api_url
#     try:
#         dataset_df = pd.read_csv(url)
#     except:
#         time.sleep(60)
#         dataset_df = pd.read_csv(url)
#     dataset_df.to_csv('test.csv')
#     try:
#         stat_name = dataset_df.filter(regex='^C2021.*NAME$', axis=1).columns[0].lower()
#     except:
#         try:
#             stat_name = dataset_df.filter(regex='^CELL.*NAME$', axis=1).columns[0].lower()
#         except:
#             stat_name = dataset_df.filter(regex='^C_.*NAME$', axis=1).columns[0].lower()

#     last_record = offset

#     for i in range(1000):
#         print(f"trying records {last_record} - {last_record + record_limit}")
#         api_url = f'/api/v01/dataset/{id}.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,{stat_name},obs_value&recordlimit={record_limit}&recordoffset={last_record}'
#         # api_url = f'/api/v01/dataset/{id}.data.csv?uid=0xd9817610eb1bbb16a8e6d24954e88792f83ff1f3&measures=20100&recordlimit={record_limit}&recordoffset={last_record}'
#         url = root_url + api_url

#         print(url)

#         try:
#             batch_df = pd.read_csv(url)
#         except pd.errors.EmptyDataError:
#             print("empty dataset")
#             break
#         except:
#             time.sleep(60)
#             batch_df = pd.read_csv(url)

#         display(batch_df.head())

#         if len(batch_df) == 0:
#             break

#         dest_file = f'./data/raw/api/c2021/{mnemonic}_{i:02}.csv'
#         batch_df.to_csv(dest_file)
#         print(f"chunk {i} saved in {dest_file}")

#         last_record += record_limit

# %%
api_url = '/api/v01/dataset/def.sdmx.json?search=c2011ks*'
url = root_url + api_url
response = requests.get(url)
json.loads(response.text)
# Out:
# {'structure': {'header': {'id': 'none',
#    'prepared': '2024-03-27T11:19:41Z',
#    'sender': {'contact': {'email': 'support@nomisweb.co.uk',
#      'name': 'Nomis',
#      'telephone': '+44(0) 191 3342680',
#      'uri': 'https://www.nomisweb.co.uk'},
#     'id': 'NOMIS'},
#    'test': 'false'},
#   'keyfamilies': {'keyfamily': [{'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Area (Hectares),Communal Establishment,Household,Household resident,Population density,Students,Schoolchildren,Usual Resident',
#         'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2011_ks',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,ps', 'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 2.2, 'annotationtitle': 'contenttype/censusrelease'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2011ks101ew', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2013-02-12 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2013-02-12 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'Usual resident population',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This table provides information that classifies by sex for the usual resident population of England and Wales as at census day, 27 March 2011.\n\nThe 2011 usual resident population is also classified by the number of residents living in households and those living in communal establishments.\n\n Additional information provided includes the area and population density for each area, and the number of students and schoolchildren who would reside in each area if they were not living away from their family home during term-time.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Statistical Disclosure Control',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'In order to protect against disclosure of personal information from the 2011 Census, there has been swapping of records in the Census database between different geographic areas, and so some counts will be affected. In the main, the greatest effects will be at the lowest geographies, since the record swapping is targeted towards those households with unusual characteristics in small areas.\n\nMore details on the ONS Census disclosure control strategy may be found on the http://www.ons.gov.uk/ons/guide-method/census/2011/census-data/2011-census-prospectus/new-developments-for-2011-census-results/statistical-disclosure-control/index.html[Statistical Disclosure Control] page on the ONS web site.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_144_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_144_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_144_1_RURAL_URBAN', 'conceptref': 'RURAL_URBAN'},
#        {'codelist': 'CL_144_1_CELL', 'conceptref': 'CELL'},
#        {'codelist': 'CL_144_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_144_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_144_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'KS101EW - Usual resident population', 'lang': 'en'},
#      'uri': 'Nm-144d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Age,Mean age,Median age,Usual Resident',
#         'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2011_ks',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,ps', 'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 2.2, 'annotationtitle': 'contenttype/censusrelease'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2011ks102ew', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2013-02-12 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2013-02-12 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'Age Structure',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This table provides information about the age structure, mean and median ages of usual residents of England and Wales as at census day, 27 March 2011.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Statistical Disclosure Control',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'In order to protect against disclosure of personal information from the 2011 Census, there has been swapping of records in the Census database between different geographic areas, and so some counts will be affected. In the main, the greatest effects will be at the lowest geographies, since the record swapping is targeted towards those households with unusual characteristics in small areas.\n\nMore details on the ONS Census disclosure control strategy may be found on the http://www.ons.gov.uk/ons/guide-method/census/2011/census-data/2011-census-prospectus/new-developments-for-2011-census-results/statistical-disclosure-control/index.html[Statistical Disclosure Control] page on the ONS web site.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_145_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_145_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_145_1_RURAL_URBAN', 'conceptref': 'RURAL_URBAN'},
#        {'codelist': 'CL_145_1_CELL', 'conceptref': 'CELL'},
#        {'codelist': 'CL_145_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_145_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_145_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'KS102EW - Age structure', 'lang': 'en'},
#      'uri': 'Nm-145d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Average bedrooms per household,Average rooms per household,Bedrooms,Central Heating,Household,Household size,Occupancy rating,Rooms',
#         'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Households', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2011_ks',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,ps', 'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 2.2, 'annotationtitle': 'contenttype/censusrelease'},
#        {'annotationtext': 'All households',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2011ks403ew', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2013-02-08 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2014-01-17 12:00:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': '2014-01-17 12:00:00',
#         'annotationtitle': 'LastRevised'},
#        {'annotationtext': 'Rooms, bedrooms and central heating',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This table provides information about the rooms, bedrooms and central heating in households, for England and Wales as at census day, 27 March 2011. It includes information about the average size of households, whether they have central heating, the number of rooms and bedrooms, and the occupancy rating of the household (based on both rooms and bedrooms).',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Statistical Disclosure Control',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'In order to protect against disclosure of personal information from the 2011 Census, there has been swapping of records in the Census database between different geographic areas, and so some counts will be affected. In the main, the greatest effects will be at the lowest geographies, since the record swapping is targeted towards those households with unusual characteristics in small areas.\n\nMore details on the ONS Census disclosure control strategy may be found on the http://www.ons.gov.uk/ons/guide-method/census/2011/census-data/2011-census-prospectus/new-developments-for-2011-census-results/statistical-disclosure-control/index.html[Statistical Disclosure Control] page on the ONS web site.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_146_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_146_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_146_1_RURAL_URBAN', 'conceptref': 'RURAL_URBAN'},
#        {'codelist': 'CL_146_1_CELL', 'conceptref': 'CELL'},
#        {'codelist': 'CL_146_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_146_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_146_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'KS403EW - Rooms, bedrooms and central heating',
#       'lang': 'en'},
#      'uri': 'Nm-146d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Area (Hectares),Communal Establishment,Household,Household resident,Population density,Students,Schoolchildren,Usual Resident',
#         'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2011_ksuk',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'UK.2',
#         'annotationtitle': 'contenttype/censusrelease'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2011ks101uk', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2014-06-13 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2014-06-13 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'Usual resident population',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': "This table provides information that classifies by sex for the usual resident population of United Kingdom as at census day, 27 March 2011.\n\nThe 2011 usual resident population is also classified by the number of residents living in households and those living in communal establishments.\n\nAdditional information provided includes the area and population density for each area, and the number of students and schoolchildren who would reside in each area if they were not living away from their family home during term-time.\n\n'All full-time students and schoolchildren aged 4+ years living away from home during term time' figures for Northern Ireland sourced from table QS106NI.\n\nArea and Population Density figures for Noerthern Ireland sourced from table QS102NI.",
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Statistical Disclosure Control',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'In order to protect against disclosure of personal information from the 2011 Census, there has been swapping of records in the Census database between different geographic areas, and so some counts will be affected. In the main, the greatest effects will be at the lowest geographies, since the record swapping is targeted towards those households with unusual characteristics in small areas.\n\nMore details on the ONS Census disclosure control strategy may be found on the http://www.ons.gov.uk/ons/guide-method/census/2011/census-data/2011-census-prospectus/new-developments-for-2011-census-results/statistical-disclosure-control/index.html[Statistical Disclosure Control] page on the ONS web site.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_158_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_158_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_158_1_CELL', 'conceptref': 'CELL'},
#        {'codelist': 'CL_158_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_158_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_158_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'KS101UK - Usual resident population', 'lang': 'en'},
#      'uri': 'Nm-158d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Age,Mean age,Median age,Usual Resident',
#         'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2011_ksuk',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'UK.2',
#         'annotationtitle': 'contenttype/censusrelease'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2011ks102uk', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2014-06-13 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2014-06-13 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'Age Structure',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This table provides information about the age structure, mean and median ages of usual residents of United Kingdom as at census day, 27 March 2011.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Statistical Disclosure Control',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'In order to protect against disclosure of personal information from the 2011 Census, there has been swapping of records in the Census database between different geographic areas, and so some counts will be affected. In the main, the greatest effects will be at the lowest geographies, since the record swapping is targeted towards those households with unusual characteristics in small areas.\n\nMore details on the ONS Census disclosure control strategy may be found on the http://www.ons.gov.uk/ons/guide-method/census/2011/census-data/2011-census-prospectus/new-developments-for-2011-census-results/statistical-disclosure-control/index.html[Statistical Disclosure Control] page on the ONS web site.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_159_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_159_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_159_1_RURAL_URBAN', 'conceptref': 'RURAL_URBAN'},
#        {'codelist': 'CL_159_1_CELL', 'conceptref': 'CELL'},
#        {'codelist': 'CL_159_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_159_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_159_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'KS102UK - Age Structure', 'lang': 'en'},
#      'uri': 'Nm-159d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Marital status,Civil partnership status,Usual Resident',
#         'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2011_ks',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,ps', 'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 2.2, 'annotationtitle': 'contenttype/censusrelease'},
#        {'annotationtext': 'All usual residents aged 16 and over',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2011ks103ew', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2013-02-01 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2013-02-01 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'Marital and civil partnership status',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This table provides information that classified usual residents aged 16 and over by marital and civil partnership status, for England and Wales as at census day, 27 March 2011.\n\nThis classification takes account of the Civil Partnership Act which came into force on 5 December 2005, providing information about civil partnership status for the first time in census results.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Statistical Disclosure Control',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'In order to protect against disclosure of personal information from the 2011 Census, there has been swapping of records in the Census database between different geographic areas, and so some counts will be affected. In the main, the greatest effects will be at the lowest geographies, since the record swapping is targeted towards those households with unusual characteristics in small areas.\n\nMore details on the ONS Census disclosure control strategy may be found on the http://www.ons.gov.uk/ons/guide-method/census/2011/census-data/2011-census-prospectus/new-developments-for-2011-census-results/statistical-disclosure-control/index.html[Statistical Disclosure Control] page on the ONS web site.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_603_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_603_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_603_1_RURAL_URBAN', 'conceptref': 'RURAL_URBAN'},
#        {'codelist': 'CL_603_1_CELL', 'conceptref': 'CELL'},
#        {'codelist': 'CL_603_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_603_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_603_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'KS103EW - Marital and civil partnership status',
#       'lang': 'en'},
#      'uri': 'Nm-603d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Household,Living arrangements,Living in a couple,Marital status,Civil partnership status,Not living in a couple,Usual Resident',
#         'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2011_ks',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,ps', 'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 2.2, 'annotationtitle': 'contenttype/censusrelease'},
#        {'annotationtext': 'All usual residents aged 16 and over in households',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2011ks104ew', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2013-01-30 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2013-01-30 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'Living arrangements',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This table provides information that classifies usual residents aged 16 and over in households by their living arrangements, for England and Wales as at census day, 27 March 2011. The living arrangements classification differs from marital and civil partnership status because cohabiting takes priority over other categories.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Statistical Disclosure Control',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'In order to protect against disclosure of personal information from the 2011 Census, there has been swapping of records in the Census database between different geographic areas, and so some counts will be affected. In the main, the greatest effects will be at the lowest geographies, since the record swapping is targeted towards those households with unusual characteristics in small areas.\n\nMore details on the ONS Census disclosure control strategy may be found on the http://www.ons.gov.uk/ons/guide-method/census/2011/census-data/2011-census-prospectus/new-developments-for-2011-census-results/statistical-disclosure-control/index.html[Statistical Disclosure Control] page on the ONS web site.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_604_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_604_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_604_1_RURAL_URBAN', 'conceptref': 'RURAL_URBAN'},
#        {'codelist': 'CL_604_1_CELL', 'conceptref': 'CELL'},
#        {'codelist': 'CL_604_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_604_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_604_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'KS104EW - Living arrangements', 'lang': 'en'},
#      'uri': 'Nm-604d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Cohabiting couple,Dependent child,Household,Household composition,Lone parent,Married couple family,Married couple household,One family only,Same-sex civil partnership couple,Students,Schoolchildren',
#         'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Households', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2011_ks',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,ps', 'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 2.2, 'annotationtitle': 'contenttype/censusrelease'},
#        {'annotationtext': 'All households',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2011ks105ew', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2013-01-30 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2013-01-30 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'Household composition',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This table provides information that classifies households by the relationships between the household members (household composition), for England and Wales as at census day, 27 March 2011.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Statistical Disclosure Control',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'In order to protect against disclosure of personal information from the 2011 Census, there has been swapping of records in the Census database between different geographic areas, and so some counts will be affected. In the main, the greatest effects will be at the lowest geographies, since the record swapping is targeted towards those households with unusual characteristics in small areas.\n\nMore details on the ONS Census disclosure control strategy may be found on the http://www.ons.gov.uk/ons/guide-method/census/2011/census-data/2011-census-prospectus/new-developments-for-2011-census-results/statistical-disclosure-control/index.html[Statistical Disclosure Control] page on the ONS web site.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_605_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_605_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_605_1_RURAL_URBAN', 'conceptref': 'RURAL_URBAN'},
#        {'codelist': 'CL_605_1_CELL', 'conceptref': 'CELL'},
#        {'codelist': 'CL_605_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_605_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_605_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'KS105EW - Household composition', 'lang': 'en'},
#      'uri': 'Nm-605d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Adult,Dependent child,Not in employment,Household,Long-term health problem or disability,Disability',
#         'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Households', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2011_ks',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,ps', 'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 2.2, 'annotationtitle': 'contenttype/censusrelease'},
#        {'annotationtext': 'All households',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2011ks106ew', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2013-01-30 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2013-01-30 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'Adults not in employment and dependent children and persons with long-term health problem or disability for all households',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This table provides information that classifies households by the presence of dependent children, adults not in employment and people with a long-term health problem or disability. Information is provided for all households in England and Wales as at census day, 27 March 2011.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Statistical Disclosure Control',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'In order to protect against disclosure of personal information from the 2011 Census, there has been swapping of records in the Census database between different geographic areas, and so some counts will be affected. In the main, the greatest effects will be at the lowest geographies, since the record swapping is targeted towards those households with unusual characteristics in small areas.\n\nMore details on the ONS Census disclosure control strategy may be found on the http://www.ons.gov.uk/ons/guide-method/census/2011/census-data/2011-census-prospectus/new-developments-for-2011-census-results/statistical-disclosure-control/index.html[Statistical Disclosure Control] page on the ONS web site.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_606_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_606_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_606_1_RURAL_URBAN', 'conceptref': 'RURAL_URBAN'},
#        {'codelist': 'CL_606_1_CELL', 'conceptref': 'CELL'},
#        {'codelist': 'CL_606_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_606_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_606_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'KS106EW - Adults not in employment and dependent children and persons with long-term health problems or disability for all households',
#       'lang': 'en'},
#      'uri': 'Nm-606d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Dependent child,Employed (in employment),Full-time working,Household,Lone parent,Main job,Part-time working,Sex',
#         'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Households', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2011_ks',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,ps', 'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 2.2, 'annotationtitle': 'contenttype/censusrelease'},
#        {'annotationtext': 'All lone parent households with dependent children where the lone parent is aged 16 to 74',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2011ks107ew', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2013-01-30 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2013-01-30 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'Lone parent households with dependent children',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This table provides information about lone parent households with dependent children, for England and Wales as at census day, 27 March 2011. Households are classified by the sex of the lone parent and their employment status.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Statistical Disclosure Control',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'In order to protect against disclosure of personal information from the 2011 Census, there has been swapping of records in the Census database between different geographic areas, and so some counts will be affected. In the main, the greatest effects will be at the lowest geographies, since the record swapping is targeted towards those households with unusual characteristics in small areas.\n\nMore details on the ONS Census disclosure control strategy may be found on the http://www.ons.gov.uk/ons/guide-method/census/2011/census-data/2011-census-prospectus/new-developments-for-2011-census-results/statistical-disclosure-control/index.html[Statistical Disclosure Control] page on the ONS web site.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_607_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_607_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_607_1_RURAL_URBAN', 'conceptref': 'RURAL_URBAN'},
#        {'codelist': 'CL_607_1_CELL', 'conceptref': 'CELL'},
#        {'codelist': 'CL_607_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_607_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_607_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'KS107EW - Lone parent households with dependent children',
#       'lang': 'en'},
#      'uri': 'Nm-607d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Ethnic Group,Usual Resident',
#         'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2011_ks',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,ps', 'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 2.2, 'annotationtitle': 'contenttype/censusrelease'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2011ks201ew', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2013-01-30 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2013-01-30 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'Ethnic Group', 'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This table provides information about the ethnic group of the usual resident population of England and Wales as at census day, 27 March 2011.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Statistical Disclosure Control',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'In order to protect against disclosure of personal information from the 2011 Census, there has been swapping of records in the Census database between different geographic areas, and so some counts will be affected. In the main, the greatest effects will be at the lowest geographies, since the record swapping is targeted towards those households with unusual characteristics in small areas.\n\nMore details on the ONS Census disclosure control strategy may be found on the http://www.ons.gov.uk/ons/guide-method/census/2011/census-data/2011-census-prospectus/new-developments-for-2011-census-results/statistical-disclosure-control/index.html[Statistical Disclosure Control] page on the ONS web site.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_608_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_608_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_608_1_RURAL_URBAN', 'conceptref': 'RURAL_URBAN'},
#        {'codelist': 'CL_608_1_CELL', 'conceptref': 'CELL'},
#        {'codelist': 'CL_608_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_608_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_608_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'KS201EW - Ethnic group', 'lang': 'en'},
#      'uri': 'Nm-608d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'National Identity,Usual Resident',
#         'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2011_ks',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,ps', 'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 2.2, 'annotationtitle': 'contenttype/censusrelease'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2011ks202ew', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2013-01-30 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2013-01-30 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'National identity',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This table provides information that classifies usual residents by their national identity, for England and Wales as at census day, 27 March 2011.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Statistical Disclosure Control',
#         'annotationtitle': 'MetadataTitle1'},
# ...
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2011_ksuk',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa', 'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'UK.2',
#         'annotationtitle': 'contenttype/censusrelease'},
#        {'annotationtext': 'All female usual residents aged 16 to 74 in employment the week before the census',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2011ks610uk', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2014-06-13 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2014-06-13 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'Occupation - Females',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This table provides information that classifies usual residents aged 16 to 74 in employment the week before the census by occupation, for United Kingdom as at census day, 27 March 2011.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Statistical Disclosure Control',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'In order to protect against disclosure of personal information from the 2011 Census, there has been swapping of records in the Census database between different geographic areas, and so some counts will be affected. In the main, the greatest effects will be at the lowest geographies, since the record swapping is targeted towards those households with unusual characteristics in small areas.\n\nMore details on the ONS Census disclosure control strategy may be found on the http://www.ons.gov.uk/ons/guide-method/census/2011/census-data/2011-census-prospectus/new-developments-for-2011-census-results/statistical-disclosure-control/index.html[Statistical Disclosure Control] page on the ONS web site.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_1520_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_1520_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_1520_1_CELL', 'conceptref': 'CELL'},
#        {'codelist': 'CL_1520_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_1520_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_1520_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'KS610UK - Occupation - Females', 'lang': 'en'},
#      'uri': 'Nm-1520d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Long-term unemployed,NS-SeC,Students,Schoolchildren,Unemployed,Usual Resident',
#         'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2011_ksuk',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa', 'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'UK.2',
#         'annotationtitle': 'contenttype/censusrelease'},
#        {'annotationtext': 'All usual residents aged 16 to 74',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2011ks611uk', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2014-06-13 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2014-06-13 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'NS-SeC', 'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This table provides information about the National Statistics Socio-economic Classification (NS-SeC) of usual residents aged 16 to 74, for United Kingdom as at census day, 27 March 2011.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Statistical Disclosure Control',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'In order to protect against disclosure of personal information from the 2011 Census, there has been swapping of records in the Census database between different geographic areas, and so some counts will be affected. In the main, the greatest effects will be at the lowest geographies, since the record swapping is targeted towards those households with unusual characteristics in small areas.\n\nMore details on the ONS Census disclosure control strategy may be found on the http://www.ons.gov.uk/ons/guide-method/census/2011/census-data/2011-census-prospectus/new-developments-for-2011-census-results/statistical-disclosure-control/index.html[Statistical Disclosure Control] page on the ONS web site.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_1521_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_1521_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_1521_1_CELL', 'conceptref': 'CELL'},
#        {'codelist': 'CL_1521_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_1521_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_1521_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'KS611UK - NS-SeC', 'lang': 'en'},
#      'uri': 'Nm-1521d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Long-term unemployed,NS-SeC,Students,Schoolchildren,Unemployed,Usual Resident',
#         'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2011_ksuk',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa', 'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'UK.2',
#         'annotationtitle': 'contenttype/censusrelease'},
#        {'annotationtext': 'All male usual residents aged 16 to 74',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2011ks612uk', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2014-06-13 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2014-06-13 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'NS-SeC - Males',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This table provides information about the National Statistics Socio-economic Classification (NS-SeC) of usual residents aged 16 to 74, for United Kingdom as at census day, 27 March 2011.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Statistical Disclosure Control',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'In order to protect against disclosure of personal information from the 2011 Census, there has been swapping of records in the Census database between different geographic areas, and so some counts will be affected. In the main, the greatest effects will be at the lowest geographies, since the record swapping is targeted towards those households with unusual characteristics in small areas.\n\nMore details on the ONS Census disclosure control strategy may be found on the http://www.ons.gov.uk/ons/guide-method/census/2011/census-data/2011-census-prospectus/new-developments-for-2011-census-results/statistical-disclosure-control/index.html[Statistical Disclosure Control] page on the ONS web site.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_1522_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_1522_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_1522_1_CELL', 'conceptref': 'CELL'},
#        {'codelist': 'CL_1522_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_1522_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_1522_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'KS612UK - NS-SeC - Males', 'lang': 'en'},
#      'uri': 'Nm-1522d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Long-term unemployed,NS-SeC,Students,Schoolchildren,Unemployed,Usual Resident',
#         'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2011_ksuk',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa', 'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'UK.2',
#         'annotationtitle': 'contenttype/censusrelease'},
#        {'annotationtext': 'All female usual residents aged 16 to 74',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2011ks613uk', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2014-06-13 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2014-06-13 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'NS-SeC - Females',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This table provides information about the National Statistics Socio-economic Classification (NS-SeC) of usual residents aged 16 to 74, for United Kingdom as at census day, 27 March 2011.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Statistical Disclosure Control',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'In order to protect against disclosure of personal information from the 2011 Census, there has been swapping of records in the Census database between different geographic areas, and so some counts will be affected. In the main, the greatest effects will be at the lowest geographies, since the record swapping is targeted towards those households with unusual characteristics in small areas.\n\nMore details on the ONS Census disclosure control strategy may be found on the http://www.ons.gov.uk/ons/guide-method/census/2011/census-data/2011-census-prospectus/new-developments-for-2011-census-results/statistical-disclosure-control/index.html[Statistical Disclosure Control] page on the ONS web site.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_1523_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_1523_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_1523_1_CELL', 'conceptref': 'CELL'},
#        {'codelist': 'CL_1523_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_1523_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_1523_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'KS613UK - NS-SeC - Females', 'lang': 'en'},
#      'uri': 'Nm-1523d1',
#      'version': 1.0}]},
#   'xmlns': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message',
#   'common': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common',
#   'structure': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure',
#   'xsi': 'http://www.w3.org/2001/XMLSchema-instance',
#   'schemalocation': 'http://sdmx.org/docs/2_0/SDMXMessage.xsd'}}

# %%
api_url = '/api/v01/dataset/def.sdmx.json?search=c2011ks*'
url = root_url + api_url
response = requests.get(url)

c2011_datasets_json = json.loads(response.text)
c2011_datasets_json = c2011_datasets_json['structure']['keyfamilies']['keyfamily']
c2011_datasets_metadata_list = []
for dataset in c2011_datasets_json:
    annotations = dataset['annotations']['annotation']
    for annotation in annotations:
        if annotation['annotationtitle'] == 'contenttype/geoglevel':
            geoglevel = annotation['annotationtext']
        if annotation['annotationtitle'] == 'Mnemonic':
            mnemonic = annotation['annotationtext']
        if annotation['annotationtitle'] == 'MetadataText0':
            description = annotation['annotationtext']
    id = dataset['id']
    metadata = {
        'id': id,
        'mnemonic': mnemonic,
        'description': description,
        'geoglevel': geoglevel
    }
    c2011_datasets_metadata_list.append(metadata)
c2011_datasets_metadata_df = pd.DataFrame(c2011_datasets_metadata_list)
c2011_datasets_metadata_df.to_csv('./data/raw/api/c2011/metadata.csv')
c2011_datasets_metadata_df
# Out:
#            id      mnemonic  \
# 0    NM_144_1  c2011ks101ew
# 1    NM_145_1  c2011ks102ew
# 2    NM_146_1  c2011ks403ew
# 3    NM_158_1  c2011ks101uk
# 4    NM_159_1  c2011ks102uk
# 5    NM_603_1  c2011ks103ew
# 6    NM_604_1  c2011ks104ew
# 7    NM_605_1  c2011ks105ew
# 8    NM_606_1  c2011ks106ew
# 9    NM_607_1  c2011ks107ew
# 10   NM_608_1  c2011ks201ew
# 11   NM_609_1  c2011ks202ew
# 12   NM_611_1  c2011ks204ew
# 13   NM_612_1  c2011ks205ew
# 14   NM_613_1  c2011ks206ew
# 15   NM_614_1  c2011ks207wa
# 16   NM_615_1  c2011ks208wa
# 17   NM_616_1  c2011ks209ew
# 18   NM_617_1  c2011ks301ew
# 19   NM_618_1  c2011ks401ew
# 20   NM_619_1  c2011ks402ew
# 21   NM_621_1  c2011ks404ew
# 22   NM_622_1  c2011ks405ew
# 23   NM_623_1  c2011ks501ew
# 24   NM_624_1  c2011ks601ew
# 25   NM_625_1  c2011ks604ew
# 26   NM_626_1  c2011ks605ew
# 27   NM_627_1  c2011ks608ew
# 28   NM_628_1  c2011ks611ew
# 29  NM_1500_1  c2011ks103uk
# 30  NM_1501_1  c2011ks104uk
# 31  NM_1502_1  c2011ks105uk
# 32  NM_1503_1  c2011ks107uk
# 33  NM_1504_1  c2011ks201uk
# 34  NM_1505_1  c2011ks301uk
# 35  NM_1506_1  c2011ks401uk
# 36  NM_1507_1  c2011ks402uk
# 37  NM_1508_1  c2011ks404uk
# 38  NM_1509_1  c2011ks405uk
# 39  NM_1510_1  c2011ks501uk
# 40  NM_1511_1  c2011ks601uk
# 41  NM_1512_1  c2011ks602uk
# 42  NM_1513_1  c2011ks603uk
# 43  NM_1514_1  c2011ks604uk
# 44  NM_1515_1  c2011ks605uk
# 45  NM_1516_1  c2011ks606uk
# 46  NM_1517_1  c2011ks607uk
# 47  NM_1518_1  c2011ks608uk
# 48  NM_1519_1  c2011ks609uk
# 49  NM_1520_1  c2011ks610uk
# 50  NM_1521_1  c2011ks611uk
# 51  NM_1522_1  c2011ks612uk
# 52  NM_1523_1  c2011ks613uk
#
#                                           description geoglevel
# 0   This table provides information that classifie...     oa,ps
# 1   This table provides information about the age ...     oa,ps
# 2   This table provides information about the room...     oa,ps
# 3   This table provides information that classifie...     oa,ps
# 4   This table provides information about the age ...     oa,ps
# 5   This table provides information that classifie...     oa,ps
# 6   This table provides information that classifie...     oa,ps
# 7   This table provides information that classifie...     oa,ps
# 8   This table provides information that classifie...     oa,ps
# 9   This table provides information about lone par...     oa,ps
# 10  This table provides information about the ethn...     oa,ps
# 11  This table provides information that classifie...     oa,ps
# 12  This table provides information that classifie...     oa,ps
# 13  This table provides information that classifie...     oa,ps
# 14  This table provides information that classifie...     oa,ps
# 15  This table provides information that classifie...     oa,ps
# 16  This "Welsh language profile" classifies usual...     oa,ps
# 17  This table provides information that classifie...     oa,ps
# 18  This table provides information about the heal...     oa,ps
# 19  This table provides information about dwelling...     oa,ps
# 20  This table provides information that classifie...     oa,ps
# 21  This table provides information about the numb...     oa,ps
# 22  This table provides information about the numb...     oa,ps
# 23  This table provides information that classifie...     oa,ps
# 24  This table provides information that classifie...     oa,ps
# 25  This table provides information that classifie...     oa,ps
# 26  This table provides information that classifie...     oa,ps
# 27  This table provides information that classifie...     oa,ps
# 28  This table provides information about the Nati...     oa,ps
# 29  This table provides information that classifie...        oa
# 30  This table provides information that classifie...        oa
# 31  This table provides information that classifie...        oa
# 32  This table provides information about lone par...        oa
# 33  This table provides information about the ethn...        oa
# 34  This table provides information about the heal...        oa
# 35  This table provides information about dwelling...        oa
# 36  This table provides information that classifie...        oa
# 37  This table provides information about the numb...        oa
# 38  This table provides information about the numb...        oa
# 39  This table provides information that classifie...        oa
# 40  This table provides information that classifie...        oa
# 41  This table provides information that classifie...        oa
# 42  This table provides information that classifie...        oa
# 43  This table provides information that classifie...        oa
# 44  This table provides information that classifie...        oa
# 45  This table provides information that classifie...        oa
# 46  This table provides information that classifie...        oa
# 47  This table provides information that classifie...        oa
# 48  This table provides information that classifie...        oa
# 49  This table provides information that classifie...        oa
# 50  This table provides information about the Nati...        oa
# 51  This table provides information about the Nati...        oa
# 52  This table provides information about the Nati...        oa

# %%
record_limit = 25000
offset = 0

for dataset in c2011_datasets_metadata_list[25:]:
    id = dataset['id']
    mnemonic = dataset['mnemonic']
    # if mnemonic != 'c2011ts007a':
    #     continue
    geoglevel = dataset['geoglevel'].split(',')
    if 'oa' not in geoglevel:
        continue

    print("downloading", mnemonic)
    api_url = f'/api/v01/dataset/{id}.data.csv?recordlimit=10'
    url = root_url + api_url
    try:
        dataset_df = pd.read_csv(url)
    except:
        time.sleep(60)
        dataset_df = pd.read_csv(url)
    dataset_df.to_csv('test.csv')
    try:
        stat_name = dataset_df.filter(regex='^C2011.*NAME$', axis=1).columns[0].lower()
    except:
        try:
            stat_name = dataset_df.filter(regex='^CELL.*NAME$', axis=1).columns[0].lower()
        except:
            try:
                stat_name = dataset_df.filter(regex='^C_.*NAME$', axis=1).columns[0].lower()
            except:
                stat_name = dataset_df.filter(regex='RURAL_URBAN_TYPE', axis=1).columns[0].lower()

    last_record = offset

    for i in range(1000):
        print(f"trying records {last_record} - {last_record + record_limit}")
        api_url = f'/api/v01/dataset/{id}.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,{stat_name},obs_value&recordlimit={record_limit}&recordoffset={last_record}'
        # api_url = f'/api/v01/dataset/{id}.data.csv?uid=0xd9817610eb1bbb16a8e6d24954e88792f83ff1f3&measures=20100&recordlimit={record_limit}&recordoffset={last_record}'
        url = root_url + api_url

        print(url)

        try:
            batch_df = pd.read_csv(url)
        except pd.errors.EmptyDataError:
            print("empty dataset")
            break
        except:
            time.sleep(60)
            batch_df = pd.read_csv(url)

        display(batch_df.head())

        if len(batch_df) == 0:
            break

        dest_file = f'./data/raw/api/c2011/{mnemonic}_{i:02}.csv'
        batch_df.to_csv(dest_file)
        print(f"chunk {i} saved in {dest_file}")

        last_record += record_limit
# Out:
# downloading c2011ks301ew
# trying records 0 - 25000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=0
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02002559  2011 super output areas - middle layer
# 1  2011      E02002559  2011 super output areas - middle layer
# 2  2011      E02002559  2011 super output areas - middle layer
# 3  2011      E02002559  2011 super output areas - middle layer
# 4  2011      E02002559  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                          CELL_NAME  \
# 0                 297  All categories: Long-term health problem or di...
# 1                 297                Day-to-day activities limited a lot
# 2                 297             Day-to-day activities limited a little
# 3                 297                  Day-to-day activities not limited
# 4                 297  Day-to-day activities limited a lot: Age 16 to 64
#
#    OBS_VALUE
# 0       8842
# 1        506
# 2        719
# 3       7617
# 4        199
# chunk 0 saved in ./data/raw/api/c2011/c2011ks301ew_00.csv
# trying records 25000 - 50000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=25000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02005710  2011 super output areas - middle layer
# 1  2011      E02005710  2011 super output areas - middle layer
# 2  2011      E02005710  2011 super output areas - middle layer
# 3  2011      E02005710  2011 super output areas - middle layer
# 4  2011      E02005710  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                CELL_NAME  OBS_VALUE
# 0                 297              Good health          0
# 1                 297              Fair health          0
# 2                 297               Bad health          0
# 3                 297          Very bad health          0
# 4                 297  Provides no unpaid care          0
# chunk 1 saved in ./data/raw/api/c2011/c2011ks301ew_01.csv
# trying records 50000 - 75000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=50000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02001728  2011 super output areas - middle layer
# 1  2011      E02001728  2011 super output areas - middle layer
# 2  2011      E02001728  2011 super output areas - middle layer
# 3  2011      E02001728  2011 super output areas - middle layer
# 4  2011      E02001728  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                          CELL_NAME  \
# 0                 297  All categories: Long-term health problem or di...
# 1                 297                Day-to-day activities limited a lot
# 2                 297             Day-to-day activities limited a little
# 3                 297                  Day-to-day activities not limited
# 4                 297  Day-to-day activities limited a lot: Age 16 to 64
#
#    OBS_VALUE
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# chunk 2 saved in ./data/raw/api/c2011/c2011ks301ew_02.csv
# trying records 75000 - 100000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=75000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02002635  2011 super output areas - middle layer
# 1  2011      E02002635  2011 super output areas - middle layer
# 2  2011      E02002635  2011 super output areas - middle layer
# 3  2011      E02002635  2011 super output areas - middle layer
# 4  2011      E02002635  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                CELL_NAME  OBS_VALUE
# 0                 297              Good health          0
# 1                 297              Fair health          0
# 2                 297               Bad health          0
# 3                 297          Very bad health          0
# 4                 297  Provides no unpaid care          0
# chunk 3 saved in ./data/raw/api/c2011/c2011ks301ew_03.csv
# trying records 100000 - 125000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=100000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02002579  2011 super output areas - middle layer
# 1  2011      E02002579  2011 super output areas - middle layer
# 2  2011      E02002579  2011 super output areas - middle layer
# 3  2011      E02002579  2011 super output areas - middle layer
# 4  2011      E02002579  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                          CELL_NAME  \
# 0                 297  All categories: Long-term health problem or di...
# 1                 297                Day-to-day activities limited a lot
# 2                 297             Day-to-day activities limited a little
# 3                 297                  Day-to-day activities not limited
# 4                 297  Day-to-day activities limited a lot: Age 16 to 64
#
#    OBS_VALUE
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# chunk 4 saved in ./data/raw/api/c2011/c2011ks301ew_04.csv
# trying records 125000 - 150000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=125000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02001004  2011 super output areas - middle layer
# 1  2011      E02001004  2011 super output areas - middle layer
# 2  2011      E02001004  2011 super output areas - middle layer
# 3  2011      E02001004  2011 super output areas - middle layer
# 4  2011      E02001004  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                CELL_NAME  OBS_VALUE
# 0                 297              Good health          0
# 1                 297              Fair health          0
# 2                 297               Bad health          0
# 3                 297          Very bad health          0
# 4                 297  Provides no unpaid care          0
# chunk 5 saved in ./data/raw/api/c2011/c2011ks301ew_05.csv
# trying records 150000 - 175000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=150000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02001123  2011 super output areas - middle layer
# 1  2011      E02001123  2011 super output areas - middle layer
# 2  2011      E02001123  2011 super output areas - middle layer
# 3  2011      E02001123  2011 super output areas - middle layer
# 4  2011      E02001123  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                          CELL_NAME  \
# 0                 297  All categories: Long-term health problem or di...
# 1                 297                Day-to-day activities limited a lot
# 2                 297             Day-to-day activities limited a little
# 3                 297                  Day-to-day activities not limited
# 4                 297  Day-to-day activities limited a lot: Age 16 to 64
#
#    OBS_VALUE
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# chunk 6 saved in ./data/raw/api/c2011/c2011ks301ew_06.csv
# trying records 175000 - 200000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=175000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02001242  2011 super output areas - middle layer
# 1  2011      E02001242  2011 super output areas - middle layer
# 2  2011      E02001242  2011 super output areas - middle layer
# 3  2011      E02001242  2011 super output areas - middle layer
# 4  2011      E02001242  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                CELL_NAME  OBS_VALUE
# 0                 297              Good health          0
# 1                 297              Fair health          0
# 2                 297               Bad health          0
# 3                 297          Very bad health          0
# 4                 297  Provides no unpaid care          0
# chunk 7 saved in ./data/raw/api/c2011/c2011ks301ew_07.csv
# trying records 200000 - 225000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=200000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02005212  2011 super output areas - middle layer
# 1  2011      E02005212  2011 super output areas - middle layer
# 2  2011      E02005212  2011 super output areas - middle layer
# 3  2011      E02005212  2011 super output areas - middle layer
# 4  2011      E02005212  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                          CELL_NAME  \
# 0                 297  All categories: Long-term health problem or di...
# 1                 297                Day-to-day activities limited a lot
# 2                 297             Day-to-day activities limited a little
# 3                 297                  Day-to-day activities not limited
# 4                 297  Day-to-day activities limited a lot: Age 16 to 64
#
#    OBS_VALUE
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# chunk 8 saved in ./data/raw/api/c2011/c2011ks301ew_08.csv
# trying records 225000 - 250000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=225000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02001328  2011 super output areas - middle layer
# 1  2011      E02001328  2011 super output areas - middle layer
# 2  2011      E02001328  2011 super output areas - middle layer
# 3  2011      E02001328  2011 super output areas - middle layer
# 4  2011      E02001328  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                CELL_NAME  OBS_VALUE
# 0                 297              Good health          0
# 1                 297              Fair health          0
# 2                 297               Bad health          0
# 3                 297          Very bad health          0
# 4                 297  Provides no unpaid care          0
# chunk 9 saved in ./data/raw/api/c2011/c2011ks301ew_09.csv
# trying records 250000 - 275000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=250000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02001408  2011 super output areas - middle layer
# 1  2011      E02001408  2011 super output areas - middle layer
# 2  2011      E02001408  2011 super output areas - middle layer
# 3  2011      E02001408  2011 super output areas - middle layer
# 4  2011      E02001408  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                          CELL_NAME  \
# 0                 297  All categories: Long-term health problem or di...
# 1                 297                Day-to-day activities limited a lot
# 2                 297             Day-to-day activities limited a little
# 3                 297                  Day-to-day activities not limited
# 4                 297  Day-to-day activities limited a lot: Age 16 to 64
#
#    OBS_VALUE
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# chunk 10 saved in ./data/raw/api/c2011/c2011ks301ew_10.csv
# trying records 275000 - 300000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=275000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02002667  2011 super output areas - middle layer
# 1  2011      E02002667  2011 super output areas - middle layer
# 2  2011      E02002667  2011 super output areas - middle layer
# 3  2011      E02002667  2011 super output areas - middle layer
# 4  2011      E02002667  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                CELL_NAME  OBS_VALUE
# 0                 297              Good health          0
# 1                 297              Fair health          0
# 2                 297               Bad health          0
# 3                 297          Very bad health          0
# 4                 297  Provides no unpaid care          0
# chunk 11 saved in ./data/raw/api/c2011/c2011ks301ew_11.csv
# trying records 300000 - 325000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=300000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02005775  2011 super output areas - middle layer
# 1  2011      E02005775  2011 super output areas - middle layer
# 2  2011      E02005775  2011 super output areas - middle layer
# 3  2011      E02005775  2011 super output areas - middle layer
# 4  2011      E02005775  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                          CELL_NAME  \
# 0                 297  All categories: Long-term health problem or di...
# 1                 297                Day-to-day activities limited a lot
# 2                 297             Day-to-day activities limited a little
# 3                 297                  Day-to-day activities not limited
# 4                 297  Day-to-day activities limited a lot: Age 16 to 64
#
#    OBS_VALUE
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# chunk 12 saved in ./data/raw/api/c2011/c2011ks301ew_12.csv
# trying records 325000 - 350000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=325000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02001586  2011 super output areas - middle layer
# 1  2011      E02001586  2011 super output areas - middle layer
# 2  2011      E02001586  2011 super output areas - middle layer
# 3  2011      E02001586  2011 super output areas - middle layer
# 4  2011      E02001586  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                CELL_NAME  OBS_VALUE
# 0                 297              Good health          0
# 1                 297              Fair health          0
# 2                 297               Bad health          0
# 3                 297          Very bad health          0
# 4                 297  Provides no unpaid care          0
# chunk 13 saved in ./data/raw/api/c2011/c2011ks301ew_13.csv
# trying records 350000 - 375000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=350000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02002208  2011 super output areas - middle layer
# 1  2011      E02002208  2011 super output areas - middle layer
# 2  2011      E02002208  2011 super output areas - middle layer
# 3  2011      E02002208  2011 super output areas - middle layer
# 4  2011      E02002208  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                          CELL_NAME  \
# 0                 297  All categories: Long-term health problem or di...
# 1                 297                Day-to-day activities limited a lot
# 2                 297             Day-to-day activities limited a little
# 3                 297                  Day-to-day activities not limited
# 4                 297  Day-to-day activities limited a lot: Age 16 to 64
#
#    OBS_VALUE
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# chunk 14 saved in ./data/raw/api/c2011/c2011ks301ew_14.csv
# trying records 375000 - 400000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=375000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02002328  2011 super output areas - middle layer
# 1  2011      E02002328  2011 super output areas - middle layer
# 2  2011      E02002328  2011 super output areas - middle layer
# 3  2011      E02002328  2011 super output areas - middle layer
# 4  2011      E02002328  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                CELL_NAME  OBS_VALUE
# 0                 297              Good health          0
# 1                 297              Fair health          0
# 2                 297               Bad health          0
# 3                 297          Very bad health          0
# 4                 297  Provides no unpaid care          0
# chunk 15 saved in ./data/raw/api/c2011/c2011ks301ew_15.csv
# trying records 400000 - 425000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=400000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02002450  2011 super output areas - middle layer
# 1  2011      E02002450  2011 super output areas - middle layer
# 2  2011      E02002450  2011 super output areas - middle layer
# 3  2011      E02002450  2011 super output areas - middle layer
# 4  2011      E02002450  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                          CELL_NAME  \
# 0                 297  All categories: Long-term health problem or di...
# 1                 297                Day-to-day activities limited a lot
# 2                 297             Day-to-day activities limited a little
# 3                 297                  Day-to-day activities not limited
# 4                 297  Day-to-day activities limited a lot: Age 16 to 64
#
#    OBS_VALUE
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# chunk 16 saved in ./data/raw/api/c2011/c2011ks301ew_16.csv
# trying records 425000 - 450000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=425000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02002888  2011 super output areas - middle layer
# 1  2011      E02002888  2011 super output areas - middle layer
# 2  2011      E02002888  2011 super output areas - middle layer
# 3  2011      E02002888  2011 super output areas - middle layer
# 4  2011      E02002888  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                CELL_NAME  OBS_VALUE
# 0                 297              Good health          0
# 1                 297              Fair health          0
# 2                 297               Bad health          0
# 3                 297          Very bad health          0
# 4                 297  Provides no unpaid care          0
# chunk 17 saved in ./data/raw/api/c2011/c2011ks301ew_17.csv
# trying records 450000 - 475000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=450000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02004126  2011 super output areas - middle layer
# 1  2011      E02004126  2011 super output areas - middle layer
# 2  2011      E02004126  2011 super output areas - middle layer
# 3  2011      E02004126  2011 super output areas - middle layer
# 4  2011      E02004126  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                          CELL_NAME  \
# 0                 297  All categories: Long-term health problem or di...
# 1                 297                Day-to-day activities limited a lot
# 2                 297             Day-to-day activities limited a little
# 3                 297                  Day-to-day activities not limited
# 4                 297  Day-to-day activities limited a lot: Age 16 to 64
#
#    OBS_VALUE
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# chunk 18 saved in ./data/raw/api/c2011/c2011ks301ew_18.csv
# trying records 475000 - 500000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=475000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02005449  2011 super output areas - middle layer
# 1  2011      E02005449  2011 super output areas - middle layer
# 2  2011      E02005449  2011 super output areas - middle layer
# 3  2011      E02005449  2011 super output areas - middle layer
# 4  2011      E02005449  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                CELL_NAME  OBS_VALUE
# 0                 297              Good health          0
# 1                 297              Fair health          0
# 2                 297               Bad health          0
# 3                 297          Very bad health          0
# 4                 297  Provides no unpaid care          0
# chunk 19 saved in ./data/raw/api/c2011/c2011ks301ew_19.csv
# trying records 500000 - 525000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=500000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02005676  2011 super output areas - middle layer
# 1  2011      E02005676  2011 super output areas - middle layer
# 2  2011      E02005676  2011 super output areas - middle layer
# 3  2011      E02005676  2011 super output areas - middle layer
# 4  2011      E02005676  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                          CELL_NAME  \
# 0                 297  All categories: Long-term health problem or di...
# 1                 297                Day-to-day activities limited a lot
# 2                 297             Day-to-day activities limited a little
# 3                 297                  Day-to-day activities not limited
# 4                 297  Day-to-day activities limited a lot: Age 16 to 64
#
#    OBS_VALUE
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# chunk 20 saved in ./data/raw/api/c2011/c2011ks301ew_20.csv
# trying records 525000 - 550000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=525000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02005916  2011 super output areas - middle layer
# 1  2011      E02005916  2011 super output areas - middle layer
# 2  2011      E02005916  2011 super output areas - middle layer
# 3  2011      E02005916  2011 super output areas - middle layer
# 4  2011      E02005916  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                CELL_NAME  OBS_VALUE
# 0                 297              Good health       2415
# 1                 297              Fair health        912
# 2                 297               Bad health        241
# 3                 297          Very bad health         94
# 4                 297  Provides no unpaid care       6498
# chunk 21 saved in ./data/raw/api/c2011/c2011ks301ew_21.csv
# trying records 550000 - 575000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=550000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02002947  2011 super output areas - middle layer
# 1  2011      E02002947  2011 super output areas - middle layer
# 2  2011      E02002947  2011 super output areas - middle layer
# 3  2011      E02002947  2011 super output areas - middle layer
# 4  2011      E02002947  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                          CELL_NAME  \
# 0                 297  All categories: Long-term health problem or di...
# 1                 297                Day-to-day activities limited a lot
# 2                 297             Day-to-day activities limited a little
# 3                 297                  Day-to-day activities not limited
# 4                 297  Day-to-day activities limited a lot: Age 16 to 64
#
#    OBS_VALUE
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# chunk 22 saved in ./data/raw/api/c2011/c2011ks301ew_22.csv
# trying records 575000 - 600000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=575000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02006475  2011 super output areas - middle layer
# 1  2011      E02006475  2011 super output areas - middle layer
# 2  2011      E02006475  2011 super output areas - middle layer
# 3  2011      E02006475  2011 super output areas - middle layer
# 4  2011      E02006475  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                CELL_NAME  OBS_VALUE
# 0                 297              Good health          0
# 1                 297              Fair health          0
# 2                 297               Bad health          0
# 3                 297          Very bad health          0
# 4                 297  Provides no unpaid care          0
# chunk 23 saved in ./data/raw/api/c2011/c2011ks301ew_23.csv
# trying records 600000 - 625000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=600000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02001892  2011 super output areas - middle layer
# 1  2011      E02001892  2011 super output areas - middle layer
# 2  2011      E02001892  2011 super output areas - middle layer
# 3  2011      E02001892  2011 super output areas - middle layer
# 4  2011      E02001892  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                          CELL_NAME  \
# 0                 297  All categories: Long-term health problem or di...
# 1                 297                Day-to-day activities limited a lot
# 2                 297             Day-to-day activities limited a little
# 3                 297                  Day-to-day activities not limited
# 4                 297  Day-to-day activities limited a lot: Age 16 to 64
#
#    OBS_VALUE
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# chunk 24 saved in ./data/raw/api/c2011/c2011ks301ew_24.csv
# trying records 625000 - 650000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=625000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02002007  2011 super output areas - middle layer
# 1  2011      E02002007  2011 super output areas - middle layer
# 2  2011      E02002007  2011 super output areas - middle layer
# 3  2011      E02002007  2011 super output areas - middle layer
# 4  2011      E02002007  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                CELL_NAME  OBS_VALUE
# 0                 297              Good health          0
# 1                 297              Fair health          0
# 2                 297               Bad health          0
# 3                 297          Very bad health          0
# 4                 297  Provides no unpaid care          0
# chunk 25 saved in ./data/raw/api/c2011/c2011ks301ew_25.csv
# trying records 650000 - 675000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=650000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02002128  2011 super output areas - middle layer
# 1  2011      E02002128  2011 super output areas - middle layer
# 2  2011      E02002128  2011 super output areas - middle layer
# 3  2011      E02002128  2011 super output areas - middle layer
# 4  2011      E02002128  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                          CELL_NAME  \
# 0                 297  All categories: Long-term health problem or di...
# 1                 297                Day-to-day activities limited a lot
# 2                 297             Day-to-day activities limited a little
# 3                 297                  Day-to-day activities not limited
# 4                 297  Day-to-day activities limited a lot: Age 16 to 64
#
#    OBS_VALUE
# 0       5547
# 1        602
# 2        632
# 3       4313
# 4        252
# chunk 26 saved in ./data/raw/api/c2011/c2011ks301ew_26.csv
# trying records 675000 - 700000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=675000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02006762  2011 super output areas - middle layer
# 1  2011      E02006762  2011 super output areas - middle layer
# 2  2011      E02006762  2011 super output areas - middle layer
# 3  2011      E02006762  2011 super output areas - middle layer
# 4  2011      E02006762  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                CELL_NAME  OBS_VALUE
# 0                 297              Good health          0
# 1                 297              Fair health          0
# 2                 297               Bad health          0
# 3                 297          Very bad health          0
# 4                 297  Provides no unpaid care          0
# chunk 27 saved in ./data/raw/api/c2011/c2011ks301ew_27.csv
# trying records 700000 - 725000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=700000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02003284  2011 super output areas - middle layer
# 1  2011      E02003284  2011 super output areas - middle layer
# 2  2011      E02003284  2011 super output areas - middle layer
# 3  2011      E02003284  2011 super output areas - middle layer
# 4  2011      E02003284  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                          CELL_NAME  \
# 0                 297  All categories: Long-term health problem or di...
# 1                 297                Day-to-day activities limited a lot
# 2                 297             Day-to-day activities limited a little
# 3                 297                  Day-to-day activities not limited
# 4                 297  Day-to-day activities limited a lot: Age 16 to 64
#
#    OBS_VALUE
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# chunk 28 saved in ./data/raw/api/c2011/c2011ks301ew_28.csv
# trying records 725000 - 750000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=725000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02004437  2011 super output areas - middle layer
# 1  2011      E02004437  2011 super output areas - middle layer
# 2  2011      E02004437  2011 super output areas - middle layer
# 3  2011      E02004437  2011 super output areas - middle layer
# 4  2011      E02004437  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                CELL_NAME  OBS_VALUE
# 0                 297              Good health          0
# 1                 297              Fair health          0
# 2                 297               Bad health          0
# 3                 297          Very bad health          0
# 4                 297  Provides no unpaid care          0
# chunk 29 saved in ./data/raw/api/c2011/c2011ks301ew_29.csv
# trying records 750000 - 775000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=750000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02004558  2011 super output areas - middle layer
# 1  2011      E02004558  2011 super output areas - middle layer
# 2  2011      E02004558  2011 super output areas - middle layer
# 3  2011      E02004558  2011 super output areas - middle layer
# 4  2011      E02004558  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                          CELL_NAME  \
# 0                 297  All categories: Long-term health problem or di...
# 1                 297                Day-to-day activities limited a lot
# 2                 297             Day-to-day activities limited a little
# 3                 297                  Day-to-day activities not limited
# 4                 297  Day-to-day activities limited a lot: Age 16 to 64
#
#    OBS_VALUE
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# chunk 30 saved in ./data/raw/api/c2011/c2011ks301ew_30.csv
# trying records 775000 - 800000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=775000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02004921  2011 super output areas - middle layer
# 1  2011      E02004921  2011 super output areas - middle layer
# 2  2011      E02004921  2011 super output areas - middle layer
# 3  2011      E02004921  2011 super output areas - middle layer
# 4  2011      E02004921  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                CELL_NAME  OBS_VALUE
# 0                 297              Good health          0
# 1                 297              Fair health          0
# 2                 297               Bad health          0
# 3                 297          Very bad health          0
# 4                 297  Provides no unpaid care          0
# chunk 31 saved in ./data/raw/api/c2011/c2011ks301ew_31.csv
# trying records 800000 - 825000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=800000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02005549  2011 super output areas - middle layer
# 1  2011      E02005549  2011 super output areas - middle layer
# 2  2011      E02005549  2011 super output areas - middle layer
# 3  2011      E02005549  2011 super output areas - middle layer
# 4  2011      E02005549  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                          CELL_NAME  \
# 0                 297  All categories: Long-term health problem or di...
# 1                 297                Day-to-day activities limited a lot
# 2                 297             Day-to-day activities limited a little
# 3                 297                  Day-to-day activities not limited
# 4                 297  Day-to-day activities limited a lot: Age 16 to 64
#
#    OBS_VALUE
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# chunk 32 saved in ./data/raw/api/c2011/c2011ks301ew_32.csv
# trying records 825000 - 850000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=825000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02006283  2011 super output areas - middle layer
# 1  2011      E02006283  2011 super output areas - middle layer
# 2  2011      E02006283  2011 super output areas - middle layer
# 3  2011      E02006283  2011 super output areas - middle layer
# 4  2011      E02006283  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                CELL_NAME  OBS_VALUE
# 0                 297              Good health          0
# 1                 297              Fair health          0
# 2                 297               Bad health          0
# 3                 297          Very bad health          0
# 4                 297  Provides no unpaid care          0
# chunk 33 saved in ./data/raw/api/c2011/c2011ks301ew_33.csv
# trying records 850000 - 875000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=850000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02000402  2011 super output areas - middle layer
# 1  2011      E02000402  2011 super output areas - middle layer
# 2  2011      E02000402  2011 super output areas - middle layer
# 3  2011      E02000402  2011 super output areas - middle layer
# 4  2011      E02000402  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                          CELL_NAME  \
# 0                 297  All categories: Long-term health problem or di...
# 1                 297                Day-to-day activities limited a lot
# 2                 297             Day-to-day activities limited a little
# 3                 297                  Day-to-day activities not limited
# 4                 297  Day-to-day activities limited a lot: Age 16 to 64
#
#    OBS_VALUE
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# chunk 34 saved in ./data/raw/api/c2011/c2011ks301ew_34.csv
# trying records 875000 - 900000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=875000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02000663  2011 super output areas - middle layer
# 1  2011      E02000663  2011 super output areas - middle layer
# 2  2011      E02000663  2011 super output areas - middle layer
# 3  2011      E02000663  2011 super output areas - middle layer
# 4  2011      E02000663  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                CELL_NAME  OBS_VALUE
# 0                 297              Good health          0
# 1                 297              Fair health          0
# 2                 297               Bad health          0
# 3                 297          Very bad health          0
# 4                 297  Provides no unpaid care          0
# chunk 35 saved in ./data/raw/api/c2011/c2011ks301ew_35.csv
# trying records 900000 - 925000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=900000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02000887  2011 super output areas - middle layer
# 1  2011      E02000887  2011 super output areas - middle layer
# 2  2011      E02000887  2011 super output areas - middle layer
# 3  2011      E02000887  2011 super output areas - middle layer
# 4  2011      E02000887  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                          CELL_NAME  \
# 0                 297  All categories: Long-term health problem or di...
# 1                 297                Day-to-day activities limited a lot
# 2                 297             Day-to-day activities limited a little
# 3                 297                  Day-to-day activities not limited
# 4                 297  Day-to-day activities limited a lot: Age 16 to 64
#
#    OBS_VALUE
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# chunk 36 saved in ./data/raw/api/c2011/c2011ks301ew_36.csv
# trying records 925000 - 950000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=925000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02000053  2011 super output areas - middle layer
# 1  2011      E02000053  2011 super output areas - middle layer
# 2  2011      E02000053  2011 super output areas - middle layer
# 3  2011      E02000053  2011 super output areas - middle layer
# 4  2011      E02000053  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                CELL_NAME  OBS_VALUE
# 0                 297              Good health          0
# 1                 297              Fair health          0
# 2                 297               Bad health          0
# 3                 297          Very bad health          0
# 4                 297  Provides no unpaid care          0
# chunk 37 saved in ./data/raw/api/c2011/c2011ks301ew_37.csv
# trying records 950000 - 975000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=950000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02000201  2011 super output areas - middle layer
# 1  2011      E02000201  2011 super output areas - middle layer
# 2  2011      E02000201  2011 super output areas - middle layer
# 3  2011      E02000201  2011 super output areas - middle layer
# 4  2011      E02000201  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                          CELL_NAME  \
# 0                 297  All categories: Long-term health problem or di...
# 1                 297                Day-to-day activities limited a lot
# 2                 297             Day-to-day activities limited a little
# 3                 297                  Day-to-day activities not limited
# 4                 297  Day-to-day activities limited a lot: Age 16 to 64
#
#    OBS_VALUE
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# chunk 38 saved in ./data/raw/api/c2011/c2011ks301ew_38.csv
# trying records 975000 - 1000000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=975000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02000321  2011 super output areas - middle layer
# 1  2011      E02000321  2011 super output areas - middle layer
# 2  2011      E02000321  2011 super output areas - middle layer
# 3  2011      E02000321  2011 super output areas - middle layer
# 4  2011      E02000321  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                CELL_NAME  OBS_VALUE
# 0                 297              Good health          0
# 1                 297              Fair health          0
# 2                 297               Bad health          0
# 3                 297          Very bad health          0
# 4                 297  Provides no unpaid care          0
# chunk 39 saved in ./data/raw/api/c2011/c2011ks301ew_39.csv
# trying records 1000000 - 1025000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=1000000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02000530  2011 super output areas - middle layer
# 1  2011      E02000530  2011 super output areas - middle layer
# 2  2011      E02000530  2011 super output areas - middle layer
# 3  2011      E02000530  2011 super output areas - middle layer
# 4  2011      E02000530  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                          CELL_NAME  \
# 0                 297  All categories: Long-term health problem or di...
# 1                 297                Day-to-day activities limited a lot
# 2                 297             Day-to-day activities limited a little
# 3                 297                  Day-to-day activities not limited
# 4                 297  Day-to-day activities limited a lot: Age 16 to 64
#
#    OBS_VALUE
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# chunk 40 saved in ./data/raw/api/c2011/c2011ks301ew_40.csv
# trying records 1025000 - 1050000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_617_1.data.csv?geography=TYPE297&measures=20100&select=date,geography_code,geography_type,geography_typecode,cell_name,obs_value&recordlimit=25000&recordoffset=1025000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2011      E02000803  2011 super output areas - middle layer
# 1  2011      E02000803  2011 super output areas - middle layer
# 2  2011      E02000803  2011 super output areas - middle layer
# 3  2011      E02000803  2011 super output areas - middle layer
# 4  2011      E02000803  2011 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                CELL_NAME  OBS_VALUE
# ...
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:716, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     715 # open URLs
# --> 716 ioargs = _get_filepath_or_buffer(
#     717     path_or_buf,
#     718     encoding=encoding,
#     719     compression=compression,
#     720     mode=mode,
#     721     storage_options=storage_options,
#     722 )
#     724 handle = ioargs.filepath_or_buffer
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:368, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     367 req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 368 with urlopen(req_info) as req:
#     369     content_encoding = req.headers.get("Content-Encoding", None)
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:270, in urlopen(*args, **kwargs)
#     268 import urllib.request
# --> 270 return urllib.request.urlopen(*args, **kwargs)
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:557, in OpenerDirector.error(self, proto, *args)
#     556 args = (dict, proto, meth_name) + args
# --> 557 result = self._call_chain(*args)
#     558 if result:
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     495 func = getattr(handler, meth_name)
# --> 496 result = func(*args)
#     497 if result is not None:
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:749, in HTTPRedirectHandler.http_error_302(self, req, fp, code, msg, headers)
#     747 fp.close()
# --> 749 return self.parent.open(new, timeout=req.timeout)
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     495 func = getattr(handler, meth_name)
# --> 496 result = func(*args)
#     497 if result is not None:
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:1351, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1350 except OSError as err: # timeout error
# -> 1351     raise URLError(err)
#    1352 r = h.getresponse()
#
# URLError: <urlopen error [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond>
#
# During handling of the above exception, another exception occurred:
#
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1283, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1282 """Send a complete request to the server."""
# -> 1283 self._send_request(method, url, body, headers, encode_chunked)
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1329, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1328     body = _encode(body, 'body')
# -> 1329 self.endheaders(body, encode_chunked=encode_chunked)
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1278, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1277     raise CannotSendHeader()
# -> 1278 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1038, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1037 del self._buffer[:]
# -> 1038 self.send(msg)
#    1040 if message_body is not None:
#    1041
#    1042     # create a consistent interface to message_body
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\http\client.py:976, in HTTPConnection.send(self, data)
#     975 if self.auto_open:
# --> 976     self.connect()
#     977 else:
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1448, in HTTPSConnection.connect(self)
#    1446 "Connect to a host on a given (SSL) port."
# -> 1448 super().connect()
#    1450 if self._tunnel_host:
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\http\client.py:942, in HTTPConnection.connect(self)
#     941 sys.audit("http.client.connect", self, self.host, self.port)
# --> 942 self.sock = self._create_connection(
#     943     (self.host,self.port), self.timeout, self.source_address)
#     944 # Might fail in OSs that don't implement TCP_NODELAY
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\socket.py:851, in create_connection(address, timeout, source_address, all_errors)
#     850 if not all_errors:
# --> 851     raise exceptions[0]
#     852 raise ExceptionGroup("create_connection failed", exceptions)
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\socket.py:836, in create_connection(address, timeout, source_address, all_errors)
#     835     sock.bind(source_address)
# --> 836 sock.connect(sa)
#     837 # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[12], line 47
#      45 except:
#      46     time.sleep(60)
# ---> 47     batch_df = pd.read_csv(url)
#      49 display(batch_df.head())
#      51 if len(batch_df) == 0:
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:716, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     713     codecs.lookup_error(errors)
#     715 # open URLs
# --> 716 ioargs = _get_filepath_or_buffer(
#     717     path_or_buf,
#     718     encoding=encoding,
#     719     compression=compression,
#     720     mode=mode,
#     721     storage_options=storage_options,
#     722 )
#     724 handle = ioargs.filepath_or_buffer
#     725 handles: list[BaseBuffer]
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:368, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     366 # assuming storage_options is to be interpreted as headers
#     367 req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 368 with urlopen(req_info) as req:
#     369     content_encoding = req.headers.get("Content-Encoding", None)
#     370     if content_encoding == "gzip":
#     371         # Override compression based on Content-Encoding header
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:270, in urlopen(*args, **kwargs)
#     264 """
#     265 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     266 the stdlib.
#     267 """
#     268 import urllib.request
# --> 270 return urllib.request.urlopen(*args, **kwargs)
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:557, in OpenerDirector.error(self, proto, *args)
#     555     http_err = 0
#     556 args = (dict, proto, meth_name) + args
# --> 557 result = self._call_chain(*args)
#     558 if result:
#     559     return result
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:749, in HTTPRedirectHandler.http_error_302(self, req, fp, code, msg, headers)
#     746 fp.read()
#     747 fp.close()
# --> 749 return self.parent.open(new, timeout=req.timeout)
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File c:\Users\ysabe\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:1351, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1348         h.request(req.get_method(), req.selector, req.data, headers,
#    1349                   encode_chunked=req.has_header('Transfer-encoding'))
#    1350     except OSError as err: # timeout error
# -> 1351         raise URLError(err)
#    1352     r = h.getresponse()
#    1353 except:
#
# URLError: <urlopen error [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond>
