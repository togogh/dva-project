# %%
import requests
import json
import pandas as pd
import time

# %%
root_url = 'http://www.nomisweb.co.uk'

# api_url = '/api/v01/dataset/NM_1_1/geography.def.sdmx.json' # list all possible geography sets
api_url = '/api/v01/dataset/NM_1_1/geography/2092957697.def.sdmx.json' # list of all geography sets in UK
# api_url = '/api/v01/dataset/NM_1_1/geography/2092957697TYPE441.def.sdmx.json' # major towns and cities within United Kingdom

url = root_url + api_url

response = requests.get(url)
json.loads(response.text)
# Out:
# {'structure': {'codelists': {'codelist': [{'agencyid': 'NOMIS',
#      'id': 'CL_1_1_GEOGRAPHY',
#      'code': [{'annotations': {'annotation': [{'annotationtext': 'countries',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 499, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'K02000001', 'annotationtitle': 'GeogCode'}]},
#        'description': {'value': 'United Kingdom', 'lang': 'en'},
#        'value': 2092957697},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 1, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '1991 frozen wards',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 11330, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '1991 frozen wards within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE1'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 8, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'parliamentary constituencies 1983 revision',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 2498, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'parliamentary constituencies 1983 revision within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE8'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 18, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'tecs / lecs as of 1989',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 394, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'tecs / lecs as of 1989 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE18'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 27, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'english learning partnerships',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 101, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'english learning partnerships within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE27'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 33, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '1981 frozen wards',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 11083, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '1981 frozen wards within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE33'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 45, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'parliamentary constituencies 1983 revision',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 651, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'parliamentary constituencies 1983 revision within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE45'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 61, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'postcode towns', 'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 466, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'postcode towns within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE61'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 62, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'postcode districts',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 11451, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'postcode districts within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE62'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 63, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'postcode sectors', 'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 47389, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'postcode sectors within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE63'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 65, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'jobcentre plus offices',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 3795, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'jobcentre plus offices within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE65'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 66, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'jobcentre plus districts prior to April 2011',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 192, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'jobcentre plus districts prior to April 2011 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE66'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 83, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'jobcentre plus group as of April 2019',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 44, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'jobcentre plus group as of April 2019 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE83'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 84, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'jobcentre plus district as of April 2019',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 144, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'jobcentre plus district as of April 2019 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE84'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 86, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'live jobcentre plus offices',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 2708, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'live jobcentre plus offices within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE86'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 236, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2011 census frozen wards',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 9481, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2011 census frozen wards within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE236'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 241, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'scottish parliamentary regions',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 16, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'scottish parliamentary regions within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE241'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 267, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'built-up areas including subdivisions',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 6622, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'built-up areas including subdivisions within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE267'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 269, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'built-up areas', 'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 5493, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'built-up areas within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE269'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 297, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2011 super output areas - middle layer',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 7201, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2011 super output areas - middle layer within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE297'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 304, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2001 super output areas - lower layer',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 34378, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2001 super output areas - lower layer within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE304'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 305, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2001 super output areas - middle layer',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 7194, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2001 super output areas - middle layer within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE305'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 307, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2001 scottish data zones',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 6505, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2001 scottish data zones within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE307'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 308, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2001 northern ireland - super output areas',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 890, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2001 northern ireland - super output areas within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE308'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 312, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2003 CAS wards', 'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 10654, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2003 CAS wards within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE312'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 317, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2001 scottish intermediate zones',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 1235, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2001 scottish intermediate zones within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE317'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 324, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2005 statistical wards',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 35412, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2005 statistical wards within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE324'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 331, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'travel to work areas 2001-based',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 243, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'travel to work areas 2001-based within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE331'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 337, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2009 statistical wards',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 8483, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2009 statistical wards within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE337'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 338, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'output area classification group',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 63, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'output area classification group within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE338'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 339, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'output area classification sub group',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 156, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'output area classification sub group within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE339'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 340, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'output area classification super group',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 21, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'output area classification super group within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE340'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 347, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'scottish index of multiple deprivation 2009 - deciles',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 30, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'scottish index of multiple deprivation 2009 - deciles within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE347'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 349, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'welsh index of multiple deprivation 2008 - deciles',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 40, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'welsh index of multiple deprivation 2008 - deciles within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE349'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 351, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'northern ireland index of multiple deprivation 2010 - deciles',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 10, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'northern ireland index of multiple deprivation 2010 - deciles within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE351'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 355, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'welsh index of multiple deprivation 2011 - deciles',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 40, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'welsh index of multiple deprivation 2011 - deciles within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE355'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 362, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'scottish index of multiple deprivation 2012 - deciles',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 30, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'scottish index of multiple deprivation 2012 - deciles within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE362'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 395, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2019 electoral ward',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 8407, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2019 electoral ward within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE395'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 396, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2018 electoral ward',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 8634, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2018 electoral ward within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE396'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 397, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2017 electoral ward',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 8651, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2017 electoral ward within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE397'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 399, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2015 electoral ward',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 9298, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2015 electoral ward within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE399'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 400, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': '2014 electoral ward',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 9438, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': '2014 electoral ward within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE400'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 431, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'local authorities: county / unitary (as of April 2021)',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 217, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'local authorities: county / unitary (as of April 2021) within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE431'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 432, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'local authorities: district / unitary (as of April 2021)',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 374, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'local authorities: district / unitary (as of April 2021) within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE432'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 433, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'local authorities: county / unitary (as of April 2019)',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 216, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'local authorities: county / unitary (as of April 2019) within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE433'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 434, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'local authorities: district / unitary (as of April 2019)',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 382, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'local authorities: district / unitary (as of April 2019) within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE434'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 437, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'nuts 2016 level 3',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 179, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'nuts 2016 level 3 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE437'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 438, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'nuts 2016 level 2',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 41, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'nuts 2016 level 2 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE438'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 439, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'nuts 2016 level 1',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 12, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'nuts 2016 level 1 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE439'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 440, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'local administrative units 2016 level 1',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 400, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'local administrative units 2016 level 1 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE440'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 112, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'major towns and cities within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE441'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 442, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'combined authorities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 10, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'combined authorities within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE442'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 444, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'travel to work areas 2001-based',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 243, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'travel to work areas 2001-based within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE444'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 446, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'local authorities: county / unitary (as of April 2015)',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 217, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'local authorities: county / unitary (as of April 2015) within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE446'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 447, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'travel to work areas 2011-based',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 228, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'travel to work areas 2011-based within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE447'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 448, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'local authorities: district / unitary (as of April 2015)',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 391, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'local authorities: district / unitary (as of April 2015) within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE448'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 449, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'nuts 2013 level 3',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 173, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'nuts 2013 level 3 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE449'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 450, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'nuts 2013 level 2',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 40, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'nuts 2013 level 2 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE450'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 451, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'nuts 2013 level 1',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 12, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'nuts 2013 level 1 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE451'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 452, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'Northern Ireland local government districts (as of 2014)',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 11, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'Northern Ireland local government districts (as of 2014) within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE452'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 454, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'nuts 2010 level 1',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 12, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'nuts 2010 level 1 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE454'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 455, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'nuts 2010 level 2',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 37, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'nuts 2010 level 2 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE455'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 456, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'nuts 2010 level 3',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 139, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'nuts 2010 level 3 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE456'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 458, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'scottish parliamentary constituencies 2011 revision',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 73, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'scottish parliamentary constituencies 2011 revision within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE458'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 459, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'local enterprise partnerships (as of April 2021)',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 38, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'local enterprise partnerships (as of April 2021) within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE459'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 460, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'parliamentary constituencies 2010',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 650, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'parliamentary constituencies 2010 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE460'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 462, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'former metropolitan counties',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 8, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'former metropolitan counties within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE462'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 463, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'local authorities: county / unitary (prior to April 2015)',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 232, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'local authorities: county / unitary (prior to April 2015) within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE463'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 464, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'local authorities: district / unitary (prior to April 2015)',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 406, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'local authorities: district / unitary (prior to April 2015) within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE464'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 466, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'national assembly for wales constituencies',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 40, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'national assembly for wales constituencies within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE466'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 467, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'scottish local enterprise companies',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 21, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'scottish local enterprise companies within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE467'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 468, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'parliamentary constituencies 2005 revision',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 646, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'parliamentary constituencies 2005 revision within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE468'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 469, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'english counties', 'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 42, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'english counties within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE469'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 473, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'ELWAs', 'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 4, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'ELWAs within United Kingdom', 'lang': 'en'},
#        'value': '2092957697TYPE473'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 474, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'scottish local enterprise companies',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 22, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'scottish local enterprise companies within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE474'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 476, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'english local learning and skills councils',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 47, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'english local learning and skills councils within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE476'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 477, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'nuts 2003 level 1',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 12, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'nuts 2003 level 1 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE477'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 478, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'nuts 2003 level 2',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 37, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'nuts 2003 level 2 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE478'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 479, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'nuts 2003 level 3',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 133, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'nuts 2003 level 3 within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE479'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 480, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'regions', 'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 12, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'regions within United Kingdom', 'lang': 'en'},
#        'value': '2092957697TYPE480'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 481, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'travel to work areas 1984 revision',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 334, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'travel to work areas 1984 revision within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE481'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 482, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'pre-2009 local authorities: county / unitary',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 229, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'pre-2009 local authorities: county / unitary within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE482'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 483, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'new deal units of delivery',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 144, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'new deal units of delivery within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE483'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 484, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'parliamentary constituencies 1995 revision',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 659, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'parliamentary constituencies 1995 revision within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE484'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 486, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'pre-2009 local authorities: district / unitary',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 434, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'pre-2009 local authorities: district / unitary within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE486'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 487, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'unitary authority areas',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 167, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'unitary authority areas within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE487'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 488, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'travel to work areas 1998 revision',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 308, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'travel to work areas 1998 revision within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE488'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 489, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'tecs / lecs', 'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 98, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'tecs / lecs within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE489'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 490, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'government office regions tec / lec based',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 13, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'government office regions tec / lec based within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE490'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 491, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'government office regions (former inc. Merseyside)',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 13, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'government office regions (former inc. Merseyside) within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE491'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 492, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'standard statistical regions',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 12, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'standard statistical regions within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE492'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 496, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'pre-1996 local authority districts',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 485, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'pre-1996 local authority districts within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE496'},
#       {'annotations': {'annotation': [{'annotationtext': 'True',
#           'annotationtitle': 'IsAbstractCode'},
#          {'annotationtext': 498, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'pre-1996 counties / scottish regions',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 2092957697, 'annotationtitle': 'ParentCode'},
#          {'annotationtext': 66, 'annotationtitle': 'ChildCount'}]},
#        'description': {'value': 'pre-1996 counties / scottish regions within United Kingdom',
#         'lang': 'en'},
#        'value': '2092957697TYPE498'}],
#      'name': {'value': 'geography', 'lang': 'en'},
#      'uri': ''}]},
#   'header': {'id': 'NM_1_1',
#    'prepared': '2024-03-25T15:21:15Z',
#    'sender': {'contact': {'email': 'support@nomisweb.co.uk',
#      'name': 'Nomis',
#      'telephone': '+44(0) 191 3342680',
#      'uri': 'https://www.nomisweb.co.uk'},
#     'id': 'NOMIS'},
#    'test': 'false'},
#   'xmlns': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message',
#   'common': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common',
#   'structure': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure',
#   'xsi': 'http://www.w3.org/2001/XMLSchema-instance',
#   'schemalocation': 'http://sdmx.org/docs/2_0/SDMXMessage.xsd'}}

# %%
api_url = '/api/v01/dataset/NM_1_1/geography/2092957697TYPE441.def.sdmx.json' # major towns and cities within United Kingdom
url = root_url + api_url

response = requests.get(url)
json.loads(response.text)

cities_json = json.loads(response.text)
cities_json = cities_json['structure']['codelists']['codelist'][0]['code']
cities_list = []
for city in cities_json:
    geog_code = city['annotations']['annotation'][2]['annotationtext']
    name = city['description']['value']
    id = city['value']
    city_dict = {
        'id': id,
        'name': name,
        'geog_code': geog_code
    }
    cities_list.append(city_dict)
cities_df = pd.DataFrame(cities_list)
cities_df
# Out:
#              id           name  geog_code
# 0    1849688065       Barnsley  J01000001
# 1    1849688066       Basildon  J01000002
# 2    1849688067    Basingstoke  J01000003
# 3    1849688068           Bath  J01000004
# 4    1849688069        Bedford  J01000005
# ..          ...            ...        ...
# 107  1849688172         Woking  J01000108
# 108  1849688173  Wolverhampton  J01000109
# 109  1849688174      Worcester  J01000110
# 110  1849688175       Worthing  J01000111
# 111  1849688176           York  J01000112
#
# [112 rows x 3 columns]

# %%
c2011_lookup = pd.read_csv(r'data\raw\geoportal\Middle_Layer_Super_Output_Area_(2011)_to_Major_Towns_and_Cities_(December_2015)_Lookup_in_England_and_Wales.csv')
c2011_lookup = c2011_lookup.dropna(subset=['TCITY15NM'])
c2011_lookup
# Out:
#        MSOA11CD        MSOA11NM  TCITY15CD   TCITY15NM   FID
# 0     E02000053      Barnet 030  J01000055      London     1
# 1     E02000209     Croydon 016  J01000055      London     2
# 2     E02000054      Barnet 031  J01000055      London     3
# 3     E02000055      Barnet 032  J01000055      London     4
# 4     E02000056      Barnet 033  J01000055      London     5
# ...         ...             ...        ...         ...   ...
# 7196  E02003999    Carlisle 013  J01000021    Carlisle  7197
# 7197  E02005068   Maidstone 001  J01000022     Chatham  7198
# 7198  E02004497  Chelmsford 013  J01000023  Chelmsford  7199
# 7199  E02004493  Chelmsford 009  J01000023  Chelmsford  7200
# 7200  E02002792        York 021  J01000112        York  7201
#
# [3260 rows x 5 columns]

# %%
c2021_lookup = pd.read_csv(r'data\raw\geoportal\MSOA_(2011)_to_MSOA_(2021)_to_Local_Authority_District_(2022)_Lookup_for_England_and_Wales_(Version_2).csv')
c2021_lookup = c2021_lookup[['MSOA11CD', 'MSOA21CD']]
c2021_lookup = c2021_lookup.merge(c2011_lookup, on='MSOA11CD', how='inner')
c2021_lookup = c2021_lookup.drop('MSOA11CD', axis=1)
c2021_lookup = c2021_lookup.rename(columns={'MSOA11NM': 'MSOA21NM'})
c2021_lookup
# Out:
#        MSOA21CD       MSOA21NM  TCITY15CD TCITY15NM   FID
# 0     E02000308    Enfield 032  J01000055    London   336
# 1     E02000309    Enfield 033  J01000055    London   337
# 2     E02000311    Enfield 035  J01000055    London   338
# 3     E02000312    Enfield 036  J01000055    London    77
# 4     E02000313  Greenwich 001  J01000055    London    81
# ...         ...            ...        ...       ...   ...
# 3255  W02000193    Swansea 026  J01000098   Swansea  7002
# 3256  W02000194    Swansea 027  J01000098   Swansea  7047
# 3257  W02000196    Swansea 029  J01000098   Swansea  7055
# 3258  W02000198    Swansea 031  J01000098   Swansea  7063
# 3259  W02000423    Cardiff 049  J01000020   Cardiff  7178
#
# [3260 rows x 5 columns]

# %%
# api_url = '/api/v01/dataset/def.sdmx.json' # view all datasets
api_url = '/api/v01/dataset/def.sdmx.json?search=C2021TS*'
# api_url = '/api/v01/dataset/NM_2021_1/def.sdmx.json'


url = root_url + api_url

response = requests.get(url)
json.loads(response.text)
# Out:
# {'structure': {'header': {'id': 'none',
#    'prepared': '2024-03-25T15:21:21Z',
#    'sender': {'contact': {'email': 'support@nomisweb.co.uk',
#      'name': 'Nomis',
#      'telephone': '+44(0) 191 3342680',
#      'uri': 'https://www.nomisweb.co.uk'},
#     'id': 'NOMIS'},
#    'test': 'false'},
#   'keyfamilies': {'keyfamily': [{'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Age', 'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts007a', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents in England and Wales by five-year age bands. The estimates are as at Census Day, 21 March 2021',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2020_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2020_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2020_1_C2021_AGE_19', 'conceptref': 'C2021_AGE_19'},
#        {'codelist': 'CL_2020_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2020_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2020_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS007A - Age by five-year age bands', 'lang': 'en'},
#      'uri': 'Nm-2020d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Persons,Households', 'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts001', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents in England and Wales by whether they resided in households and communal establishments. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2021_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2021_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2021_1_C2021_RESTYPE_3',
#         'conceptref': 'C2021_RESTYPE_3'},
#        {'codelist': 'CL_2021_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2021_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2021_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS001 - Number of usual residents in households and communal establishments',
#       'lang': 'en'},
#      'uri': 'Nm-2021d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Married,Separated,Divorced,Widowed',
#         'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents aged 16 and over',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts002', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents aged 16 years and over in England and Wales by their legal partnership status. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2022_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2022_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2022_1_C2021_LPSTAT_12',
#         'conceptref': 'C2021_LPSTAT_12'},
#        {'codelist': 'CL_2022_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2022_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2022_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS002 - Legal partnership status', 'lang': 'en'},
#      'uri': 'Nm-2022d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Dependent child,Household,Household composition,Lone parent,Cohabiting couple family,Married or civil partnership couple,Single-family household,Same-sex civil partnership couple,Students,Schoolchildren',
#         'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Households', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All households',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts003', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify households in England and Wales by the relationships between household members (household composition). The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2023_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2023_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2023_1_C2021_HHCOMP_15',
#         'conceptref': 'C2021_HHCOMP_15'},
#        {'codelist': 'CL_2023_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2023_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2023_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS003 - Household composition', 'lang': 'en'},
#      'uri': 'Nm-2023d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Country of Birth,Usual Resident',
#         'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts004', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents in England and Wales by their country of birth. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2024_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2024_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2024_1_C2021_COB_12', 'conceptref': 'C2021_COB_12'},
#        {'codelist': 'CL_2024_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2024_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2024_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS004 - Country of birth', 'lang': 'en'},
#      'uri': 'Nm-2024d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Passports Held', 'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts005', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents in England and Wales by passports held. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2025_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2025_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2025_1_C2021_PASS_27', 'conceptref': 'C2021_PASS_27'},
#        {'codelist': 'CL_2025_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2025_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2025_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS005 - Passports held', 'lang': 'en'},
#      'uri': 'Nm-2025d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Population density', 'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts006', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents in England and Wales by population density (number of usual residents per square kilometre). The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2026_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2026_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2026_1_CELL', 'conceptref': 'CELL'},
#        {'codelist': 'CL_2026_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2026_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2026_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS006 - Population density', 'lang': 'en'},
#      'uri': 'Nm-2026d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Age,Usual Resident', 'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts007', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents in England and Wales by single year of age. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2027_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2027_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2027_1_C2021_AGE_102', 'conceptref': 'C2021_AGE_102'},
#        {'codelist': 'CL_2027_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2027_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2027_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS007 - Age by single year', 'lang': 'en'},
#      'uri': 'Nm-2027d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Sex', 'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts008', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents in England and Wales by sex. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2028_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2028_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2028_1_C_SEX', 'conceptref': 'C_SEX'},
#        {'codelist': 'CL_2028_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2028_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2028_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS008 - Sex', 'lang': 'en'},
#      'uri': 'Nm-2028d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Age,Usual Resident,Sex',
#         'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'la', 'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts009', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents in England and Wales by sex and single year of age. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2029_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2029_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2029_1_C_SEX', 'conceptref': 'C_SEX'},
#        {'codelist': 'CL_2029_1_C2021_AGE_92', 'conceptref': 'C2021_AGE_92'},
#        {'codelist': 'CL_2029_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2029_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2029_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS009 - Sex by single year of age', 'lang': 'en'},
#      'uri': 'Nm-2029d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Sex', 'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents aged 16 years and over in households',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts010', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents aged 16 years and over in households in England and Wales by their living arrangements. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2030_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2030_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2030_1_C2021_LIVING_11',
#         'conceptref': 'C2021_LIVING_11'},
#        {'codelist': 'CL_2030_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2030_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2030_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS010 - Living arrangements', 'lang': 'en'},
#      'uri': 'Nm-2030d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Sex', 'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Households', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All households',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts011', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify households in England and Wales by four dimensions of deprivation: Employment, education, health and disability, and household overcrowding. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2031_1',
# ...
#      'name': {'value': 'TS075 - Multi religion households', 'lang': 'en'},
#      'uri': 'Nm-2097d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'la', 'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents aged 3 and over',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts076', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-12-06 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-12-06 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents in Wales by their ability to speak Welsh by age. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2098_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2098_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2098_1_C2021_WLANGS_3',
#         'conceptref': 'C2021_WLANGS_3'},
#        {'codelist': 'CL_2098_1_C2021_AGE_86', 'conceptref': 'C2021_AGE_86'},
#        {'codelist': 'CL_2098_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2098_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2098_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS076 - Welsh language skills (speaking) by single year of age',
#       'lang': 'en'},
#      'uri': 'Nm-2098d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'All usual residents in communal establishments',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts048np', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify communal establishment residents in national parks in England and Wales by the type of communal establishment they live in. The estimates are as at Census Day, 21 March 2021. \n\n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2099_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2099_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2099_1_C2021_COMEST_12',
#         'conceptref': 'C2021_COMEST_12'},
#        {'codelist': 'CL_2099_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2099_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2099_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS048NP - Communal establishment management and type - National Parks',
#       'lang': 'en'},
#      'uri': 'Nm-2099d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'All usual residents aged 16 years and over in employment the week before the census',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts060np', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents aged 16 years and over in employment the week before the census in national parks in England and Wales by industry. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2100_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2100_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2100_1_C2021_IND_16', 'conceptref': 'C2021_IND_16'},
#        {'codelist': 'CL_2100_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2100_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2100_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS060NP - Industry - National Parks', 'lang': 'en'},
#      'uri': 'Nm-2100d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Cars', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'All cars or vans available for use by household members in the area',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts045a', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates on the total number of cars or vans available to members of households in England and Wales. The estimates are as at Census Day, 21 March 2021.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2324_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2324_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2324_1_C2021_CARS_TOTAL',
#         'conceptref': 'C2021_CARS_TOTAL'},
#        {'codelist': 'CL_2324_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2324_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2324_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS045A - Number of cars or vans in the area',
#       'lang': 'en'},
#      'uri': 'Nm-2324d1',
#      'version': 1.0}]},
#   'xmlns': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message',
#   'common': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common',
#   'structure': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure',
#   'xsi': 'http://www.w3.org/2001/XMLSchema-instance',
#   'schemalocation': 'http://sdmx.org/docs/2_0/SDMXMessage.xsd'}}

# %%
api_url = '/api/v01/dataset/def.sdmx.json?search=C2021TS*'
url = root_url + api_url
response = requests.get(url)

c2021_datasets_json = json.loads(response.text)
c2021_datasets_json = c2021_datasets_json['structure']['keyfamilies']['keyfamily']
c2021_datasets_metadata_list = []
for dataset in c2021_datasets_json:
    annotations = dataset['annotations']['annotation']
    for annotation in annotations:
        if annotation['annotationtitle'] == 'contenttype/geoglevel':
            geoglevel = annotation['annotationtext']
        if annotation['annotationtitle'] == 'Mnemonic':
            mnemonic = annotation['annotationtext']
        if annotation['annotationtitle'] == 'MetadataText0':
            description = annotation['annotationtext']
    id = dataset['id']
    metadata = {
        'id': id,
        'mnemonic': mnemonic,
        'description': description,
        'geoglevel': geoglevel
    }
    c2021_datasets_metadata_list.append(metadata)
c2021_datasets_metadata_df = pd.DataFrame(c2021_datasets_metadata_list)
c2021_datasets_metadata_df.to_csv('./data/raw/api/metadata.csv')
c2021_datasets_metadata_df
# Out:
#            id      mnemonic  \
# 0   NM_2020_1   c2021ts007a
# 1   NM_2021_1    c2021ts001
# 2   NM_2022_1    c2021ts002
# 3   NM_2023_1    c2021ts003
# 4   NM_2024_1    c2021ts004
# ..        ...           ...
# 75  NM_2097_1    c2021ts075
# 76  NM_2098_1    c2021ts076
# 77  NM_2099_1  c2021ts048np
# 78  NM_2100_1  c2021ts060np
# 79  NM_2324_1   c2021ts045a
#
#                                           description   geoglevel
# 0   This dataset provides Census 2021 estimates th...  oa,msoa,la
# 1   This dataset provides Census 2021 estimates th...  oa,msoa,la
# 2   This dataset provides Census 2021 estimates th...  oa,msoa,la
# 3   This dataset provides Census 2021 estimates th...  oa,msoa,la
# 4   This dataset provides Census 2021 estimates th...  oa,msoa,la
# ..                                                ...         ...
# 75  This dataset provides Census 2021 estimates th...  oa,msoa,la
# 76  This dataset provides Census 2021 estimates th...          la
# 77  This dataset provides Census 2021 estimates th...          la
# 78  This dataset provides Census 2021 estimates th...          la
# 79  This dataset provides Census 2021 estimates on...          la
#
# [80 rows x 4 columns]

# %%
c2021_datasets_metadata_df["id"][0]
# Out:
# 'NM_2020_1'

# %%
record_limit = 25000
offset = 0

for dataset in c2021_datasets_metadata_list[8:]:
    id = dataset['id']
    mnemonic = dataset['mnemonic']
    # if mnemonic != 'c2021ts007a':
    #     continue
    geoglevel = dataset['geoglevel'].split(',')
    if 'msoa' not in geoglevel:
        continue

    print("downloading", mnemonic)
    api_url = f'/api/v01/dataset/{id}.data.csv?recordlimit=10'
    url = root_url + api_url
    try:
        dataset_df = pd.read_csv(url)
    except:
        time.sleep(60)
        dataset_df = pd.read_csv(url)
    dataset_df.to_csv('test.csv')
    try:
        stat_name = dataset_df.filter(regex='^C2021.*NAME$', axis=1).columns[0].lower()
    except:
        try:
            stat_name = dataset_df.filter(regex='^CELL.*NAME$', axis=1).columns[0].lower()
        except:
            stat_name = dataset_df.filter(regex='^C_.*NAME$', axis=1).columns[0].lower()

    last_record = offset

    for i in range(1000):
        print(f"trying records {last_record} - {last_record + record_limit}")
        api_url = f'/api/v01/dataset/{id}.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,{stat_name},obs_value&recordlimit={record_limit}&recordoffset={last_record}'
        # api_url = f'/api/v01/dataset/{id}.data.csv?uid=0xd9817610eb1bbb16a8e6d24954e88792f83ff1f3&measures=20100&recordlimit={record_limit}&recordoffset={last_record}'
        url = root_url + api_url

        print(url)

        try:
            batch_df = pd.read_csv(url)
        except pd.errors.EmptyDataError:
            print("empty dataset")
            break
        except:
            time.sleep(60)
            batch_df = pd.read_csv(url)

        display(batch_df.head())

        if len(batch_df) == 0:
            break

        dest_file = f'./data/raw/api/{mnemonic}_{i:02}.csv'
        batch_df.to_csv(dest_file)
        print(f"chunk {i} saved in {dest_file}")

        last_record += record_limit
# Out:
# downloading c2021ts008
# trying records 0 - 25000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2028_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c_sex_name,obs_value&recordlimit=25000&recordoffset=0
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02002483  2021 super output areas - middle layer
# 1  2021      E02002483  2021 super output areas - middle layer
# 2  2021      E02002483  2021 super output areas - middle layer
# 3  2021      E02002484  2021 super output areas - middle layer
# 4  2021      E02002484  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE   C_SEX_NAME  OBS_VALUE
# 0                 152  All persons      10238
# 1                 152       Female       5324
# 2                 152         Male       4914
# 3                 152  All persons      10278
# 4                 152       Female       5279
# chunk 0 saved in ./data/raw/api/c2021ts008_00.csv
# trying records 25000 - 50000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2028_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c_sex_name,obs_value&recordlimit=25000&recordoffset=25000
# Empty DataFrame
# Columns: [DATE, GEOGRAPHY_CODE, GEOGRAPHY_TYPE, GEOGRAPHY_TYPECODE, C_SEX_NAME, OBS_VALUE]
# Index: []
# downloading c2021ts010
# trying records 0 - 25000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2030_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_living_11_name,obs_value&recordlimit=25000&recordoffset=0
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02002483  2021 super output areas - middle layer
# 1  2021      E02002483  2021 super output areas - middle layer
# 2  2021      E02002483  2021 super output areas - middle layer
# 3  2021      E02002483  2021 super output areas - middle layer
# 4  2021      E02002483  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                               C2021_LIVING_11_NAME  \
# 0                 152                         Total: All usual residents
# 1                 152                                 Living in a couple
# 2                 152  Living in a couple: Married or in a civil part...
# 3                 152  Living in a couple: Married or in a civil part...
# 4                 152  Living in a couple: Married or in a civil part...
#
#    OBS_VALUE
# 0       8177
# 1       5190
# 2       3809
# 3       3799
# 4         10
# chunk 0 saved in ./data/raw/api/c2021ts010_00.csv
# trying records 25000 - 50000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2030_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_living_11_name,obs_value&recordlimit=25000&recordoffset=25000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02006869  2021 super output areas - middle layer
# 1  2021      E02006869  2021 super output areas - middle layer
# 2  2021      E02006869  2021 super output areas - middle layer
# 3  2021      E02006869  2021 super output areas - middle layer
# 4  2021      E02006869  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                               C2021_LIVING_11_NAME  \
# 0                 152  Not living in a couple: Single (never married ...
# 1                 152  Not living in a couple: Married or in a regist...
# 2                 152  Not living in a couple: Separated (including t...
# 3                 152  Not living in a couple: Divorced or formerly i...
# 4                 152  Not living in a couple: Widowed or surviving p...
#
#    OBS_VALUE
# 0       2320
# 1         52
# 2        149
# 3        608
# 4        554
# chunk 1 saved in ./data/raw/api/c2021ts010_01.csv
# trying records 50000 - 75000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2030_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_living_11_name,obs_value&recordlimit=25000&recordoffset=50000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02003289  2021 super output areas - middle layer
# 1  2021      E02003289  2021 super output areas - middle layer
# 2  2021      E02003289  2021 super output areas - middle layer
# 3  2021      E02003289  2021 super output areas - middle layer
# 4  2021      E02003289  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                               C2021_LIVING_11_NAME  \
# 0                 152  Living in a couple: Separated, but still marri...
# 1                 152                     Living in a couple: Cohabiting
# 2                 152  Living in a couple: Cohabiting: Opposite-sex c...
# 3                 152    Living in a couple: Cohabiting: Same-sex couple
# 4                 152                             Not living in a couple
#
#    OBS_VALUE
# 0         15
# 1       1554
# 2       1490
# 3         64
# 4       3415
# chunk 2 saved in ./data/raw/api/c2021ts010_02.csv
# trying records 75000 - 100000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2030_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_living_11_name,obs_value&recordlimit=25000&recordoffset=75000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02000959  2021 super output areas - middle layer
# 1  2021      E02000959  2021 super output areas - middle layer
# 2  2021      E02000959  2021 super output areas - middle layer
# 3  2021      E02000959  2021 super output areas - middle layer
# 4  2021      E02000959  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                               C2021_LIVING_11_NAME  \
# 0                 152                         Total: All usual residents
# 1                 152                                 Living in a couple
# 2                 152  Living in a couple: Married or in a civil part...
# 3                 152  Living in a couple: Married or in a civil part...
# 4                 152  Living in a couple: Married or in a civil part...
#
#    OBS_VALUE
# 0       6293
# 1       2846
# 2       1921
# 3       1894
# 4         27
# chunk 3 saved in ./data/raw/api/c2021ts010_03.csv
# trying records 100000 - 125000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2030_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_living_11_name,obs_value&recordlimit=25000&recordoffset=100000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02004193  2021 super output areas - middle layer
# 1  2021      E02004193  2021 super output areas - middle layer
# 2  2021      E02004193  2021 super output areas - middle layer
# 3  2021      E02004193  2021 super output areas - middle layer
# 4  2021      E02004193  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                               C2021_LIVING_11_NAME  \
# 0                 152  Not living in a couple: Single (never married ...
# 1                 152  Not living in a couple: Married or in a regist...
# 2                 152  Not living in a couple: Separated (including t...
# 3                 152  Not living in a couple: Divorced or formerly i...
# 4                 152  Not living in a couple: Widowed or surviving p...
#
#    OBS_VALUE
# 0       1823
# 1         41
# 2        146
# 3        670
# 4        583
# chunk 4 saved in ./data/raw/api/c2021ts010_04.csv
# trying records 125000 - 150000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2030_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_living_11_name,obs_value&recordlimit=25000&recordoffset=125000
# Empty DataFrame
# Columns: [DATE, GEOGRAPHY_CODE, GEOGRAPHY_TYPE, GEOGRAPHY_TYPECODE, C2021_LIVING_11_NAME, OBS_VALUE]
# Index: []
# downloading c2021ts011
# trying records 0 - 25000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2031_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_dep_6_name,obs_value&recordlimit=25000&recordoffset=0
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02002483  2021 super output areas - middle layer
# 1  2021      E02002483  2021 super output areas - middle layer
# 2  2021      E02002483  2021 super output areas - middle layer
# 3  2021      E02002483  2021 super output areas - middle layer
# 4  2021      E02002483  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                            C2021_DEP_6_NAME  OBS_VALUE
# 0                 152                       Total: All households       4330
# 1                 152  Household is not deprived in any dimension       2250
# 2                 152      Household is deprived in one dimension       1337
# 3                 152     Household is deprived in two dimensions        624
# 4                 152   Household is deprived in three dimensions        117
# chunk 0 saved in ./data/raw/api/c2021ts011_00.csv
# trying records 25000 - 50000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2031_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_dep_6_name,obs_value&recordlimit=25000&recordoffset=25000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02000141  2021 super output areas - middle layer
# 1  2021      E02000141  2021 super output areas - middle layer
# 2  2021      E02000142  2021 super output areas - middle layer
# 3  2021      E02000142  2021 super output areas - middle layer
# 4  2021      E02000142  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                            C2021_DEP_6_NAME  OBS_VALUE
# 0                 152   Household is deprived in three dimensions         77
# 1                 152    Household is deprived in four dimensions          9
# 2                 152                       Total: All households       3452
# 3                 152  Household is not deprived in any dimension       2087
# 4                 152      Household is deprived in one dimension       1027
# chunk 1 saved in ./data/raw/api/c2021ts011_01.csv
# trying records 50000 - 75000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2031_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_dep_6_name,obs_value&recordlimit=25000&recordoffset=50000
# Empty DataFrame
# Columns: [DATE, GEOGRAPHY_CODE, GEOGRAPHY_TYPE, GEOGRAPHY_TYPECODE, C2021_DEP_6_NAME, OBS_VALUE]
# Index: []
# downloading c2021ts013
# trying records 0 - 25000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2033_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_pass_52_name,obs_value&recordlimit=25000&recordoffset=0
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02002483  2021 super output areas - middle layer
# 1  2021      E02002483  2021 super output areas - middle layer
# 2  2021      E02002483  2021 super output areas - middle layer
# 3  2021      E02002483  2021 super output areas - middle layer
# 4  2021      E02002483  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE          C2021_PASS_52_NAME  OBS_VALUE
# 0                 152  Total: All usual residents      10236
# 1                 152                      Europe       8677
# 2                 152      Europe: United Kingdom       8621
# 3                 152             Europe: Ireland          7
# 4                 152        Europe: Other Europe         49
# chunk 0 saved in ./data/raw/api/c2021ts013_00.csv
# trying records 25000 - 50000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2033_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_pass_52_name,obs_value&recordlimit=25000&recordoffset=25000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02002594  2021 super output areas - middle layer
# 1  2021      E02002594  2021 super output areas - middle layer
# 2  2021      E02002594  2021 super output areas - middle layer
# 3  2021      E02002594  2021 super output areas - middle layer
# 4  2021      E02002594  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                 C2021_PASS_52_NAME  \
# 0                 152        Africa: Central and Western Africa: Nigeria
# 1                 152  Africa: Central and Western Africa: Other Cent...
# 2                 152                   Africa: South and Eastern Africa
# 3                 152            Africa: South and Eastern Africa: Kenya
# 4                 152          Africa: South and Eastern Africa: Somalia
#
#    OBS_VALUE
# 0          9
# 1          0
# 2          2
# 3          0
# 4          0
# chunk 1 saved in ./data/raw/api/c2021ts013_01.csv
# trying records 50000 - 75000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2033_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_pass_52_name,obs_value&recordlimit=25000&recordoffset=50000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02005321  2021 super output areas - middle layer
# 1  2021      E02005321  2021 super output areas - middle layer
# 2  2021      E02005321  2021 super output areas - middle layer
# 3  2021      E02005321  2021 super output areas - middle layer
# 4  2021      E02005321  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                 C2021_PASS_52_NAME  \
# 0                 152      Middle East and Asia: Southern Asia: Pakistan
# 1                 152     Middle East and Asia: Southern Asia: Sri Lanka
# 2                 152  Middle East and Asia: Southern Asia: Other Sou...
# 3                 152              Middle East and Asia: South-East Asia
# 4                 152    Middle East and Asia: South-East Asia: Malaysia
#
#    OBS_VALUE
# 0          1
# 1          0
# 2          0
# 3         12
# 4          1
# chunk 2 saved in ./data/raw/api/c2021ts013_02.csv
# trying records 75000 - 100000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2033_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_pass_52_name,obs_value&recordlimit=25000&recordoffset=75000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02001324  2021 super output areas - middle layer
# 1  2021      E02001324  2021 super output areas - middle layer
# 2  2021      E02001324  2021 super output areas - middle layer
# 3  2021      E02001325  2021 super output areas - middle layer
# 4  2021      E02001325  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                 C2021_PASS_52_NAME  \
# 0                 152  Antarctica and Oceania: Other Antarctica and O...
# 1                 152                       British Overseas Territories
# 2                 152                                   No passport held
# 3                 152                         Total: All usual residents
# 4                 152                                             Europe
#
#    OBS_VALUE
# 0          1
# 1          0
# 2       1515
# 3       8956
# 4       7939
# chunk 3 saved in ./data/raw/api/c2021ts013_03.csv
# trying records 100000 - 125000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2033_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_pass_52_name,obs_value&recordlimit=25000&recordoffset=100000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02005772  2021 super output areas - middle layer
# 1  2021      E02005772  2021 super output areas - middle layer
# 2  2021      E02005772  2021 super output areas - middle layer
# 3  2021      E02005772  2021 super output areas - middle layer
# 4  2021      E02005772  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                 C2021_PASS_52_NAME  \
# 0                 152                               Africa: North Africa
# 1                 152                 Africa: Central and Western Africa
# 2                 152          Africa: Central and Western Africa: Ghana
# 3                 152        Africa: Central and Western Africa: Nigeria
# 4                 152  Africa: Central and Western Africa: Other Cent...
#
#    OBS_VALUE
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# chunk 4 saved in ./data/raw/api/c2021ts013_04.csv
# trying records 125000 - 150000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2033_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_pass_52_name,obs_value&recordlimit=25000&recordoffset=125000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02002325  2021 super output areas - middle layer
# 1  2021      E02002325  2021 super output areas - middle layer
# 2  2021      E02002325  2021 super output areas - middle layer
# 3  2021      E02002325  2021 super output areas - middle layer
# 4  2021      E02002325  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                C2021_PASS_52_NAME  \
# 0                 152  Middle East and Asia: Southern Asia: Afghanistan
# 1                 152   Middle East and Asia: Southern Asia: Bangladesh
# 2                 152        Middle East and Asia: Southern Asia: India
# 3                 152     Middle East and Asia: Southern Asia: Pakistan
# 4                 152    Middle East and Asia: Southern Asia: Sri Lanka
#
#    OBS_VALUE
# 0          0
# 1          0
# 2          4
# 3          3
# 4          0
# chunk 5 saved in ./data/raw/api/c2021ts013_05.csv
# trying records 150000 - 175000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2033_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_pass_52_name,obs_value&recordlimit=25000&recordoffset=150000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02004030  2021 super output areas - middle layer
# 1  2021      E02004030  2021 super output areas - middle layer
# 2  2021      E02004030  2021 super output areas - middle layer
# 3  2021      E02004030  2021 super output areas - middle layer
# 4  2021      E02004030  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                 C2021_PASS_52_NAME  \
# 0                 152                Antarctica and Oceania: Australasia
# 1                 152     Antarctica and Oceania: Australasia: Australia
# 2                 152   Antarctica and Oceania: Australasia: New Zealand
# 3                 152  Antarctica and Oceania: Other Antarctica and O...
# 4                 152                       British Overseas Territories
#
#    OBS_VALUE
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# chunk 6 saved in ./data/raw/api/c2021ts013_06.csv
# trying records 175000 - 200000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2033_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_pass_52_name,obs_value&recordlimit=25000&recordoffset=175000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02005914  2021 super output areas - middle layer
# 1  2021      E02005914  2021 super output areas - middle layer
# 2  2021      E02005914  2021 super output areas - middle layer
# 3  2021      E02005914  2021 super output areas - middle layer
# 4  2021      E02005914  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                 C2021_PASS_52_NAME  \
# 0                 152       Europe: Other Europe: Rest of Europe: Turkey
# 1                 152  Europe: Other Europe: Rest of Europe: Other Eu...
# 2                 152                                             Africa
# 3                 152                               Africa: North Africa
# 4                 152                 Africa: Central and Western Africa
#
#    OBS_VALUE
# 0          1
# 1          4
# 2         17
# 3          0
# 4          5
# chunk 7 saved in ./data/raw/api/c2021ts013_07.csv
# trying records 200000 - 225000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2033_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_pass_52_name,obs_value&recordlimit=25000&recordoffset=200000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02006757  2021 super output areas - middle layer
# 1  2021      E02006757  2021 super output areas - middle layer
# 2  2021      E02006757  2021 super output areas - middle layer
# 3  2021      E02006757  2021 super output areas - middle layer
# 4  2021      E02006757  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                 C2021_PASS_52_NAME  \
# 0                 152          Middle East and Asia: Eastern Asia: Japan
# 1                 152  Middle East and Asia: Eastern Asia: Other East...
# 2                 152                Middle East and Asia: Southern Asia
# 3                 152   Middle East and Asia: Southern Asia: Afghanistan
# 4                 152    Middle East and Asia: Southern Asia: Bangladesh
#
#    OBS_VALUE
# 0          2
# 1          0
# 2          3
# 3          0
# 4          0
# chunk 8 saved in ./data/raw/api/c2021ts013_08.csv
# trying records 225000 - 250000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2033_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_pass_52_name,obs_value&recordlimit=25000&recordoffset=225000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02002163  2021 super output areas - middle layer
# 1  2021      E02002163  2021 super output areas - middle layer
# 2  2021      E02002163  2021 super output areas - middle layer
# 3  2021      E02002163  2021 super output areas - middle layer
# 4  2021      E02002163  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                 C2021_PASS_52_NAME  \
# 0                 152  The Americas and the Caribbean: The Caribbean:...
# 1                 152  The Americas and the Caribbean: The Caribbean:...
# 2                 152                             Antarctica and Oceania
# 3                 152                Antarctica and Oceania: Australasia
# 4                 152     Antarctica and Oceania: Australasia: Australia
#
#    OBS_VALUE
# 0         66
# 1         11
# 2          4
# 3          1
# 4          1
# chunk 9 saved in ./data/raw/api/c2021ts013_09.csv
# trying records 250000 - 275000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2033_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_pass_52_name,obs_value&recordlimit=25000&recordoffset=250000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02004556  2021 super output areas - middle layer
# 1  2021      E02004556  2021 super output areas - middle layer
# 2  2021      E02004556  2021 super output areas - middle layer
# 3  2021      E02004556  2021 super output areas - middle layer
# 4  2021      E02004556  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                 C2021_PASS_52_NAME  \
# 0                 152  Europe: Other Europe: EU Member countries: Rom...
# 1                 152  Europe: Other Europe: EU Member countries: Oth...
# 2                 152               Europe: Other Europe: Rest of Europe
# 3                 152       Europe: Other Europe: Rest of Europe: Turkey
# 4                 152  Europe: Other Europe: Rest of Europe: Other Eu...
#
#    OBS_VALUE
# 0          2
# 1         36
# 2          5
# 3          0
# 4          5
# chunk 10 saved in ./data/raw/api/c2021ts013_10.csv
# trying records 275000 - 300000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2033_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_pass_52_name,obs_value&recordlimit=25000&recordoffset=275000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02006298  2021 super output areas - middle layer
# 1  2021      E02006298  2021 super output areas - middle layer
# 2  2021      E02006298  2021 super output areas - middle layer
# 3  2021      E02006298  2021 super output areas - middle layer
# 4  2021      E02006298  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                 C2021_PASS_52_NAME  \
# 0                 152                 Middle East and Asia: Eastern Asia
# 1                 152          Middle East and Asia: Eastern Asia: China
# 2                 152  Middle East and Asia: Eastern Asia: Hong Kong ...
# 3                 152          Middle East and Asia: Eastern Asia: Japan
# 4                 152  Middle East and Asia: Eastern Asia: Other East...
#
#    OBS_VALUE
# 0          1
# 1          1
# 2          0
# 3          0
# 4          0
# chunk 11 saved in ./data/raw/api/c2021ts013_11.csv
# trying records 300000 - 325000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2033_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_pass_52_name,obs_value&recordlimit=25000&recordoffset=300000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02000320  2021 super output areas - middle layer
# 1  2021      E02000320  2021 super output areas - middle layer
# 2  2021      E02000320  2021 super output areas - middle layer
# 3  2021      E02000320  2021 super output areas - middle layer
# 4  2021      E02000320  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                 C2021_PASS_52_NAME  \
# 0                 152    The Americas and the Caribbean: Central America
# 1                 152      The Americas and the Caribbean: South America
# 2                 152      The Americas and the Caribbean: The Caribbean
# 3                 152  The Americas and the Caribbean: The Caribbean:...
# 4                 152  The Americas and the Caribbean: The Caribbean:...
#
#    OBS_VALUE
# 0          1
# 1         32
# 2         22
# 3         18
# 4          4
# chunk 12 saved in ./data/raw/api/c2021ts013_12.csv
# trying records 325000 - 350000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2033_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_pass_52_name,obs_value&recordlimit=25000&recordoffset=325000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02000678  2021 super output areas - middle layer
# 1  2021      E02000678  2021 super output areas - middle layer
# 2  2021      E02000678  2021 super output areas - middle layer
# 3  2021      E02000678  2021 super output areas - middle layer
# 4  2021      E02000678  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                 C2021_PASS_52_NAME  \
# 0                 152   Europe: Other Europe: EU Member countries: Spain
# 1                 152  Europe: Other Europe: EU Member countries: Lit...
# 2                 152  Europe: Other Europe: EU Member countries: Poland
# 3                 152  Europe: Other Europe: EU Member countries: Rom...
# 4                 152  Europe: Other Europe: EU Member countries: Oth...
#
#    OBS_VALUE
# 0         56
# 1         57
# 2        138
# 3        107
# 4        188
# chunk 13 saved in ./data/raw/api/c2021ts013_13.csv
# trying records 350000 - 375000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2033_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_pass_52_name,obs_value&recordlimit=25000&recordoffset=350000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02003359  2021 super output areas - middle layer
# 1  2021      E02003359  2021 super output areas - middle layer
# 2  2021      E02003359  2021 super output areas - middle layer
# 3  2021      E02003359  2021 super output areas - middle layer
# 4  2021      E02003359  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                 C2021_PASS_52_NAME  \
# 0                 152            Middle East and Asia: Middle East: Iran
# 1                 152            Middle East and Asia: Middle East: Iraq
# 2                 152  Middle East and Asia: Middle East: Other Middl...
# 3                 152                 Middle East and Asia: Eastern Asia
# 4                 152          Middle East and Asia: Eastern Asia: China
#
#    OBS_VALUE
# 0          0
# 1          0
# 2          1
# 3         10
# 4          9
# chunk 14 saved in ./data/raw/api/c2021ts013_14.csv
# trying records 375000 - 400000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2033_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_pass_52_name,obs_value&recordlimit=25000&recordoffset=375000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02004403  2021 super output areas - middle layer
# 1  2021      E02004403  2021 super output areas - middle layer
# 2  2021      E02004403  2021 super output areas - middle layer
# 3  2021      E02004403  2021 super output areas - middle layer
# 4  2021      E02004403  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                 C2021_PASS_52_NAME  \
# 0                 152      The Americas and the Caribbean: North America
# 1                 152  The Americas and the Caribbean: North America:...
# 2                 152  The Americas and the Caribbean: North America:...
# 3                 152    The Americas and the Caribbean: Central America
# 4                 152      The Americas and the Caribbean: South America
#
#    OBS_VALUE
# 0         34
# 1          8
# 2         26
# 3          0
# 4          3
# chunk 15 saved in ./data/raw/api/c2021ts013_15.csv
# trying records 400000 - 425000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2033_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_pass_52_name,obs_value&recordlimit=25000&recordoffset=400000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02005165  2021 super output areas - middle layer
# 1  2021      E02005165  2021 super output areas - middle layer
# 2  2021      E02005165  2021 super output areas - middle layer
# 3  2021      E02005165  2021 super output areas - middle layer
# 4  2021      E02005165  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                 C2021_PASS_52_NAME  \
# 0                 152  Europe: Other Europe: EU Member countries: Ger...
# 1                 152   Europe: Other Europe: EU Member countries: Italy
# 2                 152  Europe: Other Europe: EU Member countries: Por...
# 3                 152   Europe: Other Europe: EU Member countries: Spain
# 4                 152  Europe: Other Europe: EU Member countries: Lit...
#
#    OBS_VALUE
# 0         18
# 1          6
# 2         11
# 3          6
# 4         12
# chunk 16 saved in ./data/raw/api/c2021ts013_16.csv
# trying records 425000 - 450000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2033_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_pass_52_name,obs_value&recordlimit=25000&recordoffset=425000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02002998  2021 super output areas - middle layer
# 1  2021      E02002998  2021 super output areas - middle layer
# 2  2021      E02002998  2021 super output areas - middle layer
# 3  2021      E02002998  2021 super output areas - middle layer
# 4  2021      E02002998  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                 C2021_PASS_52_NAME  \
# 0                 152  Africa: South and Eastern Africa: Other South ...
# 1                 152                               Middle East and Asia
# 2                 152                  Middle East and Asia: Middle East
# 3                 152            Middle East and Asia: Middle East: Iran
# 4                 152            Middle East and Asia: Middle East: Iraq
#
#    OBS_VALUE
# 0          5
# 1         94
# 2         11
# 3          0
# 4          0
# chunk 17 saved in ./data/raw/api/c2021ts013_17.csv
# trying records 450000 - 475000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2033_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_pass_52_name,obs_value&recordlimit=25000&recordoffset=450000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02003188  2021 super output areas - middle layer
# 1  2021      E02003188  2021 super output areas - middle layer
# 2  2021      E02003188  2021 super output areas - middle layer
# 3  2021      E02003188  2021 super output areas - middle layer
# 4  2021      E02003188  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                 C2021_PASS_52_NAME  \
# 0                 152  Middle East and Asia: South-East Asia: Other S...
# 1                 152                 Middle East and Asia: Central Asia
# 2                 152                     The Americas and the Caribbean
# 3                 152      The Americas and the Caribbean: North America
# 4                 152  The Americas and the Caribbean: North America:...
#
#    OBS_VALUE
# 0         49
# 1         19
# 2        317
# 3         62
# 4         20
# chunk 18 saved in ./data/raw/api/c2021ts013_18.csv
# trying records 475000 - 500000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2033_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_pass_52_name,obs_value&recordlimit=25000&recordoffset=475000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      W02000029  2021 super output areas - middle layer
# 1  2021      W02000029  2021 super output areas - middle layer
# 2  2021      W02000029  2021 super output areas - middle layer
# 3  2021      W02000029  2021 super output areas - middle layer
# 4  2021      W02000029  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                 C2021_PASS_52_NAME  \
# 0                 152                               Europe: Other Europe
# 1                 152          Europe: Other Europe: EU Member countries
# 2                 152  Europe: Other Europe: EU Member countries: France
# 3                 152  Europe: Other Europe: EU Member countries: Ger...
# 4                 152   Europe: Other Europe: EU Member countries: Italy
#
#    OBS_VALUE
# 0         94
# 1         90
# 2          3
# 3         10
# 4          9
# chunk 19 saved in ./data/raw/api/c2021ts013_19.csv
# trying records 500000 - 525000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2033_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_pass_52_name,obs_value&recordlimit=25000&recordoffset=500000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      W02000105  2021 super output areas - middle layer
# 1  2021      W02000105  2021 super output areas - middle layer
# 2  2021      W02000105  2021 super output areas - middle layer
# 3  2021      W02000105  2021 super output areas - middle layer
# 4  2021      W02000105  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                                 C2021_PASS_52_NAME  \
# 0                 152          Africa: South and Eastern Africa: Somalia
# 1                 152     Africa: South and Eastern Africa: South Africa
# 2                 152         Africa: South and Eastern Africa: Zimbabwe
# 3                 152  Africa: South and Eastern Africa: Other South ...
# 4                 152                               Middle East and Asia
#
#    OBS_VALUE
# 0          0
# 1          1
# 2          0
# 3          0
# 4          7
# chunk 20 saved in ./data/raw/api/c2021ts013_20.csv
# trying records 525000 - 550000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2033_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_pass_52_name,obs_value&recordlimit=25000&recordoffset=525000
# Empty DataFrame
# Columns: [DATE, GEOGRAPHY_CODE, GEOGRAPHY_TYPE, GEOGRAPHY_TYPECODE, C2021_PASS_52_NAME, OBS_VALUE]
# Index: []
# downloading c2021ts015
# trying records 0 - 25000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2035_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_arruk_13_name,obs_value&recordlimit=25000&recordoffset=0
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02002483  2021 super output areas - middle layer
# 1  2021      E02002483  2021 super output areas - middle layer
# 2  2021      E02002483  2021 super output areas - middle layer
# 3  2021      E02002483  2021 super output areas - middle layer
# 4  2021      E02002483  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE         C2021_ARRUK_13_NAME  OBS_VALUE
# 0                 152  Total: All usual residents      10239
# 1                 152              Born in the UK      10023
# 2                 152         Arrived before 1951          3
# 3                 152        Arrived 1951 to 1960          7
# 4                 152        Arrived 1961 to 1970         14
# chunk 0 saved in ./data/raw/api/c2021ts015_00.csv
# trying records 25000 - 50000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2035_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_arruk_13_name,obs_value&recordlimit=25000&recordoffset=25000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02002438  2021 super output areas - middle layer
# 1  2021      E02002438  2021 super output areas - middle layer
# 2  2021      E02002438  2021 super output areas - middle layer
# 3  2021      E02002438  2021 super output areas - middle layer
# 4  2021      E02002438  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE   C2021_ARRUK_13_NAME  OBS_VALUE
# 0                 152        Born in the UK       8347
# 1                 152   Arrived before 1951          6
# 2                 152  Arrived 1951 to 1960          8
# 3                 152  Arrived 1961 to 1970         12
# 4                 152  Arrived 1971 to 1980         12
# chunk 1 saved in ./data/raw/api/c2021ts015_01.csv
# trying records 50000 - 75000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2035_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_arruk_13_name,obs_value&recordlimit=25000&recordoffset=50000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02005594  2021 super output areas - middle layer
# 1  2021      E02005594  2021 super output areas - middle layer
# 2  2021      E02005594  2021 super output areas - middle layer
# 3  2021      E02005594  2021 super output areas - middle layer
# 4  2021      E02005594  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE   C2021_ARRUK_13_NAME  OBS_VALUE
# 0                 152   Arrived before 1951         21
# 1                 152  Arrived 1951 to 1960         44
# 2                 152  Arrived 1961 to 1970         67
# 3                 152  Arrived 1971 to 1980         43
# 4                 152  Arrived 1981 to 1990         84
# chunk 2 saved in ./data/raw/api/c2021ts015_02.csv
# trying records 75000 - 100000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2035_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_arruk_13_name,obs_value&recordlimit=25000&recordoffset=75000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02005137  2021 super output areas - middle layer
# 1  2021      E02005137  2021 super output areas - middle layer
# 2  2021      E02005137  2021 super output areas - middle layer
# 3  2021      E02005137  2021 super output areas - middle layer
# 4  2021      E02005137  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE   C2021_ARRUK_13_NAME  OBS_VALUE
# 0                 152  Arrived 1951 to 1960         17
# 1                 152  Arrived 1961 to 1970         22
# 2                 152  Arrived 1971 to 1980         39
# 3                 152  Arrived 1981 to 1990         33
# 4                 152  Arrived 1991 to 2000         86
# chunk 3 saved in ./data/raw/api/c2021ts015_03.csv
# trying records 100000 - 125000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2035_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_arruk_13_name,obs_value&recordlimit=25000&recordoffset=100000
# Empty DataFrame
# Columns: [DATE, GEOGRAPHY_CODE, GEOGRAPHY_TYPE, GEOGRAPHY_TYPECODE, C2021_ARRUK_13_NAME, OBS_VALUE]
# Index: []
# downloading c2021ts016
# trying records 0 - 25000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2036_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_resuk_6_name,obs_value&recordlimit=25000&recordoffset=0
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02002483  2021 super output areas - middle layer
# 1  2021      E02002483  2021 super output areas - middle layer
# 2  2021      E02002483  2021 super output areas - middle layer
# 3  2021      E02002483  2021 super output areas - middle layer
# 4  2021      E02002483  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                       C2021_RESUK_6_NAME  OBS_VALUE
# 0                 152               Total: All usual residents      10240
# 1                 152                           Born in the UK      10023
# 2                 152                         10 years or more        142
# 3                 152  5 years or more, but less than 10 years         38
# 4                 152   2 years or more, but less than 5 years         30
# chunk 0 saved in ./data/raw/api/c2021ts016_00.csv
# trying records 25000 - 50000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2036_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_resuk_6_name,obs_value&recordlimit=25000&recordoffset=25000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02000141  2021 super output areas - middle layer
# 1  2021      E02000141  2021 super output areas - middle layer
# 2  2021      E02000142  2021 super output areas - middle layer
# 3  2021      E02000142  2021 super output areas - middle layer
# 4  2021      E02000142  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                      C2021_RESUK_6_NAME  OBS_VALUE
# 0                 152  2 years or more, but less than 5 years        150
# 1                 152                       Less than 2 years        116
# 2                 152              Total: All usual residents       8816
# 3                 152                          Born in the UK       6932
# 4                 152                        10 years or more       1205
# chunk 1 saved in ./data/raw/api/c2021ts016_01.csv
# trying records 50000 - 75000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2036_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_resuk_6_name,obs_value&recordlimit=25000&recordoffset=50000
# Empty DataFrame
# Columns: [DATE, GEOGRAPHY_CODE, GEOGRAPHY_TYPE, GEOGRAPHY_TYPECODE, C2021_RESUK_6_NAME, OBS_VALUE]
# Index: []
# downloading c2021ts017
# trying records 0 - 25000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2037_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_hhsize_10_name,obs_value&recordlimit=25000&recordoffset=0
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02002483  2021 super output areas - middle layer
# 1  2021      E02002483  2021 super output areas - middle layer
# 2  2021      E02002483  2021 super output areas - middle layer
# 3  2021      E02002483  2021 super output areas - middle layer
# 4  2021      E02002483  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE   C2021_HHSIZE_10_NAME  OBS_VALUE
# 0                 152  Total: All households       4330
# 1                 152  0 people in household          0
# 2                 152  1 person in household       1183
# 3                 152  2 people in household       1492
# 4                 152  3 people in household        849
# chunk 0 saved in ./data/raw/api/c2021ts017_00.csv
# trying records 25000 - 50000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2037_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_hhsize_10_name,obs_value&recordlimit=25000&recordoffset=25000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02005879  2021 super output areas - middle layer
# 1  2021      E02005879  2021 super output areas - middle layer
# 2  2021      E02005879  2021 super output areas - middle layer
# 3  2021      E02005879  2021 super output areas - middle layer
# 4  2021      E02005879  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE   C2021_HHSIZE_10_NAME  OBS_VALUE
# 0                 152  Total: All households       3495
# 1                 152  0 people in household          0
# 2                 152  1 person in household       1272
# 3                 152  2 people in household       1199
# 4                 152  3 people in household        587
# chunk 1 saved in ./data/raw/api/c2021ts017_01.csv
# trying records 50000 - 75000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2037_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_hhsize_10_name,obs_value&recordlimit=25000&recordoffset=50000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02000959  2021 super output areas - middle layer
# 1  2021      E02000959  2021 super output areas - middle layer
# 2  2021      E02000959  2021 super output areas - middle layer
# 3  2021      E02000959  2021 super output areas - middle layer
# 4  2021      E02000959  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE   C2021_HHSIZE_10_NAME  OBS_VALUE
# 0                 152  Total: All households       3104
# 1                 152  0 people in household          0
# 2                 152  1 person in household        897
# 3                 152  2 people in household        863
# 4                 152  3 people in household        614
# chunk 2 saved in ./data/raw/api/c2021ts017_02.csv
# trying records 75000 - 100000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2037_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_hhsize_10_name,obs_value&recordlimit=25000&recordoffset=75000
# Empty DataFrame
# Columns: [DATE, GEOGRAPHY_CODE, GEOGRAPHY_TYPE, GEOGRAPHY_TYPECODE, C2021_HHSIZE_10_NAME, OBS_VALUE]
# Index: []
# downloading c2021ts018
# trying records 0 - 25000
# ...
# 2                 152        Other religion: Scientology          0
# 3                 152          Other religion: Shamanism          0
# 4                 152          Other religion: Shintoism          0
# chunk 7 saved in ./data/raw/api/c2021ts031_07.csv
# trying records 200000 - 225000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2096_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_religion_58_name,obs_value&recordlimit=25000&recordoffset=200000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02003289  2021 super output areas - middle layer
# 1  2021      E02003289  2021 super output areas - middle layer
# 2  2021      E02003289  2021 super output areas - middle layer
# 3  2021      E02003289  2021 super output areas - middle layer
# 4  2021      E02003289  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                  C2021_RELIGION_58_NAME  OBS_VALUE
# 0                 152        Other religion: Chinese Religion          0
# 1                 152  Other religion: Church of All Religion          0
# 2                 152            Other religion: Confucianist          0
# 3                 152                   Other religion: Deist          0
# 4                 152                   Other religion: Druid          0
# chunk 8 saved in ./data/raw/api/c2021ts031_08.csv
# trying records 225000 - 250000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2096_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_religion_58_name,obs_value&recordlimit=25000&recordoffset=225000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02004974  2021 super output areas - middle layer
# 1  2021      E02004974  2021 super output areas - middle layer
# 2  2021      E02004974  2021 super output areas - middle layer
# 3  2021      E02004974  2021 super output areas - middle layer
# 4  2021      E02004974  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE      C2021_RELIGION_58_NAME  OBS_VALUE
# 0                 152  Total: All Usual Residents       9075
# 1                 152                   Christian       3681
# 2                 152                    Buddhist         94
# 3                 152                       Hindu       1277
# 4                 152                      Jewish        170
# chunk 9 saved in ./data/raw/api/c2021ts031_09.csv
# trying records 250000 - 275000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2096_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_religion_58_name,obs_value&recordlimit=25000&recordoffset=250000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02000141  2021 super output areas - middle layer
# 1  2021      E02000141  2021 super output areas - middle layer
# 2  2021      E02000141  2021 super output areas - middle layer
# 3  2021      E02000141  2021 super output areas - middle layer
# 4  2021      E02000141  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE             C2021_RELIGION_58_NAME  OBS_VALUE
# 0                 152  Other religion: Reconstructionist          0
# 1                 152           Other religion: Satanism          0
# 2                 152        Other religion: Scientology          0
# 3                 152          Other religion: Shamanism          0
# 4                 152          Other religion: Shintoism          0
# chunk 10 saved in ./data/raw/api/c2021ts031_10.csv
# trying records 275000 - 300000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2096_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_religion_58_name,obs_value&recordlimit=25000&recordoffset=275000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02000552  2021 super output areas - middle layer
# 1  2021      E02000552  2021 super output areas - middle layer
# 2  2021      E02000552  2021 super output areas - middle layer
# 3  2021      E02000552  2021 super output areas - middle layer
# 4  2021      E02000552  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                  C2021_RELIGION_58_NAME  OBS_VALUE
# 0                 152        Other religion: Chinese Religion          0
# 1                 152  Other religion: Church of All Religion          0
# 2                 152            Other religion: Confucianist          0
# 3                 152                   Other religion: Deist          1
# 4                 152                   Other religion: Druid          0
# chunk 11 saved in ./data/raw/api/c2021ts031_11.csv
# trying records 300000 - 325000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2096_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_religion_58_name,obs_value&recordlimit=25000&recordoffset=300000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02000959  2021 super output areas - middle layer
# 1  2021      E02000959  2021 super output areas - middle layer
# 2  2021      E02000959  2021 super output areas - middle layer
# 3  2021      E02000959  2021 super output areas - middle layer
# 4  2021      E02000959  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE      C2021_RELIGION_58_NAME  OBS_VALUE
# 0                 152  Total: All Usual Residents       7867
# 1                 152                   Christian       3495
# 2                 152                    Buddhist         42
# 3                 152                       Hindu        144
# 4                 152                      Jewish         15
# chunk 12 saved in ./data/raw/api/c2021ts031_12.csv
# trying records 325000 - 350000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2096_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_religion_58_name,obs_value&recordlimit=25000&recordoffset=325000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02004385  2021 super output areas - middle layer
# 1  2021      E02004385  2021 super output areas - middle layer
# 2  2021      E02004385  2021 super output areas - middle layer
# 3  2021      E02004385  2021 super output areas - middle layer
# 4  2021      E02004385  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE             C2021_RELIGION_58_NAME  OBS_VALUE
# 0                 152  Other religion: Reconstructionist          0
# 1                 152           Other religion: Satanism          0
# 2                 152        Other religion: Scientology          0
# 3                 152          Other religion: Shamanism          1
# 4                 152          Other religion: Shintoism          0
# chunk 13 saved in ./data/raw/api/c2021ts031_13.csv
# trying records 350000 - 375000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2096_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_religion_58_name,obs_value&recordlimit=25000&recordoffset=350000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02005946  2021 super output areas - middle layer
# 1  2021      E02005946  2021 super output areas - middle layer
# 2  2021      E02005946  2021 super output areas - middle layer
# 3  2021      E02005946  2021 super output areas - middle layer
# 4  2021      E02005946  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                  C2021_RELIGION_58_NAME  OBS_VALUE
# 0                 152        Other religion: Chinese Religion          0
# 1                 152  Other religion: Church of All Religion          0
# 2                 152            Other religion: Confucianist          0
# 3                 152                   Other religion: Deist          0
# 4                 152                   Other religion: Druid          0
# chunk 14 saved in ./data/raw/api/c2021ts031_14.csv
# trying records 375000 - 400000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2096_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_religion_58_name,obs_value&recordlimit=25000&recordoffset=375000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02003086  2021 super output areas - middle layer
# 1  2021      E02003086  2021 super output areas - middle layer
# 2  2021      E02003086  2021 super output areas - middle layer
# 3  2021      E02003086  2021 super output areas - middle layer
# 4  2021      E02003086  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE      C2021_RELIGION_58_NAME  OBS_VALUE
# 0                 152  Total: All Usual Residents       6127
# 1                 152                   Christian       3069
# 2                 152                    Buddhist         30
# 3                 152                       Hindu         10
# 4                 152                      Jewish          7
# chunk 15 saved in ./data/raw/api/c2021ts031_15.csv
# trying records 400000 - 425000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2096_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_religion_58_name,obs_value&recordlimit=25000&recordoffset=400000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02004193  2021 super output areas - middle layer
# 1  2021      E02004193  2021 super output areas - middle layer
# 2  2021      E02004193  2021 super output areas - middle layer
# 3  2021      E02004193  2021 super output areas - middle layer
# 4  2021      E02004193  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE             C2021_RELIGION_58_NAME  OBS_VALUE
# 0                 152  Other religion: Reconstructionist          1
# 1                 152           Other religion: Satanism          2
# 2                 152        Other religion: Scientology          3
# 3                 152          Other religion: Shamanism          0
# 4                 152          Other religion: Shintoism          0
# chunk 16 saved in ./data/raw/api/c2021ts031_16.csv
# trying records 425000 - 450000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2096_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_religion_58_name,obs_value&recordlimit=25000&recordoffset=425000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      W02000368  2021 super output areas - middle layer
# 1  2021      W02000368  2021 super output areas - middle layer
# 2  2021      W02000368  2021 super output areas - middle layer
# 3  2021      W02000368  2021 super output areas - middle layer
# 4  2021      W02000368  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                  C2021_RELIGION_58_NAME  OBS_VALUE
# 0                 152        Other religion: Chinese Religion          0
# 1                 152  Other religion: Church of All Religion          0
# 2                 152            Other religion: Confucianist          0
# 3                 152                   Other religion: Deist          0
# 4                 152                   Other religion: Druid          1
# chunk 17 saved in ./data/raw/api/c2021ts031_17.csv
# trying records 450000 - 475000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2096_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_religion_58_name,obs_value&recordlimit=25000&recordoffset=450000
# Empty DataFrame
# Columns: [DATE, GEOGRAPHY_CODE, GEOGRAPHY_TYPE, GEOGRAPHY_TYPECODE, C2021_RELIGION_58_NAME, OBS_VALUE]
# Index: []
# downloading c2021ts075
# trying records 0 - 25000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2097_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_relmult_7_name,obs_value&recordlimit=25000&recordoffset=0
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02002483  2021 super output areas - middle layer
# 1  2021      E02002483  2021 super output areas - middle layer
# 2  2021      E02002483  2021 super output areas - middle layer
# 3  2021      E02002483  2021 super output areas - middle layer
# 4  2021      E02002483  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                               C2021_RELMULT_7_NAME  \
# 0                 152                              Total: All households
# 1                 152                               One-person household
# 2                 152                             Multi-person household
# 3                 152  Multi-person household: No people stated their...
# 4                 152  Multi-person household: Same religion (at leas...
#
#    OBS_VALUE
# 0       4330
# 1       1183
# 2       3147
# 3         58
# 4       1541
# chunk 0 saved in ./data/raw/api/c2021ts075_00.csv
# trying records 25000 - 50000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2097_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_relmult_7_name,obs_value&recordlimit=25000&recordoffset=25000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02002029  2021 super output areas - middle layer
# 1  2021      E02002029  2021 super output areas - middle layer
# 2  2021      E02002029  2021 super output areas - middle layer
# 3  2021      E02002029  2021 super output areas - middle layer
# 4  2021      E02002029  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                               C2021_RELMULT_7_NAME  \
# 0                 152                              Total: All households
# 1                 152                               One-person household
# 2                 152                             Multi-person household
# 3                 152  Multi-person household: No people stated their...
# 4                 152  Multi-person household: Same religion (at leas...
#
#    OBS_VALUE
# 0       2592
# 1        691
# 2       1901
# 3         46
# 4       1070
# chunk 1 saved in ./data/raw/api/c2021ts075_01.csv
# trying records 50000 - 75000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2097_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_relmult_7_name,obs_value&recordlimit=25000&recordoffset=50000
#    DATE GEOGRAPHY_CODE                          GEOGRAPHY_TYPE  \
# 0  2021      E02003086  2021 super output areas - middle layer
# 1  2021      E02003086  2021 super output areas - middle layer
# 2  2021      E02003086  2021 super output areas - middle layer
# 3  2021      E02003086  2021 super output areas - middle layer
# 4  2021      E02003086  2021 super output areas - middle layer
#
#    GEOGRAPHY_TYPECODE                               C2021_RELMULT_7_NAME  \
# 0                 152                              Total: All households
# 1                 152                               One-person household
# 2                 152                             Multi-person household
# 3                 152  Multi-person household: No people stated their...
# 4                 152  Multi-person household: Same religion (at leas...
#
#    OBS_VALUE
# 0       2791
# 1       1096
# 2       1695
# 3         45
# 4        721
# chunk 2 saved in ./data/raw/api/c2021ts075_02.csv
# trying records 75000 - 100000
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2097_1.data.csv?geography=TYPE152&measures=20100&select=date,geography_code,geography_type,geography_typecode,c2021_relmult_7_name,obs_value&recordlimit=25000&recordoffset=75000
# Empty DataFrame
# Columns: [DATE, GEOGRAPHY_CODE, GEOGRAPHY_TYPE, GEOGRAPHY_TYPECODE, C2021_RELMULT_7_NAME, OBS_VALUE]
# Index: []

# %%
# record_limit = 1000000
# offset = 0

# for dataset in c2021_datasets_metadata_list:
#     id = dataset['id']
#     mnemonic = dataset['mnemonic']
#     # if mnemonic != 'c2021ts007a':
#     #     continue
#     geoglevel = dataset['geoglevel'].split(',')
#     if 'msoa' not in geoglevel:
#         continue

#     print("downloading", mnemonic)
#     api_url = f'/api/v01/dataset/{id}.data.csv?recordlimit=0'
#     url = root_url + api_url
#     try:
#         dataset_df = pd.read_csv(url)
#     except:
#         time.sleep(60)
#         dataset_df = pd.read_csv(url)
#     try:
#         stat_name = dataset_df.filter(regex='^C2021.*NAME$', axis=1).columns[0].lower()
#     except:
#         stat_name = dataset_df.filter(regex='^CELL.*NAME$', axis=1).columns[0].lower()

#     # api_url = f'/api/v01/dataset/{id}.data.csv?recordlimit=0&select=date,geography_code,{stat_name},obs_value'
#     # url = root_url + api_url
#     # dataset_df = pd.read_csv(url)

#     last_record = offset
#     # api_url = f'/api/v01/dataset/{id}.data.csv?uid=0xd9817610eb1bbb16a8e6d24954e88792f83ff1f3&measures=20100&select=date,geography_code,{stat_name},obs_value'
#     # url = root_url + api_url
#     # chunksize = 10 ** 6
#     # with pd.read_csv(url, chunksize=chunksize) as reader:
#     #     i = 0
#     #     for chunk in reader:
#     #         dest_file = f'./data/raw/api/{mnemonic}_{i:02}.csv'
#     #         chunk.to_csv(dest_file)
#     #         print(f"chunk {i} saved in {dest_file}")
#     #         i += 1
#     # try:
#     #     dataset_df = pd.read_csv(url)
#     # except:
#     #     time.sleep(60)
#     #     dataset_df = pd.read_csv(url)
#     for i in range(1000):
#         print(f"trying records {last_record} - {last_record + record_limit}")
#         api_url = f'/api/v01/dataset/{id}.data.csv?uid=0xd9817610eb1bbb16a8e6d24954e88792f83ff1f3&measures=20100&select=date,geography_code,geography_type,geography_typecode,{stat_name},obs_value&recordlimit={record_limit}&recordoffset={last_record}'
#         url = root_url + api_url

#         try:
#             batch_df = pd.read_csv(url)
#         except:
#             time.sleep(60)
#             batch_df = pd.read_csv(url)

#         display(batch_df.head())

#         if len(batch_df) == 0:
#             break

#         dest_file = f'./data/raw/api/{mnemonic}_{i:02}.csv'
#         batch_df.to_csv(dest_file)
#         print(f"chunk {i} saved in {dest_file}")

#         # dataset_df = pd.concat([dataset_df, batch_df])
#         last_record += record_limit

#     # for oa in oa21:
#     #     api_url = f'/api/v01/dataset/{id}.data.csv?geography={oa}&measures=20100&select=date,geography_code,{stat_name},obs_value'
#     #     url = root_url + api_url
#     #     oa_df = pd.read_csv(url)
#     #     dataset_df = pd.concat([dataset_df, oa_df])

#     # dataset_df.to_csv(f'./data/raw/api/{mnemonic}.csv')
#     # print(f"dataset saved in ./data/raw/api/{mnemonic}.csv")
# Out:
# downloading c2021ts007a
# trying records 0 - 1000000
#    DATE GEOGRAPHY_CODE       C2021_AGE_19_NAME  OBS_VALUE
# 0  2021      E00060274                   Total        274
# 1  2021      E00060274  Aged 4 years and under         26
# 2  2021      E00060274       Aged 5 to 9 years         26
# 3  2021      E00060274     Aged 10 to 14 years         27
# 4  2021      E00060274     Aged 15 to 19 years         15
# chunk 0 saved in ./data/raw/api/c2021ts007a_00.csv
# trying records 1000000 - 2000000
#    DATE GEOGRAPHY_CODE    C2021_AGE_19_NAME  OBS_VALUE
# 0  2021      E00068884  Aged 50 to 54 years         36
# 1  2021      E00068884  Aged 55 to 59 years         14
# 2  2021      E00068884  Aged 60 to 64 years          6
# 3  2021      E00068884  Aged 65 to 69 years          5
# 4  2021      E00068884  Aged 70 to 74 years          1
# chunk 1 saved in ./data/raw/api/c2021ts007a_01.csv
# trying records 2000000 - 3000000
#    DATE GEOGRAPHY_CODE    C2021_AGE_19_NAME  OBS_VALUE
# 0  2021      E00000222  Aged 10 to 14 years         32
# 1  2021      E00000222  Aged 15 to 19 years         28
# 2  2021      E00000222  Aged 20 to 24 years         29
# 3  2021      E00000222  Aged 25 to 29 years         24
# 4  2021      E00000222  Aged 30 to 34 years         52
# chunk 2 saved in ./data/raw/api/c2021ts007a_02.csv
# trying records 3000000 - 4000000

# %%
api_url = f'/api/v01/dataset/{c2021_datasets_metadata_df["id"][0]}.data.csv?geography=MAKE|myarea|E00000001;E00000003&measures=20100&recordlimit=100'
url = root_url + api_url
print(url)
batch_df = pd.read_csv(url)
batch_df.to_csv('test.csv')
# Out:
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2020_1.data.csv?geography=MAKE|myarea|E00000001;E00000003&measures=20100&recordlimit=100

# %%
london_code = list(cities_df[cities_df['name'] == 'London']['geog_code'])[0]
# london_code
c2021_london = c2021_lookup[c2021_lookup['TCITY15CD'] == london_code]
c2021_london
# Out:
#           OA21CD  TCITY15CD TCITY15NM     FID
# 0      E00000001  J01000055    London     101
# 1      E00000003  J01000055    London     102
# 2      E00000005  J01000055    London     103
# 3      E00000007  J01000055    London     104
# 4      E00000010  J01000055    London     105
# ...          ...        ...       ...     ...
# 80918  E00176332  J01000055    London  170973
# 80919  E00176333  J01000055    London  170974
# 80920  E00183720  J01000055    London  170975
# 80921  E00176335  J01000055    London  170976
# 80922  E00183715  J01000055    London  170977
#
# [24927 rows x 4 columns]

# %%
c2021_london_oa_list = list(c2021_london['OA21CD'])
c2021_london_oa_list
# Out:
# ['E00000001',
#  'E00000003',
#  'E00000005',
#  'E00000007',
#  'E00000010',
#  'E00190349',
#  'E00000013',
#  'E00190349',
#  'E00190348',
#  'E00190348',
#  'E00000018',
#  'E00000019',
#  'E00000020',
#  'E00000021',
#  'E00000022',
#  'E00000023',
#  'E00000024',
#  'E00000025',
#  'E00190440',
#  'E00190407',
#  'E00000028',
#  'E00000029',
#  'E00000030',
#  'E00000031',
#  'E00000032',
#  'E00190458',
#  'E00000037',
#  'E00000038',
#  'E00000039',
#  'E00000040',
#  'E00000041',
#  'E00000042',
#  'E00000043',
#  'E00000045',
#  'E00000046',
#  'E00000048',
#  'E00000049',
#  'E00000050',
#  'E00000051',
#  'E00000052',
#  'E00000053',
#  'E00000054',
#  'E00000055',
#  'E00000056',
#  'E00000057',
#  'E00000059',
#  'E00000060',
#  'E00000061',
#  'E00185746',
#  'E00000063',
#  'E00000115',
#  'E00000116',
#  'E00000117',
#  'E00000118',
#  'E00000119',
#  'E00000120',
#  'E00000121',
#  'E00000122',
#  'E00000123',
#  'E00000124',
#  'E00000125',
#  'E00185673',
#  'E00185721',
#  'E00000128',
#  'E00000129',
#  'E00000130',
#  'E00000131',
#  'E00000132',
#  'E00000133',
#  'E00000134',
#  'E00000135',
#  'E00000136',
#  'E00000137',
#  'E00000138',
#  'E00000139',
#  'E00000140',
#  'E00000141',
#  'E00000142',
#  'E00000143',
#  'E00000144',
#  'E00000145',
#  'E00000146',
#  'E00000147',
#  'E00000148',
#  'E00000149',
#  'E00000150',
#  'E00000151',
#  'E00000152',
#  'E00000153',
#  'E00000154',
#  'E00000155',
#  'E00000156',
#  'E00000157',
#  'E00000158',
#  'E00000159',
#  'E00000160',
#  'E00000161',
#  'E00000162',
#  'E00000163',
#  'E00000164',
#  'E00000215',
#  'E00000216',
#  'E00000217',
#  'E00000218',
#  'E00000219',
#  'E00000220',
#  'E00000221',
#  'E00000222',
#  'E00000223',
#  'E00000224',
#  'E00000225',
#  'E00000226',
#  'E00000227',
#  'E00000228',
#  'E00000229',
#  'E00000230',
#  'E00000231',
#  'E00000232',
#  'E00000234',
#  'E00185665',
#  'E00000236',
#  'E00000237',
#  'E00000238',
#  'E00185666',
#  'E00000240',
#  'E00185665',
#  'E00185671',
#  'E00000243',
#  'E00000244',
#  'E00000245',
#  'E00000246',
#  'E00000247',
#  'E00185667',
#  'E00000249',
#  'E00185667',
#  'E00000251',
#  'E00000252',
#  'E00000253',
#  'E00185666',
#  'E00000255',
#  'E00000256',
#  'E00000257',
#  'E00000258',
#  'E00000259',
#  'E00000260',
#  'E00000261',
#  'E00000263',
#  'E00185666',
#  'E00000265',
#  'E00000266',
#  'E00000318',
#  'E00000319',
#  'E00000320',
#  'E00000321',
#  'E00000322',
#  'E00000323',
#  'E00000324',
#  'E00000325',
#  'E00000326',
#  'E00000327',
#  'E00000328',
#  'E00000329',
#  'E00000330',
#  'E00000331',
#  'E00000332',
#  'E00000333',
#  'E00000334',
#  'E00000335',
#  'E00000336',
#  'E00000337',
#  'E00000338',
#  'E00185718',
#  'E00000340',
#  'E00000341',
#  'E00000342',
#  'E00000343',
#  'E00000344',
#  'E00000345',
#  'E00000346',
#  'E00000347',
#  'E00000348',
#  'E00000349',
#  'E00000350',
#  'E00000351',
#  'E00185806',
#  'E00000353',
#  'E00000354',
#  'E00000355',
#  'E00000356',
#  'E00000357',
#  'E00000358',
#  'E00000360',
#  'E00000361',
#  'E00000362',
#  'E00000363',
#  'E00000364',
#  'E00000365',
#  'E00000366',
#  'E00000367',
#  'E00000368',
#  'E00000165',
#  'E00000166',
#  'E00000167',
#  'E00000168',
#  'E00000169',
#  'E00000170',
#  'E00000171',
#  'E00000172',
#  'E00000173',
#  'E00000174',
#  'E00000175',
#  'E00000176',
#  'E00000177',
#  'E00000178',
#  'E00000179',
#  'E00000180',
#  'E00000181',
#  'E00000182',
#  'E00000183',
#  'E00000184',
#  'E00000185',
#  'E00000186',
#  'E00000187',
#  'E00000188',
#  'E00000189',
#  'E00000190',
#  'E00000191',
#  'E00000192',
#  'E00000193',
#  'E00000194',
#  'E00000195',
#  'E00000196',
#  'E00000197',
#  'E00000198',
#  'E00000199',
#  'E00000200',
#  'E00000201',
#  'E00000202',
#  'E00000203',
#  'E00000204',
#  'E00000205',
#  'E00000206',
#  'E00000207',
#  'E00000208',
#  'E00000209',
#  'E00000210',
#  'E00000211',
#  'E00000212',
#  'E00000213',
#  'E00000214',
#  'E00000267',
#  'E00000268',
#  'E00000269',
#  'E00000270',
#  'E00000271',
#  'E00000272',
#  'E00000273',
#  'E00000274',
#  'E00000275',
#  'E00000276',
#  'E00000277',
#  'E00000278',
#  'E00000279',
#  'E00000280',
#  'E00000282',
#  'E00000283',
#  'E00000284',
#  'E00000285',
#  'E00000286',
#  'E00000287',
#  'E00000288',
#  'E00000289',
#  'E00000290',
#  'E00000291',
#  'E00000292',
#  'E00000293',
#  'E00000294',
#  'E00000295',
#  'E00000296',
#  'E00000297',
#  'E00000298',
#  'E00000299',
#  'E00000300',
#  'E00000301',
#  'E00000302',
#  'E00000303',
#  'E00000304',
#  'E00000305',
#  'E00000306',
#  'E00000307',
#  'E00000308',
#  'E00000309',
#  'E00000310',
#  'E00000311',
#  'E00000312',
#  'E00000313',
#  'E00000314',
#  'E00000315',
#  'E00000316',
#  'E00000317',
#  'E00000064',
#  'E00185694',
#  'E00000066',
#  'E00000067',
#  'E00000068',
#  'E00000069',
#  'E00000070',
#  'E00000071',
#  'E00000072',
#  'E00000073',
#  'E00000074',
#  'E00000075',
#  'E00000076',
#  'E00000077',
#  'E00000078',
#  'E00000079',
#  'E00000080',
#  'E00000081',
#  'E00000082',
#  'E00000083',
#  'E00000084',
#  'E00000085',
#  'E00000086',
#  'E00000087',
#  'E00000088',
#  'E00000089',
#  'E00000090',
#  'E00000091',
#  'E00000092',
#  'E00000093',
#  'E00000094',
#  'E00000095',
#  'E00000096',
#  'E00000097',
#  'E00000098',
#  'E00000099',
#  'E00000100',
#  'E00000101',
#  'E00000102',
#  'E00000103',
#  'E00000104',
#  'E00000106',
#  'E00000107',
#  'E00000108',
#  'E00000109',
#  'E00000110',
#  'E00000111',
#  'E00000112',
#  'E00000113',
#  'E00000114',
#  'E00000369',
#  'E00000370',
#  'E00000371',
#  'E00000372',
#  'E00000373',
#  'E00000374',
#  'E00000375',
#  'E00000376',
#  'E00000377',
#  'E00000378',
#  'E00000379',
#  'E00000380',
#  'E00000381',
#  'E00000382',
#  'E00000383',
#  'E00000384',
#  'E00000385',
#  'E00000386',
#  'E00000387',
#  'E00000388',
#  'E00000389',
#  'E00000390',
#  'E00000391',
#  'E00000392',
#  'E00000393',
#  'E00000394',
#  'E00000395',
#  'E00000396',
#  'E00000397',
#  'E00000398',
#  'E00000399',
#  'E00000400',
#  'E00000401',
#  'E00000402',
#  'E00000403',
#  'E00000404',
#  'E00000405',
#  'E00000406',
#  'E00000407',
#  'E00000408',
#  'E00000409',
#  'E00000410',
#  'E00000411',
#  'E00000412',
#  'E00000413',
#  'E00000414',
#  'E00000415',
#  'E00000416',
#  'E00000417',
#  'E00000418',
#  'E00000520',
#  'E00000521',
#  'E00000522',
#  'E00000523',
#  'E00000524',
#  'E00000525',
#  'E00000526',
#  'E00000527',
#  'E00000528',
#  'E00000529',
#  'E00000530',
#  'E00000531',
#  'E00000532',
#  'E00000533',
#  'E00000534',
#  'E00000535',
#  'E00000536',
#  'E00000537',
#  'E00000538',
#  'E00000539',
#  'E00000540',
#  'E00000541',
#  'E00000542',
#  'E00000543',
#  'E00000544',
#  'E00000545',
#  'E00185837',
#  'E00000547',
#  'E00000548',
#  'E00000549',
#  'E00000550',
#  'E00000551',
#  'E00000552',
#  'E00000553',
#  'E00000554',
#  'E00000555',
#  'E00000556',
#  'E00000557',
#  'E00000558',
#  'E00000559',
#  'E00000560',
#  'E00000561',
#  'E00000562',
#  'E00000563',
#  'E00000564',
#  'E00000565',
#  'E00000566',
#  'E00000567',
#  'E00000568',
#  'E00000569',
#  'E00000419',
#  'E00000420',
#  'E00000421',
#  'E00000422',
#  'E00000423',
#  'E00000424',
#  'E00000425',
#  'E00000426',
#  'E00000427',
#  'E00000428',
#  'E00000429',
#  'E00000430',
#  'E00000431',
#  'E00000432',
#  'E00000433',
#  'E00000434',
#  'E00000435',
#  'E00000436',
#  'E00000437',
#  'E00000438',
#  'E00000439',
#  'E00000440',
#  'E00000441',
#  'E00000442',
#  'E00000443',
#  'E00000444',
#  'E00000445',
#  'E00000446',
#  'E00000447',
#  'E00000448',
#  'E00000449',
#  'E00000450',
#  'E00000451',
#  'E00185683',
#  'E00000453',
#  'E00000454',
#  'E00000455',
#  'E00000456',
#  'E00000457',
#  'E00185668',
#  'E00185669',
#  'E00185669',
#  'E00000461',
#  'E00000462',
#  'E00000463',
#  'E00000464',
#  'E00000465',
#  'E00000466',
#  'E00000467',
#  'E00000468',
#  'E00000570',
#  'E00000571',
#  'E00000572',
#  'E00000573',
#  'E00000574',
#  'E00000575',
#  'E00000576',
#  'E00000577',
#  'E00000578',
#  'E00000579',
#  'E00000580',
#  'E00000581',
#  'E00178878',
#  'E00000583',
#  'E00000584',
#  'E00000585',
#  'E00000586',
#  'E00000587',
#  'E00000588',
#  'E00000589',
#  'E00000590',
#  'E00000591',
#  'E00000592',
#  'E00000593',
#  'E00000594',
#  'E00000595',
#  'E00000596',
#  'E00000597',
#  'E00000598',
#  'E00000599',
#  'E00000600',
#  'E00000601',
#  'E00000602',
#  'E00000603',
#  'E00000604',
#  'E00000605',
#  'E00000606',
#  'E00000607',
#  'E00000608',
#  'E00000609',
#  'E00000610',
#  'E00000611',
#  'E00000612',
#  'E00000613',
#  'E00000614',
#  'E00000615',
#  'E00000616',
#  'E00000617',
#  'E00000618',
#  'E00000619',
#  'E00000723',
#  'E00000724',
#  'E00000725',
#  'E00000726',
#  'E00000727',
#  'E00000728',
#  'E00178723',
#  'E00000730',
#  'E00178893',
#  'E00000732',
#  'E00178891',
#  'E00178894',
#  'E00178876',
#  'E00000737',
#  'E00000738',
#  'E00000739',
#  'E00000672',
#  'E00000740',
#  'E00000742',
#  'E00000743',
#  'E00178803',
#  'E00000745',
#  'E00000746',
#  'E00000747',
#  'E00000748',
#  'E00000749',
#  'E00000750',
#  'E00000751',
#  'E00000752',
#  'E00000754',
#  'E00000755',
#  'E00000756',
#  'E00000757',
#  'E00000758',
#  'E00178838',
#  'E00000761',
#  'E00178800',
#  'E00000763',
#  'E00178820',
#  'E00178826',
#  'E00178882',
#  'E00000767',
#  'E00000768',
#  'E00000769',
#  'E00000770',
#  'E00000771',
#  'E00000772',
#  'E00000773',
#  'E00000774',
#  'E00000775',
#  'E00000776',
#  'E00000620',
#  'E00000674',
#  'E00000675',
#  'E00000676',
#  'E00000677',
#  'E00000678',
#  'E00000679',
#  'E00178756',
#  'E00000681',
#  'E00000682',
#  'E00000683',
#  'E00000684',
#  'E00000685',
#  'E00000686',
#  'E00000687',
#  'E00000688',
#  'E00000689',
#  'E00000690',
#  'E00000691',
#  'E00000692',
#  'E00000693',
#  'E00000622',
#  'E00000694',
#  'E00178854',
#  'E00000695',
#  'E00000624',
#  'E00178811',
#  'E00000625',
#  'E00000697',
#  'E00000626',
#  'E00000698',
#  'E00000627',
#  'E00000699',
#  'E00000628',
#  'E00000700',
#  'E00000629',
#  'E00000701',
#  'E00000630',
#  'E00000702',
#  'E00000631',
#  'E00000703',
#  'E00000632',
#  'E00000704',
#  'E00000633',
#  'E00000705',
#  'E00000706',
#  'E00000707',
#  'E00000708',
#  'E00000709',
#  'E00000710',
#  'E00000711',
#  'E00000712',
#  'E00000713',
#  'E00000714',
#  'E00000715',
#  'E00000716',
#  'E00000717',
#  'E00000718',
#  'E00000719',
#  'E00000720',
#  'E00000721',
#  'E00000722',
#  'E00000634',
#  'E00000635',
#  'E00000636',
#  'E00000637',
#  'E00000638',
#  'E00000640',
#  'E00000641',
#  'E00000642',
#  'E00000643',
#  'E00000644',
#  'E00000645',
#  'E00000646',
#  'E00000647',
#  'E00000648',
#  'E00000649',
#  'E00000650',
#  'E00000651',
#  'E00000652',
#  'E00000653',
#  'E00000654',
#  'E00000655',
#  'E00000656',
#  'E00000657',
#  'E00000658',
#  'E00000659',
#  'E00000660',
#  'E00000661',
#  'E00000662',
#  'E00000663',
#  'E00000664',
#  'E00178814',
#  'E00000666',
#  'E00000667',
#  'E00000668',
#  'E00000669',
#  'E00000670',
#  'E00000671',
#  'E00000777',
#  'E00000778',
#  'E00000779',
#  'E00000780',
#  'E00000781',
#  'E00000782',
#  'E00000783',
#  'E00000785',
#  'E00000786',
#  'E00000787',
#  'E00000788',
#  'E00000789',
#  'E00000790',
#  'E00000791',
#  'E00000792',
#  'E00000793',
#  'E00000794',
#  'E00000795',
#  'E00000796',
#  'E00000797',
#  'E00000798',
#  'E00000799',
#  'E00000800',
#  'E00000801',
#  'E00000802',
#  'E00000803',
#  'E00000804',
#  'E00000805',
#  'E00000806',
#  'E00000807',
#  'E00000808',
#  'E00000809',
#  'E00000810',
#  'E00000811',
#  'E00000812',
#  'E00000813',
#  'E00000814',
#  'E00000815',
#  'E00000816',
#  'E00000817',
#  'E00000818',
#  'E00000819',
#  'E00000820',
#  'E00000821',
#  'E00000822',
#  'E00000823',
#  'E00000824',
#  'E00000825',
#  'E00000826',
#  'E00000827',
#  'E00000469',
#  'E00000470',
#  'E00000471',
#  'E00000472',
#  'E00185668',
#  'E00000475',
#  'E00000476',
#  'E00000477',
#  'E00000478',
#  'E00000479',
#  'E00000480',
#  'E00000481',
#  'E00000482',
#  'E00000483',
#  'E00000484',
#  'E00000485',
#  'E00185832',
#  'E00000487',
#  'E00000488',
#  'E00000489',
#  'E00000490',
#  'E00000491',
#  'E00000492',
#  'E00000493',
#  'E00000494',
#  'E00000495',
#  'E00000496',
#  'E00000497',
#  'E00000498',
#  'E00000499',
#  'E00000500',
#  'E00000501',
#  'E00000502',
#  'E00000503',
#  'E00000504',
#  'E00000505',
#  'E00000506',
#  'E00000507',
#  'E00000508',
#  'E00000509',
#  'E00000510',
#  'E00000511',
#  'E00000512',
#  'E00000513',
#  'E00000514',
#  'E00000515',
#  'E00000516',
#  'E00000517',
#  'E00000518',
#  'E00000519',
#  'E00001128',
#  'E00001129',
#  'E00001130',
#  'E00001131',
#  'E00001132',
#  'E00001133',
#  'E00001134',
#  'E00001135',
#  'E00001136',
#  'E00001137',
#  'E00001138',
#  'E00001139',
#  'E00000878',
#  'E00001140',
#  'E00001141',
#  'E00178736',
#  'E00001142',
#  'E00000880',
#  'E00001028',
#  'E00001143',
#  'E00000881',
#  'E00001029',
#  'E00001144',
#  'E00000882',
#  'E00001030',
#  'E00000828',
#  'E00001145',
#  'E00000883',
#  'E00000928',
#  'E00001031',
#  'E00000829',
#  'E00001146',
#  'E00000884',
#  'E00000929',
#  'E00001032',
#  'E00000830',
#  'E00001147',
#  'E00000885',
#  'E00000930',
#  'E00001033',
#  'E00000831',
#  'E00001148',
#  'E00000886',
#  'E00000931',
#  'E00001034',
#  'E00000832',
#  'E00001149',
#  'E00000887',
#  'E00000932',
#  'E00001035',
#  'E00000833',
#  'E00001150',
#  'E00000888',
#  'E00178760',
#  'E00001036',
#  'E00000834',
#  'E00001151',
#  'E00000889',
#  'E00000934',
#  'E00001037',
#  'E00000835',
#  'E00001152',
#  'E00000890',
#  'E00000935',
#  'E00001038',
#  'E00000836',
#  'E00001153',
#  'E00000891',
#  'E00000936',
#  'E00001039',
#  'E00001040',
#  'E00001041',
#  'E00001042',
#  'E00001043',
#  'E00001044',
#  'E00001045',
#  'E00001046',
#  'E00001047',
#  'E00001048',
#  'E00001049',
#  'E00001050',
#  'E00001051',
#  'E00001052',
#  'E00001053',
#  'E00001054',
#  'E00001055',
#  'E00001056',
#  'E00001057',
#  'E00001058',
#  'E00001059',
#  'E00001060',
#  'E00001061',
#  'E00001062',
#  'E00001063',
#  'E00001064',
#  'E00001065',
#  'E00001066',
#  'E00001067',
#  'E00001068',
#  'E00001069',
#  'E00178740',
#  'E00001071',
#  'E00001072',
#  'E00001073',
#  'E00001074',
#  'E00001075',
#  'E00001076',
#  'E00001077',
#  'E00000937',
#  'E00000938',
#  'E00000939',
#  'E00000940',
#  'E00000941',
#  'E00178725',
#  'E00000943',
#  'E00000944',
#  'E00000945',
#  'E00178725',
#  'E00000947',
#  'E00000948',
#  'E00000949',
#  'E00000950',
#  'E00000951',
#  'E00000952',
#  'E00000953',
#  'E00000954',
#  'E00000955',
#  'E00000956',
#  'E00178781',
#  'E00000958',
#  'E00000959',
#  'E00000960',
#  'E00000892',
#  'E00000961',
#  'E00001154',
#  'E00000837',
#  'E00000893',
#  'E00000962',
#  'E00001155',
#  'E00000838',
#  'E00000894',
#  'E00000963',
#  'E00001156',
#  'E00000839',
#  'E00000895',
#  'E00000964',
#  'E00001157',
#  'E00001158',
#  'E00001159',
#  'E00001160',
#  'E00001161',
#  'E00001162',
#  'E00001163',
#  'E00001164',
#  'E00001165',
#  'E00001166',
#  'E00001167',
#  'E00001168',
#  'E00001169',
#  'E00001170',
#  'E00001171',
#  'E00001172',
#  'E00001173',
#  'E00001174',
#  'E00001175',
#  'E00001176',
#  'E00001177',
#  'E00000896',
#  'E00000897',
#  'E00000898',
#  'E00000899',
#  'E00000900',
#  'E00000901',
#  'E00000902',
#  'E00000903',
#  'E00000904',
#  'E00000905',
#  'E00000906',
#  'E00000907',
#  'E00000908',
#  'E00000909',
#  'E00000910',
#  'E00000911',
#  'E00000912',
#  'E00000913',
#  'E00000914',
#  'E00000840',
#  'E00000915',
#  'E00000841',
#  'E00000965',
#  'E00000916',
#  'E00000842',
#  'E00000966',
#  'E00000917',
#  'E00000843',
#  'E00000967',
#  'E00000918',
#  'E00000844',
#  'E00000968',
#  'E00000919',
#  ...]

# %%
for dataset in c2021_datasets_metadata_list:
    id = dataset['id']
    mnemonic = dataset['mnemonic']
    geoglevel = dataset['geoglevel'].split(',')
    if 'oa' not in geoglevel:
        continue

    print("downloading", mnemonic, "for london")
    api_url = f'/api/v01/dataset/{id}.data.csv?recordlimit=0'
    url = root_url + api_url
    try:
        dataset_df = pd.read_csv(url)
    except:
        time.sleep(60)
        dataset_df = pd.read_csv(url)
    try:
        stat_name = dataset_df.filter(regex='^C2021.*NAME$', axis=1).columns[0].lower()
    except:
        stat_name = dataset_df.filter(regex='^CELL.*NAME$', axis=1).columns[0].lower()

    api_url = f'/api/v01/dataset/{id}.data.csv?recordlimit=0&select=date,geography_code,{stat_name},obs_value'
    url = root_url + api_url
    try:
        dataset_df = pd.read_csv(url)
    except:
        time.sleep(60)
        dataset_df = pd.read_csv(url)

    for oa in c2021_london_oa_list:
        api_url = f'/api/v01/dataset/{id}.data.csv?geography={oa}&measures=20100&select=date,geography_code,{stat_name},obs_value'
        url = root_url + api_url

        try:
            batch_df = pd.read_csv(url)
        except:
            time.sleep(60)
            batch_df = pd.read_csv(url)

        # display(batch_df.head())

        # if len(batch_df) == 0:
        #     break

        # dest_file = f'./data/raw/api/{mnemonic}_{i:02}.csv'
        # batch_df.to_csv(dest_file)
        # print(f"chunk {i} saved in {dest_file}")

        dataset_df = pd.concat([dataset_df, batch_df])

    # for oa in oa21:
    #     api_url = f'/api/v01/dataset/{id}.data.csv?geography={oa}&measures=20100&select=date,geography_code,{stat_name},obs_value'
    #     url = root_url + api_url
    #     oa_df = pd.read_csv(url)
    #     dataset_df = pd.concat([dataset_df, oa_df])

    dataset_df.to_csv(f'./data/raw/api/{mnemonic}_london.csv')
    print(f"dataset saved in ./data/raw/api/{mnemonic}_london.csv")
# Out:
# downloading c2021ts007a for london
