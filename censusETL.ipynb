# %%
import requests
import json
import pandas as pd
import time

# %%
root_url = 'http://www.nomisweb.co.uk'

# api_url = '/api/v01/dataset/NM_1_1/geography.def.sdmx.json'
# api_url = '/api/v01/dataset/NM_1_1/geography/2092957697.def.sdmx.json' # list of all geography sets in UK
api_url = '/api/v01/dataset/NM_1_1/geography/2092957697TYPE441.def.sdmx.json' # major towns and cities within United Kingdom

url = root_url + api_url

response = requests.get(url)
json.loads(response.text)
# Out:
# {'structure': {'codelists': {'codelist': [{'agencyid': 'NOMIS',
#      'id': 'CL_1_1_GEOGRAPHY',
#      'code': [{'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000001', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Barnsley', 'lang': 'en'},
#        'value': 1849688065},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000002', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Basildon', 'lang': 'en'},
#        'value': 1849688066},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000003', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Basingstoke', 'lang': 'en'},
#        'value': 1849688067},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000004', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Bath', 'lang': 'en'},
#        'value': 1849688068},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000005', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Bedford', 'lang': 'en'},
#        'value': 1849688069},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000006', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Birkenhead', 'lang': 'en'},
#        'value': 1849688070},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000007', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Birmingham', 'lang': 'en'},
#        'value': 1849688071},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000008', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Blackburn', 'lang': 'en'},
#        'value': 1849688072},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000009', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Blackpool', 'lang': 'en'},
#        'value': 1849688073},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000010', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Bolton', 'lang': 'en'},
#        'value': 1849688074},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000011', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Bournemouth', 'lang': 'en'},
#        'value': 1849688075},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000012', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Bracknell', 'lang': 'en'},
#        'value': 1849688076},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000013', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Bradford', 'lang': 'en'},
#        'value': 1849688077},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000014', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Brighton and Hove', 'lang': 'en'},
#        'value': 1849688078},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000015', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Bristol', 'lang': 'en'},
#        'value': 1849688079},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000016', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Burnley', 'lang': 'en'},
#        'value': 1849688080},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000017', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Burton upon Trent', 'lang': 'en'},
#        'value': 1849688081},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000018', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Bury', 'lang': 'en'},
#        'value': 1849688082},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000019', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Cambridge', 'lang': 'en'},
#        'value': 1849688083},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000020', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Cardiff', 'lang': 'en'},
#        'value': 1849688084},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000021', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Carlisle', 'lang': 'en'},
#        'value': 1849688085},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000022', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Chatham', 'lang': 'en'},
#        'value': 1849688086},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000023', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Chelmsford', 'lang': 'en'},
#        'value': 1849688087},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000024', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Cheltenham', 'lang': 'en'},
#        'value': 1849688088},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000025', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Chester', 'lang': 'en'},
#        'value': 1849688089},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000026', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Chesterfield', 'lang': 'en'},
#        'value': 1849688090},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000027', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Colchester', 'lang': 'en'},
#        'value': 1849688091},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000028', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Coventry', 'lang': 'en'},
#        'value': 1849688092},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000029', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Crawley', 'lang': 'en'},
#        'value': 1849688093},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000030', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Darlington', 'lang': 'en'},
#        'value': 1849688094},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000031', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Derby', 'lang': 'en'},
#        'value': 1849688095},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000032', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Doncaster', 'lang': 'en'},
#        'value': 1849688096},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000033', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Dudley', 'lang': 'en'},
#        'value': 1849688097},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000034', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Eastbourne', 'lang': 'en'},
#        'value': 1849688098},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000035', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Exeter', 'lang': 'en'},
#        'value': 1849688099},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000036', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Gateshead', 'lang': 'en'},
#        'value': 1849688100},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000037', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Gillingham', 'lang': 'en'},
#        'value': 1849688101},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000038', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Gloucester', 'lang': 'en'},
#        'value': 1849688102},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000039', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Grimsby', 'lang': 'en'},
#        'value': 1849688103},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000040', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Guildford', 'lang': 'en'},
#        'value': 1849688104},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000041', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Halifax', 'lang': 'en'},
#        'value': 1849688105},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000042', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Harlow', 'lang': 'en'},
#        'value': 1849688106},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000043', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Harrogate', 'lang': 'en'},
#        'value': 1849688107},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000044', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Hartlepool', 'lang': 'en'},
#        'value': 1849688108},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000045', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Hastings', 'lang': 'en'},
#        'value': 1849688109},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000046', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Hemel Hempstead', 'lang': 'en'},
#        'value': 1849688110},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000047', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'High Wycombe', 'lang': 'en'},
#        'value': 1849688111},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000048', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Huddersfield', 'lang': 'en'},
#        'value': 1849688112},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000049', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Ipswich', 'lang': 'en'},
#        'value': 1849688113},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000050', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Kingston upon Hull', 'lang': 'en'},
#        'value': 1849688114},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000051', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Leeds', 'lang': 'en'},
#        'value': 1849688115},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000052', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Leicester', 'lang': 'en'},
#        'value': 1849688116},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000053', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Lincoln', 'lang': 'en'},
#        'value': 1849688117},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000054', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Liverpool', 'lang': 'en'},
#        'value': 1849688118},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000055', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'London', 'lang': 'en'},
#        'value': 1849688119},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000056', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Luton', 'lang': 'en'},
#        'value': 1849688120},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000057', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Maidstone', 'lang': 'en'},
#        'value': 1849688121},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000058', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Manchester', 'lang': 'en'},
#        'value': 1849688122},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000059', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Mansfield', 'lang': 'en'},
#        'value': 1849688123},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000060', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Middlesbrough', 'lang': 'en'},
#        'value': 1849688124},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000061', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Milton Keynes', 'lang': 'en'},
#        'value': 1849688125},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000062', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Newcastle upon Tyne', 'lang': 'en'},
#        'value': 1849688126},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000063', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Newcastle-under-Lyme', 'lang': 'en'},
#        'value': 1849688127},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000064', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Newport', 'lang': 'en'},
#        'value': 1849688128},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000065', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Northampton', 'lang': 'en'},
#        'value': 1849688129},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000066', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Norwich', 'lang': 'en'},
#        'value': 1849688130},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000067', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Nottingham', 'lang': 'en'},
#        'value': 1849688131},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000068', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Nuneaton', 'lang': 'en'},
#        'value': 1849688132},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000069', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Oldham', 'lang': 'en'},
#        'value': 1849688133},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000070', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Oxford', 'lang': 'en'},
#        'value': 1849688134},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000071', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Peterborough', 'lang': 'en'},
#        'value': 1849688135},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000072', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Plymouth', 'lang': 'en'},
#        'value': 1849688136},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000073', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Poole', 'lang': 'en'},
#        'value': 1849688137},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000074', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Portsmouth', 'lang': 'en'},
#        'value': 1849688138},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000075', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Preston', 'lang': 'en'},
#        'value': 1849688139},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000076', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Reading', 'lang': 'en'},
#        'value': 1849688140},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000077', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Redditch', 'lang': 'en'},
#        'value': 1849688141},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000078', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Rochdale', 'lang': 'en'},
#        'value': 1849688142},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000079', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Rotherham', 'lang': 'en'},
#        'value': 1849688143},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000080', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Salford', 'lang': 'en'},
#        'value': 1849688144},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000081', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Scunthorpe', 'lang': 'en'},
#        'value': 1849688145},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000082', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Sheffield', 'lang': 'en'},
#        'value': 1849688146},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000083', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Shrewsbury', 'lang': 'en'},
#        'value': 1849688147},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000084', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Slough', 'lang': 'en'},
#        'value': 1849688148},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000085', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Solihull', 'lang': 'en'},
#        'value': 1849688149},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000086', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'South Shields', 'lang': 'en'},
#        'value': 1849688150},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000087', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Southampton', 'lang': 'en'},
#        'value': 1849688151},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000088', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Southend-on-Sea', 'lang': 'en'},
#        'value': 1849688152},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000089', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Southport', 'lang': 'en'},
#        'value': 1849688153},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000090', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'St Albans', 'lang': 'en'},
#        'value': 1849688154},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000091', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'St Helens', 'lang': 'en'},
#        'value': 1849688155},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000092', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Stevenage', 'lang': 'en'},
#        'value': 1849688156},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000093', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Stockport', 'lang': 'en'},
#        'value': 1849688157},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000094', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Stockton-on-Tees', 'lang': 'en'},
#        'value': 1849688158},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000095', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Stoke-on-Trent', 'lang': 'en'},
#        'value': 1849688159},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000096', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Sunderland', 'lang': 'en'},
#        'value': 1849688160},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000097', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Sutton Coldfield', 'lang': 'en'},
#        'value': 1849688161},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000098', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Swansea', 'lang': 'en'},
#        'value': 1849688162},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000099', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Swindon', 'lang': 'en'},
#        'value': 1849688163},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000100', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Telford', 'lang': 'en'},
#        'value': 1849688164},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000101', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Wakefield', 'lang': 'en'},
#        'value': 1849688165},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000102', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Walsall', 'lang': 'en'},
#        'value': 1849688166},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000103', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Warrington', 'lang': 'en'},
#        'value': 1849688167},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000104', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Watford', 'lang': 'en'},
#        'value': 1849688168},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000105', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'West Bromwich', 'lang': 'en'},
#        'value': 1849688169},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000106', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Weston-Super-Mare', 'lang': 'en'},
#        'value': 1849688170},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000107', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Wigan', 'lang': 'en'},
#        'value': 1849688171},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000108', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Woking', 'lang': 'en'},
#        'value': 1849688172},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000109', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Wolverhampton', 'lang': 'en'},
#        'value': 1849688173},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000110', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Worcester', 'lang': 'en'},
#        'value': 1849688174},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000111', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'Worthing', 'lang': 'en'},
#        'value': 1849688175},
#       {'annotations': {'annotation': [{'annotationtext': 'major towns and cities',
#           'annotationtitle': 'TypeName'},
#          {'annotationtext': 441, 'annotationtitle': 'TypeCode'},
#          {'annotationtext': 'J01000112', 'annotationtitle': 'GeogCode'}]},
#        'parentcode': 2092957699,
#        'description': {'value': 'York', 'lang': 'en'},
#        'value': 1849688176}],
#      'name': {'value': 'geography', 'lang': 'en'},
#      'uri': ''}]},
#   'header': {'id': 'NM_1_1',
#    'prepared': '2024-03-23T09:16:57Z',
#    'sender': {'contact': {'email': 'support@nomisweb.co.uk',
#      'name': 'Nomis',
#      'telephone': '+44(0) 191 3342680',
#      'uri': 'https://www.nomisweb.co.uk'},
#     'id': 'NOMIS'},
#    'test': 'false'},
#   'xmlns': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message',
#   'common': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common',
#   'structure': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure',
#   'xsi': 'http://www.w3.org/2001/XMLSchema-instance',
#   'schemalocation': 'http://sdmx.org/docs/2_0/SDMXMessage.xsd'}}

# %%
cities_json = json.loads(response.text)
cities_json = cities_json['structure']['codelists']['codelist'][0]['code']
cities_list = []
for city in cities_json:
    geog_code = city['annotations']['annotation'][2]['annotationtext']
    name = city['description']['value']
    id = city['value']
    city_dict = {
        'id': id,
        'name': name,
        'geog_code': geog_code
    }
    cities_list.append(city_dict)
cities_df = pd.DataFrame(cities_list)
cities_df
# Out:
#              id           name  geog_code
# 0    1849688065       Barnsley  J01000001
# 1    1849688066       Basildon  J01000002
# 2    1849688067    Basingstoke  J01000003
# 3    1849688068           Bath  J01000004
# 4    1849688069        Bedford  J01000005
# ..          ...            ...        ...
# 107  1849688172         Woking  J01000108
# 108  1849688173  Wolverhampton  J01000109
# 109  1849688174      Worcester  J01000110
# 110  1849688175       Worthing  J01000111
# 111  1849688176           York  J01000112
#
# [112 rows x 3 columns]

# %%
for city in cities_list[:2]:
    id = city['geog_code']
    api_url = f'/api/v01/dataset/NM_1_1/geography/{id}.def.sdmx.json'
    url = root_url + api_url
    response = requests.get(url)
    print(json.loads(response.text))
# Out:
# {'structure': {'codelists': {'codelist': [{'agencyid': 'NOMIS', 'id': 'CL_1_1_GEOGRAPHY', 'code': [{'annotations': {'annotation': [{'annotationtext': 'major towns and cities', 'annotationtitle': 'TypeName'}, {'annotationtext': 441, 'annotationtitle': 'TypeCode'}, {'annotationtext': 1849688065, 'annotationtitle': 'NomisKey'}]}, 'parentcode': 'E92000001', 'description': {'value': 'Barnsley', 'lang': 'en'}, 'value': 'J01000001'}], 'name': {'value': 'geography', 'lang': 'en'}, 'uri': ''}]}, 'header': {'id': 'NM_1_1', 'prepared': '2024-03-23T09:16:59Z', 'sender': {'contact': {'email': 'support@nomisweb.co.uk', 'name': 'Nomis', 'telephone': '+44(0) 191 3342680', 'uri': 'https://www.nomisweb.co.uk'}, 'id': 'NOMIS'}, 'test': 'false'}, 'xmlns': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message', 'common': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common', 'structure': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure', 'xsi': 'http://www.w3.org/2001/XMLSchema-instance', 'schemalocation': 'http://sdmx.org/docs/2_0/SDMXMessage.xsd'}}
# {'structure': {'codelists': {'codelist': [{'agencyid': 'NOMIS', 'id': 'CL_1_1_GEOGRAPHY', 'code': [{'annotations': {'annotation': [{'annotationtext': 'major towns and cities', 'annotationtitle': 'TypeName'}, {'annotationtext': 441, 'annotationtitle': 'TypeCode'}, {'annotationtext': 1849688066, 'annotationtitle': 'NomisKey'}]}, 'parentcode': 'E92000001', 'description': {'value': 'Basildon', 'lang': 'en'}, 'value': 'J01000002'}], 'name': {'value': 'geography', 'lang': 'en'}, 'uri': ''}]}, 'header': {'id': 'NM_1_1', 'prepared': '2024-03-23T09:17:01Z', 'sender': {'contact': {'email': 'support@nomisweb.co.uk', 'name': 'Nomis', 'telephone': '+44(0) 191 3342680', 'uri': 'https://www.nomisweb.co.uk'}, 'id': 'NOMIS'}, 'test': 'false'}, 'xmlns': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message', 'common': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common', 'structure': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure', 'xsi': 'http://www.w3.org/2001/XMLSchema-instance', 'schemalocation': 'http://sdmx.org/docs/2_0/SDMXMessage.xsd'}}

# %%
oa21 = pd.read_csv('data/raw/geoportal/Output_Areas_(2011)_to_Output_Areas_(2021)_to_Local_Authority_District_(2022)_Lookup_in_England_and_Wales_(Version_2).csv')['OA21CD']
oa21 = list(oa21)
oa21
# Out:
# C:\Users\ysabe\AppData\Local\Temp\ipykernel_7636\498564723.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   oa21 = pd.read_csv('data/raw/geoportal/Output_Areas_(2011)_to_Output_Areas_(2021)_to_Local_Authority_District_(2022)_Lookup_in_England_and_Wales_(Version_2).csv')['OA21CD']
# ['E00000001',
#  'E00000003',
#  'E00000005',
#  'E00000007',
#  'E00000010',
#  'E00190349',
#  'E00000013',
#  'E00190349',
#  'E00190348',
#  'E00190348',
#  'E00000018',
#  'E00000019',
#  'E00000020',
#  'E00000021',
#  'E00000022',
#  'E00000023',
#  'E00000024',
#  'E00000025',
#  'E00190440',
#  'E00190407',
#  'E00000028',
#  'E00000029',
#  'E00000030',
#  'E00000031',
#  'E00000032',
#  'E00190458',
#  'E00000037',
#  'E00000038',
#  'E00000039',
#  'E00000040',
#  'E00000041',
#  'E00000042',
#  'E00000043',
#  'E00000045',
#  'E00000046',
#  'E00000048',
#  'E00000049',
#  'E00000050',
#  'E00000051',
#  'E00000052',
#  'E00000053',
#  'E00000054',
#  'E00000055',
#  'E00000056',
#  'E00000057',
#  'E00000059',
#  'E00000060',
#  'E00000061',
#  'E00185746',
#  'E00000063',
#  'E00000115',
#  'E00000116',
#  'E00000117',
#  'E00000118',
#  'E00000119',
#  'E00000120',
#  'E00000121',
#  'E00000122',
#  'E00000123',
#  'E00000124',
#  'E00000125',
#  'E00185673',
#  'E00185721',
#  'E00000128',
#  'E00000129',
#  'E00000130',
#  'E00000131',
#  'E00000132',
#  'E00000133',
#  'E00000134',
#  'E00000135',
#  'E00000136',
#  'E00000137',
#  'E00000138',
#  'E00000139',
#  'E00000140',
#  'E00000141',
#  'E00000142',
#  'E00000143',
#  'E00000144',
#  'E00000145',
#  'E00000146',
#  'E00000147',
#  'E00000148',
#  'E00000149',
#  'E00000150',
#  'E00000151',
#  'E00000152',
#  'E00000153',
#  'E00000154',
#  'E00000155',
#  'E00000156',
#  'E00000157',
#  'E00000158',
#  'E00000159',
#  'E00000160',
#  'E00000161',
#  'E00000162',
#  'E00000163',
#  'E00000164',
#  'E00000215',
#  'E00000216',
#  'E00000217',
#  'E00000218',
#  'E00000219',
#  'E00000220',
#  'E00000221',
#  'E00000222',
#  'E00000223',
#  'E00000224',
#  'E00000225',
#  'E00000226',
#  'E00000227',
#  'E00000228',
#  'E00000229',
#  'E00000230',
#  'E00000231',
#  'E00000232',
#  'E00000234',
#  'E00185665',
#  'E00000236',
#  'E00000237',
#  'E00000238',
#  'E00185666',
#  'E00000240',
#  'E00185665',
#  'E00185671',
#  'E00000243',
#  'E00000244',
#  'E00000245',
#  'E00000246',
#  'E00000247',
#  'E00185667',
#  'E00000249',
#  'E00185667',
#  'E00000251',
#  'E00000252',
#  'E00000253',
#  'E00185666',
#  'E00000255',
#  'E00000256',
#  'E00000257',
#  'E00000258',
#  'E00000259',
#  'E00000260',
#  'E00000261',
#  'E00000263',
#  'E00185666',
#  'E00000265',
#  'E00000266',
#  'E00000318',
#  'E00000319',
#  'E00000320',
#  'E00000321',
#  'E00000322',
#  'E00000323',
#  'E00000324',
#  'E00000325',
#  'E00000326',
#  'E00000327',
#  'E00000328',
#  'E00000329',
#  'E00000330',
#  'E00000331',
#  'E00000332',
#  'E00000333',
#  'E00000334',
#  'E00000335',
#  'E00000336',
#  'E00000337',
#  'E00000338',
#  'E00185718',
#  'E00000340',
#  'E00000341',
#  'E00000342',
#  'E00000343',
#  'E00000344',
#  'E00000345',
#  'E00000346',
#  'E00000347',
#  'E00000348',
#  'E00000349',
#  'E00000350',
#  'E00000351',
#  'E00185806',
#  'E00000353',
#  'E00000354',
#  'E00000355',
#  'E00000356',
#  'E00000357',
#  'E00000358',
#  'E00000360',
#  'E00000361',
#  'E00000362',
#  'E00000363',
#  'E00000364',
#  'E00000365',
#  'E00000366',
#  'E00000367',
#  'E00000368',
#  'E00000165',
#  'E00000166',
#  'E00000167',
#  'E00000168',
#  'E00000169',
#  'E00000170',
#  'E00000171',
#  'E00000172',
#  'E00000173',
#  'E00000174',
#  'E00000175',
#  'E00000176',
#  'E00000177',
#  'E00000178',
#  'E00000179',
#  'E00000180',
#  'E00000181',
#  'E00000182',
#  'E00000183',
#  'E00000184',
#  'E00000185',
#  'E00000186',
#  'E00000187',
#  'E00000188',
#  'E00000189',
#  'E00000190',
#  'E00000191',
#  'E00000192',
#  'E00000193',
#  'E00000194',
#  'E00000195',
#  'E00000196',
#  'E00000197',
#  'E00000198',
#  'E00000199',
#  'E00000200',
#  'E00000201',
#  'E00000202',
#  'E00000203',
#  'E00000204',
#  'E00000205',
#  'E00000206',
#  'E00000207',
#  'E00000208',
#  'E00000209',
#  'E00000210',
#  'E00000211',
#  'E00000212',
#  'E00000213',
#  'E00000214',
#  'E00000267',
#  'E00000268',
#  'E00000269',
#  'E00000270',
#  'E00000271',
#  'E00000272',
#  'E00000273',
#  'E00000274',
#  'E00000275',
#  'E00000276',
#  'E00000277',
#  'E00000278',
#  'E00000279',
#  'E00000280',
#  'E00000282',
#  'E00000283',
#  'E00000284',
#  'E00000285',
#  'E00000286',
#  'E00000287',
#  'E00000288',
#  'E00000289',
#  'E00000290',
#  'E00000291',
#  'E00000292',
#  'E00000293',
#  'E00000294',
#  'E00000295',
#  'E00000296',
#  'E00000297',
#  'E00000298',
#  'E00000299',
#  'E00000300',
#  'E00000301',
#  'E00000302',
#  'E00000303',
#  'E00000304',
#  'E00000305',
#  'E00000306',
#  'E00000307',
#  'E00000308',
#  'E00000309',
#  'E00000310',
#  'E00000311',
#  'E00000312',
#  'E00000313',
#  'E00000314',
#  'E00000315',
#  'E00000316',
#  'E00000317',
#  'E00000064',
#  'E00185694',
#  'E00000066',
#  'E00000067',
#  'E00000068',
#  'E00000069',
#  'E00000070',
#  'E00000071',
#  'E00000072',
#  'E00000073',
#  'E00000074',
#  'E00000075',
#  'E00000076',
#  'E00000077',
#  'E00000078',
#  'E00000079',
#  'E00000080',
#  'E00000081',
#  'E00000082',
#  'E00000083',
#  'E00000084',
#  'E00000085',
#  'E00000086',
#  'E00000087',
#  'E00000088',
#  'E00000089',
#  'E00000090',
#  'E00000091',
#  'E00000092',
#  'E00000093',
#  'E00000094',
#  'E00000095',
#  'E00000096',
#  'E00000097',
#  'E00000098',
#  'E00000099',
#  'E00000100',
#  'E00000101',
#  'E00000102',
#  'E00000103',
#  'E00000104',
#  'E00000106',
#  'E00000107',
#  'E00000108',
#  'E00000109',
#  'E00000110',
#  'E00000111',
#  'E00000112',
#  'E00000113',
#  'E00000114',
#  'E00000369',
#  'E00000370',
#  'E00000371',
#  'E00000372',
#  'E00000373',
#  'E00000374',
#  'E00000375',
#  'E00000376',
#  'E00000377',
#  'E00000378',
#  'E00000379',
#  'E00000380',
#  'E00000381',
#  'E00000382',
#  'E00000383',
#  'E00000384',
#  'E00000385',
#  'E00000386',
#  'E00000387',
#  'E00000388',
#  'E00000389',
#  'E00000390',
#  'E00000391',
#  'E00000392',
#  'E00000393',
#  'E00000394',
#  'E00000395',
#  'E00000396',
#  'E00000397',
#  'E00000398',
#  'E00000399',
#  'E00000400',
#  'E00000401',
#  'E00000402',
#  'E00000403',
#  'E00000404',
#  'E00000405',
#  'E00000406',
#  'E00000407',
#  'E00000408',
#  'E00000409',
#  'E00000410',
#  'E00000411',
#  'E00000412',
#  'E00000413',
#  'E00000414',
#  'E00000415',
#  'E00000416',
#  'E00000417',
#  'E00000418',
#  'E00000520',
#  'E00000521',
#  'E00000522',
#  'E00000523',
#  'E00000524',
#  'E00000525',
#  'E00000526',
#  'E00000527',
#  'E00000528',
#  'E00000529',
#  'E00000530',
#  'E00000531',
#  'E00000532',
#  'E00000533',
#  'E00000534',
#  'E00000535',
#  'E00000536',
#  'E00000537',
#  'E00000538',
#  'E00000539',
#  'E00000540',
#  'E00000541',
#  'E00000542',
#  'E00000543',
#  'E00000544',
#  'E00000545',
#  'E00185837',
#  'E00000547',
#  'E00000548',
#  'E00000549',
#  'E00000550',
#  'E00000551',
#  'E00000552',
#  'E00000553',
#  'E00000554',
#  'E00000555',
#  'E00000556',
#  'E00000557',
#  'E00000558',
#  'E00000559',
#  'E00000560',
#  'E00000561',
#  'E00000562',
#  'E00000563',
#  'E00000564',
#  'E00000565',
#  'E00000566',
#  'E00000567',
#  'E00000568',
#  'E00000569',
#  'E00000419',
#  'E00000420',
#  'E00000421',
#  'E00000422',
#  'E00000423',
#  'E00000424',
#  'E00000425',
#  'E00000426',
#  'E00000427',
#  'E00000428',
#  'E00000429',
#  'E00000430',
#  'E00000431',
#  'E00000432',
#  'E00000433',
#  'E00000434',
#  'E00000435',
#  'E00000436',
#  'E00000437',
#  'E00000438',
#  'E00000439',
#  'E00000440',
#  'E00000441',
#  'E00000442',
#  'E00000443',
#  'E00000444',
#  'E00000445',
#  'E00000446',
#  'E00000447',
#  'E00000448',
#  'E00000449',
#  'E00000450',
#  'E00000451',
#  'E00185683',
#  'E00000453',
#  'E00000454',
#  'E00000455',
#  'E00000456',
#  'E00000457',
#  'E00185668',
#  'E00185669',
#  'E00185669',
#  'E00000461',
#  'E00000462',
#  'E00000463',
#  'E00000464',
#  'E00000465',
#  'E00000466',
#  'E00000467',
#  'E00000468',
#  'E00000570',
#  'E00000571',
#  'E00000572',
#  'E00000573',
#  'E00000574',
#  'E00000575',
#  'E00000576',
#  'E00000577',
#  'E00000578',
#  'E00000579',
#  'E00000580',
#  'E00000581',
#  'E00178878',
#  'E00000583',
#  'E00000584',
#  'E00000585',
#  'E00000586',
#  'E00000587',
#  'E00000588',
#  'E00000589',
#  'E00000590',
#  'E00000591',
#  'E00000592',
#  'E00000593',
#  'E00000594',
#  'E00000595',
#  'E00000596',
#  'E00000597',
#  'E00000598',
#  'E00000599',
#  'E00000600',
#  'E00000601',
#  'E00000602',
#  'E00000603',
#  'E00000604',
#  'E00000605',
#  'E00000606',
#  'E00000607',
#  'E00000608',
#  'E00000609',
#  'E00000610',
#  'E00000611',
#  'E00000612',
#  'E00000613',
#  'E00000614',
#  'E00000615',
#  'E00000616',
#  'E00000617',
#  'E00000618',
#  'E00000619',
#  'E00000723',
#  'E00000724',
#  'E00000725',
#  'E00000726',
#  'E00000727',
#  'E00000728',
#  'E00178723',
#  'E00000730',
#  'E00178893',
#  'E00000732',
#  'E00178891',
#  'E00178894',
#  'E00178876',
#  'E00000737',
#  'E00000738',
#  'E00000739',
#  'E00000672',
#  'E00000740',
#  'E00000742',
#  'E00000743',
#  'E00178803',
#  'E00000745',
#  'E00000746',
#  'E00000747',
#  'E00000748',
#  'E00000749',
#  'E00000750',
#  'E00000751',
#  'E00000752',
#  'E00000754',
#  'E00000755',
#  'E00000756',
#  'E00000757',
#  'E00000758',
#  'E00178838',
#  'E00000761',
#  'E00178800',
#  'E00000763',
#  'E00178820',
#  'E00178826',
#  'E00178882',
#  'E00000767',
#  'E00000768',
#  'E00000769',
#  'E00000770',
#  'E00000771',
#  'E00000772',
#  'E00000773',
#  'E00000774',
#  'E00000775',
#  'E00000776',
#  'E00000620',
#  'E00000674',
#  'E00000675',
#  'E00000676',
#  'E00000677',
#  'E00000678',
#  'E00000679',
#  'E00178756',
#  'E00000681',
#  'E00000682',
#  'E00000683',
#  'E00000684',
#  'E00000685',
#  'E00000686',
#  'E00000687',
#  'E00000688',
#  'E00000689',
#  'E00000690',
#  'E00000691',
#  'E00000692',
#  'E00000693',
#  'E00000622',
#  'E00000694',
#  'E00178854',
#  'E00000695',
#  'E00000624',
#  'E00178811',
#  'E00000625',
#  'E00000697',
#  'E00000626',
#  'E00000698',
#  'E00000627',
#  'E00000699',
#  'E00000628',
#  'E00000700',
#  'E00000629',
#  'E00000701',
#  'E00000630',
#  'E00000702',
#  'E00000631',
#  'E00000703',
#  'E00000632',
#  'E00000704',
#  'E00000633',
#  'E00000705',
#  'E00000706',
#  'E00000707',
#  'E00000708',
#  'E00000709',
#  'E00000710',
#  'E00000711',
#  'E00000712',
#  'E00000713',
#  'E00000714',
#  'E00000715',
#  'E00000716',
#  'E00000717',
#  'E00000718',
#  'E00000719',
#  'E00000720',
#  'E00000721',
#  'E00000722',
#  'E00000634',
#  'E00000635',
#  'E00000636',
#  'E00000637',
#  'E00000638',
#  'E00000640',
#  'E00000641',
#  'E00000642',
#  'E00000643',
#  'E00000644',
#  'E00000645',
#  'E00000646',
#  'E00000647',
#  'E00000648',
#  'E00000649',
#  'E00000650',
#  'E00000651',
#  'E00000652',
#  'E00000653',
#  'E00000654',
#  'E00000655',
#  'E00000656',
#  'E00000657',
#  'E00000658',
#  'E00000659',
#  'E00000660',
#  'E00000661',
#  'E00000662',
#  'E00000663',
#  'E00000664',
#  'E00178814',
#  'E00000666',
#  'E00000667',
#  'E00000668',
#  'E00000669',
#  'E00000670',
#  'E00000671',
#  'E00000777',
#  'E00000778',
#  'E00000779',
#  'E00000780',
#  'E00000781',
#  'E00000782',
#  'E00000783',
#  'E00000785',
#  'E00000786',
#  'E00000787',
#  'E00000788',
#  'E00000789',
#  'E00000790',
#  'E00000791',
#  'E00000792',
#  'E00000793',
#  'E00000794',
#  'E00000795',
#  'E00000796',
#  'E00000797',
#  'E00000798',
#  'E00000799',
#  'E00000800',
#  'E00000801',
#  'E00000802',
#  'E00000803',
#  'E00000804',
#  'E00000805',
#  'E00000806',
#  'E00000807',
#  'E00000808',
#  'E00000809',
#  'E00000810',
#  'E00000811',
#  'E00000812',
#  'E00000813',
#  'E00000814',
#  'E00000815',
#  'E00000816',
#  'E00000817',
#  'E00000818',
#  'E00000819',
#  'E00000820',
#  'E00000821',
#  'E00000822',
#  'E00000823',
#  'E00000824',
#  'E00000825',
#  'E00000826',
#  'E00000827',
#  'E00000469',
#  'E00000470',
#  'E00000471',
#  'E00000472',
#  'E00185668',
#  'E00000475',
#  'E00000476',
#  'E00000477',
#  'E00000478',
#  'E00000479',
#  'E00000480',
#  'E00000481',
#  'E00000482',
#  'E00000483',
#  'E00000484',
#  'E00000485',
#  'E00185832',
#  'E00000487',
#  'E00000488',
#  'E00000489',
#  'E00000490',
#  'E00000491',
#  'E00000492',
#  'E00000493',
#  'E00000494',
#  'E00000495',
#  'E00000496',
#  'E00000497',
#  'E00000498',
#  'E00000499',
#  'E00000500',
#  'E00000501',
#  'E00000502',
#  'E00000503',
#  'E00000504',
#  'E00000505',
#  'E00000506',
#  'E00000507',
#  'E00000508',
#  'E00000509',
#  'E00000510',
#  'E00000511',
#  'E00000512',
#  'E00000513',
#  'E00000514',
#  'E00000515',
#  'E00000516',
#  'E00000517',
#  'E00000518',
#  'E00000519',
#  'E00001128',
#  'E00001129',
#  'E00001130',
#  'E00001131',
#  'E00001132',
#  'E00001133',
#  'E00001134',
#  'E00001135',
#  'E00001136',
#  'E00001137',
#  'E00001138',
#  'E00001139',
#  'E00000878',
#  'E00001140',
#  'E00001141',
#  'E00178736',
#  'E00001142',
#  'E00000880',
#  'E00001028',
#  'E00001143',
#  'E00000881',
#  'E00001029',
#  'E00001144',
#  'E00000882',
#  'E00001030',
#  'E00000828',
#  'E00001145',
#  'E00000883',
#  'E00000928',
#  'E00001031',
#  'E00000829',
#  'E00001146',
#  'E00000884',
#  'E00000929',
#  'E00001032',
#  'E00000830',
#  'E00001147',
#  'E00000885',
#  'E00000930',
#  'E00001033',
#  'E00000831',
#  'E00001148',
#  'E00000886',
#  'E00000931',
#  'E00001034',
#  'E00000832',
#  'E00001149',
#  'E00000887',
#  'E00000932',
#  'E00001035',
#  'E00000833',
#  'E00001150',
#  'E00000888',
#  'E00178760',
#  'E00001036',
#  'E00000834',
#  'E00001151',
#  'E00000889',
#  'E00000934',
#  'E00001037',
#  'E00000835',
#  'E00001152',
#  'E00000890',
#  'E00000935',
#  'E00001038',
#  'E00000836',
#  'E00001153',
#  'E00000891',
#  'E00000936',
#  'E00001039',
#  'E00001040',
#  'E00001041',
#  'E00001042',
#  'E00001043',
#  'E00001044',
#  'E00001045',
#  'E00001046',
#  'E00001047',
#  'E00001048',
#  'E00001049',
#  'E00001050',
#  'E00001051',
#  'E00001052',
#  'E00001053',
#  'E00001054',
#  'E00001055',
#  'E00001056',
#  'E00001057',
#  'E00001058',
#  'E00001059',
#  'E00001060',
#  'E00001061',
#  'E00001062',
#  'E00001063',
#  'E00001064',
#  'E00001065',
#  'E00001066',
#  'E00001067',
#  'E00001068',
#  'E00001069',
#  'E00178740',
#  'E00001071',
#  'E00001072',
#  'E00001073',
#  'E00001074',
#  'E00001075',
#  'E00001076',
#  'E00001077',
#  'E00000937',
#  'E00000938',
#  'E00000939',
#  'E00000940',
#  'E00000941',
#  'E00178725',
#  'E00000943',
#  'E00000944',
#  'E00000945',
#  'E00178725',
#  'E00000947',
#  'E00000948',
#  'E00000949',
#  'E00000950',
#  'E00000951',
#  'E00000952',
#  'E00000953',
#  'E00000954',
#  'E00000955',
#  'E00000956',
#  'E00178781',
#  'E00000958',
#  'E00000959',
#  'E00000960',
#  'E00000892',
#  'E00000961',
#  'E00001154',
#  'E00000837',
#  'E00000893',
#  'E00000962',
#  'E00001155',
#  'E00000838',
#  'E00000894',
#  'E00000963',
#  'E00001156',
#  'E00000839',
#  'E00000895',
#  'E00000964',
#  'E00001157',
#  'E00001158',
#  'E00001159',
#  'E00001160',
#  'E00001161',
#  'E00001162',
#  'E00001163',
#  'E00001164',
#  'E00001165',
#  'E00001166',
#  'E00001167',
#  'E00001168',
#  'E00001169',
#  'E00001170',
#  'E00001171',
#  'E00001172',
#  'E00001173',
#  'E00001174',
#  'E00001175',
#  'E00001176',
#  'E00001177',
#  'E00000896',
#  'E00000897',
#  'E00000898',
#  'E00000899',
#  'E00000900',
#  'E00000901',
#  'E00000902',
#  'E00000903',
#  'E00000904',
#  'E00000905',
#  'E00000906',
#  'E00000907',
#  'E00000908',
#  'E00000909',
#  'E00000910',
#  'E00000911',
#  'E00000912',
#  'E00000913',
#  'E00000914',
#  'E00000840',
#  'E00000915',
#  'E00000841',
#  'E00000965',
#  'E00000916',
#  'E00000842',
#  'E00000966',
#  'E00000917',
#  'E00000843',
#  'E00000967',
#  'E00000918',
#  'E00000844',
#  'E00000968',
#  'E00000919',
#  ...]

# %%
# api_url = '/api/v01/dataset/def.sdmx.json' # view all datasets
api_url = '/api/v01/dataset/def.sdmx.json?search=C2021TS*'
# api_url = '/api/v01/dataset/NM_2021_1/def.sdmx.json'


url = root_url + api_url

response = requests.get(url)
json.loads(response.text)
# Out:
# {'structure': {'header': {'id': 'none',
#    'prepared': '2024-03-23T09:17:03Z',
#    'sender': {'contact': {'email': 'support@nomisweb.co.uk',
#      'name': 'Nomis',
#      'telephone': '+44(0) 191 3342680',
#      'uri': 'https://www.nomisweb.co.uk'},
#     'id': 'NOMIS'},
#    'test': 'false'},
#   'keyfamilies': {'keyfamily': [{'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Age', 'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts007a', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents in England and Wales by five-year age bands. The estimates are as at Census Day, 21 March 2021',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2020_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2020_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2020_1_C2021_AGE_19', 'conceptref': 'C2021_AGE_19'},
#        {'codelist': 'CL_2020_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2020_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2020_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS007A - Age by five-year age bands', 'lang': 'en'},
#      'uri': 'Nm-2020d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Persons,Households', 'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts001', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents in England and Wales by whether they resided in households and communal establishments. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2021_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2021_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2021_1_C2021_RESTYPE_3',
#         'conceptref': 'C2021_RESTYPE_3'},
#        {'codelist': 'CL_2021_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2021_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2021_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS001 - Number of usual residents in households and communal establishments',
#       'lang': 'en'},
#      'uri': 'Nm-2021d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Married,Separated,Divorced,Widowed',
#         'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents aged 16 and over',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts002', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents aged 16 years and over in England and Wales by their legal partnership status. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2022_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2022_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2022_1_C2021_LPSTAT_12',
#         'conceptref': 'C2021_LPSTAT_12'},
#        {'codelist': 'CL_2022_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2022_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2022_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS002 - Legal partnership status', 'lang': 'en'},
#      'uri': 'Nm-2022d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Dependent child,Household,Household composition,Lone parent,Cohabiting couple family,Married or civil partnership couple,Single-family household,Same-sex civil partnership couple,Students,Schoolchildren',
#         'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Households', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All households',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts003', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify households in England and Wales by the relationships between household members (household composition). The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2023_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2023_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2023_1_C2021_HHCOMP_15',
#         'conceptref': 'C2021_HHCOMP_15'},
#        {'codelist': 'CL_2023_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2023_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2023_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS003 - Household composition', 'lang': 'en'},
#      'uri': 'Nm-2023d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Country of Birth,Usual Resident',
#         'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts004', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents in England and Wales by their country of birth. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2024_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2024_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2024_1_C2021_COB_12', 'conceptref': 'C2021_COB_12'},
#        {'codelist': 'CL_2024_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2024_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2024_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS004 - Country of birth', 'lang': 'en'},
#      'uri': 'Nm-2024d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Passports Held', 'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts005', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents in England and Wales by passports held. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2025_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2025_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2025_1_C2021_PASS_27', 'conceptref': 'C2021_PASS_27'},
#        {'codelist': 'CL_2025_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2025_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2025_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS005 - Passports held', 'lang': 'en'},
#      'uri': 'Nm-2025d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Population density', 'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts006', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents in England and Wales by population density (number of usual residents per square kilometre). The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2026_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2026_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2026_1_CELL', 'conceptref': 'CELL'},
#        {'codelist': 'CL_2026_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2026_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2026_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS006 - Population density', 'lang': 'en'},
#      'uri': 'Nm-2026d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Age,Usual Resident', 'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts007', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents in England and Wales by single year of age. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2027_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2027_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2027_1_C2021_AGE_102', 'conceptref': 'C2021_AGE_102'},
#        {'codelist': 'CL_2027_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2027_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2027_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS007 - Age by single year', 'lang': 'en'},
#      'uri': 'Nm-2027d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Sex', 'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts008', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents in England and Wales by sex. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2028_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2028_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2028_1_C_SEX', 'conceptref': 'C_SEX'},
#        {'codelist': 'CL_2028_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2028_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2028_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS008 - Sex', 'lang': 'en'},
#      'uri': 'Nm-2028d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Age,Usual Resident,Sex',
#         'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'la', 'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts009', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents in England and Wales by sex and single year of age. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2029_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2029_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2029_1_C_SEX', 'conceptref': 'C_SEX'},
#        {'codelist': 'CL_2029_1_C2021_AGE_92', 'conceptref': 'C2021_AGE_92'},
#        {'codelist': 'CL_2029_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2029_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2029_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS009 - Sex by single year of age', 'lang': 'en'},
#      'uri': 'Nm-2029d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Sex', 'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents aged 16 years and over in households',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts010', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents aged 16 years and over in households in England and Wales by their living arrangements. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2030_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2030_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2030_1_C2021_LIVING_11',
#         'conceptref': 'C2021_LIVING_11'},
#        {'codelist': 'CL_2030_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2030_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2030_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS010 - Living arrangements', 'lang': 'en'},
#      'uri': 'Nm-2030d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Sex', 'annotationtitle': 'Keywords'},
#        {'annotationtext': 'Households', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'oa,msoa,la',
#         'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All households',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts011', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-11-02 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify households in England and Wales by four dimensions of deprivation: Employment, education, health and disability, and household overcrowding. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2031_1',
# ...
#      'name': {'value': 'TS075 - Multi religion households', 'lang': 'en'},
#      'uri': 'Nm-2097d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'la', 'annotationtitle': 'contenttype/geoglevel'},
#        {'annotationtext': 'All usual residents aged 3 and over',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts076', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': '2022-12-06 09:30:00',
#         'annotationtitle': 'FirstReleased'},
#        {'annotationtext': '2022-12-06 09:30:00',
#         'annotationtitle': 'LastUpdated'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents in Wales by their ability to speak Welsh by age. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2098_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2098_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2098_1_C2021_WLANGS_3',
#         'conceptref': 'C2021_WLANGS_3'},
#        {'codelist': 'CL_2098_1_C2021_AGE_86', 'conceptref': 'C2021_AGE_86'},
#        {'codelist': 'CL_2098_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2098_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2098_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS076 - Welsh language skills (speaking) by single year of age',
#       'lang': 'en'},
#      'uri': 'Nm-2098d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'All usual residents in communal establishments',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts048np', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify communal establishment residents in national parks in England and Wales by the type of communal establishment they live in. The estimates are as at Census Day, 21 March 2021. \n\n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2099_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2099_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2099_1_C2021_COMEST_12',
#         'conceptref': 'C2021_COMEST_12'},
#        {'codelist': 'CL_2099_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2099_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2099_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS048NP - Communal establishment management and type - National Parks',
#       'lang': 'en'},
#      'uri': 'Nm-2099d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Persons', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'All usual residents aged 16 years and over in employment the week before the census',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts060np', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates that classify usual residents aged 16 years and over in employment the week before the census in national parks in England and Wales by industry. The estimates are as at Census Day, 21 March 2021.\n   \n   National Park data are created by plotting unique properties as identified by their Unique Property Reference Number or postcodes into National Park boundaries current at December 2022. This differs from the OA best fit methodology used for other geographic level data.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2100_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2100_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2100_1_C2021_IND_16', 'conceptref': 'C2021_IND_16'},
#        {'codelist': 'CL_2100_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2100_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2100_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS060NP - Industry - National Parks', 'lang': 'en'},
#      'uri': 'Nm-2100d1',
#      'version': 1.0},
#     {'agencyid': 'NOMIS',
#      'annotations': {'annotation': [{'annotationtext': 'Current (being actively updated)',
#         'annotationtitle': 'Status'},
#        {'annotationtext': 'Cars', 'annotationtitle': 'Units'},
#        {'annotationtext': 'census_2021_ts',
#         'annotationtitle': 'contenttype/sources'},
#        {'annotationtext': 'All cars or vans available for use by household members in the area',
#         'annotationtitle': 'SubDescription'},
#        {'annotationtext': 'c2021ts045a', 'annotationtitle': 'Mnemonic'},
#        {'annotationtext': 'About this dataset',
#         'annotationtitle': 'MetadataTitle0'},
#        {'annotationtext': 'This dataset provides Census 2021 estimates on the total number of cars or vans available to members of households in England and Wales. The estimates are as at Census Day, 21 March 2021.',
#         'annotationtitle': 'MetadataText0'},
#        {'annotationtext': 'Protecting personal data',
#         'annotationtitle': 'MetadataTitle1'},
#        {'annotationtext': 'Sometimes we need to make changes to data if it is possible to identify individuals. This is known as statistical disclosure control. In Census 2021, we:\n\n* Swapped records (targeted record swapping), for example, if a household was likely to be identified in datasets because it has unusual characteristics, we swapped the record with a similar one from a nearby small area. Very unusual households could be swapped with one in a nearby local authority.\n* Added small changes to some counts (cell key perturbation), for example, we might change a count of four to a three or a five. This might make small differences between tables depending on how the data are broken down when we applied perturbation.',
#         'annotationtitle': 'MetadataText1'},
#        {'annotationtext': 2, 'annotationtitle': 'MetadataCount'}]},
#      'id': 'NM_2324_1',
#      'components': {'attribute': [{'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_STATUS',
#         'conceptref': 'OBS_STATUS'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_CONF',
#         'conceptref': 'OBS_CONF'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Observation',
#         'codelist': 'CL_OBS_ROUND',
#         'conceptref': 'OBS_ROUND'},
#        {'assignmentstatus': 'Conditional',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT_MULT',
#         'conceptref': 'UNIT_MULTIPLIER'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_TIME_FORMAT',
#         'conceptref': 'TIME_FORMAT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'codelist': 'CL_UNIT',
#         'conceptref': 'UNIT'},
#        {'assignmentstatus': 'Mandatory',
#         'attachmentlevel': 'Series',
#         'conceptref': 'TITLE_COMPL'}],
#       'dimension': [{'codelist': 'CL_2324_1_GEOGRAPHY',
#         'conceptref': 'GEOGRAPHY'},
#        {'codelist': 'CL_2324_1_C2021_CARS_TOTAL',
#         'conceptref': 'C2021_CARS_TOTAL'},
#        {'codelist': 'CL_2324_1_MEASURES', 'conceptref': 'MEASURES'},
#        {'codelist': 'CL_2324_1_FREQ',
#         'conceptref': 'FREQ',
#         'isfrequencydimension': 'true'}],
#       'primarymeasure': {'conceptref': 'OBS_VALUE'},
#       'timedimension': {'codelist': 'CL_2324_1_TIME', 'conceptref': 'TIME'}},
#      'name': {'value': 'TS045A - Number of cars or vans in the area',
#       'lang': 'en'},
#      'uri': 'Nm-2324d1',
#      'version': 1.0}]},
#   'xmlns': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message',
#   'common': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common',
#   'structure': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure',
#   'xsi': 'http://www.w3.org/2001/XMLSchema-instance',
#   'schemalocation': 'http://sdmx.org/docs/2_0/SDMXMessage.xsd'}}

# %%
api_url = '/api/v01/dataset/def.sdmx.json?search=C2021TS*'
url = root_url + api_url
response = requests.get(url)

c2021_datasets_json = json.loads(response.text)
c2021_datasets_json = c2021_datasets_json['structure']['keyfamilies']['keyfamily']
c2021_datasets_metadata_list = []
for dataset in c2021_datasets_json:
    annotations = dataset['annotations']['annotation']
    for annotation in annotations:
        if annotation['annotationtitle'] == 'contenttype/geoglevel':
            geoglevel = annotation['annotationtext']
        if annotation['annotationtitle'] == 'Mnemonic':
            mnemonic = annotation['annotationtext']
        if annotation['annotationtitle'] == 'MetadataText0':
            description = annotation['annotationtext']
    id = dataset['id']
    metadata = {
        'id': id,
        'mnemonic': mnemonic,
        'description': description,
        'geoglevel': geoglevel
    }
    c2021_datasets_metadata_list.append(metadata)
c2021_datasets_metadata_df = pd.DataFrame(c2021_datasets_metadata_list)
c2021_datasets_metadata_df.to_csv('./data/raw/api/metadata.csv')
c2021_datasets_metadata_df
# Out:
#            id      mnemonic  \
# 0   NM_2020_1   c2021ts007a
# 1   NM_2021_1    c2021ts001
# 2   NM_2022_1    c2021ts002
# 3   NM_2023_1    c2021ts003
# 4   NM_2024_1    c2021ts004
# ..        ...           ...
# 75  NM_2097_1    c2021ts075
# 76  NM_2098_1    c2021ts076
# 77  NM_2099_1  c2021ts048np
# 78  NM_2100_1  c2021ts060np
# 79  NM_2324_1   c2021ts045a
#
#                                           description   geoglevel
# 0   This dataset provides Census 2021 estimates th...  oa,msoa,la
# 1   This dataset provides Census 2021 estimates th...  oa,msoa,la
# 2   This dataset provides Census 2021 estimates th...  oa,msoa,la
# 3   This dataset provides Census 2021 estimates th...  oa,msoa,la
# 4   This dataset provides Census 2021 estimates th...  oa,msoa,la
# ..                                                ...         ...
# 75  This dataset provides Census 2021 estimates th...  oa,msoa,la
# 76  This dataset provides Census 2021 estimates th...          la
# 77  This dataset provides Census 2021 estimates th...          la
# 78  This dataset provides Census 2021 estimates th...          la
# 79  This dataset provides Census 2021 estimates on...          la
#
# [80 rows x 4 columns]

# %%
c2021_datasets_metadata_df["id"][0]
# Out:
# 'NM_2020_1'

# %%
api_url = f'/api/v01/dataset/{c2021_datasets_metadata_df["id"][0]}.data.csv?geography=MAKE|myarea|E00000001;E00000003&measures=20100&recordlimit=100'
url = root_url + api_url
print(url)
batch_df = pd.read_csv(url)
batch_df.to_csv('test.csv')
# Out:
# http://www.nomisweb.co.uk/api/v01/dataset/NM_2020_1.data.csv?geography=MAKE|myarea|E00000001;E00000003&measures=20100&recordlimit=100

# %%
record_limit = 1000000

for dataset in c2021_datasets_metadata_list:
    id = dataset['id']
    mnemonic = dataset['mnemonic']
    geoglevel = dataset['geoglevel'].split(',')
    if 'oa' not in geoglevel:
        continue

    print("downloading", mnemonic)
    api_url = f'/api/v01/dataset/{id}.data.csv?recordlimit=0'
    url = root_url + api_url
    try:
        dataset_df = pd.read_csv(url)
    except:
        time.sleep(60)
        dataset_df = pd.read_csv(url)
    try:
        stat_name = dataset_df.filter(regex='^C2021.*NAME$', axis=1).columns[0].lower()
    except:
        stat_name = dataset_df.filter(regex='^CELL.*NAME$', axis=1).columns[0].lower()

    # api_url = f'/api/v01/dataset/{id}.data.csv?recordlimit=0&select=date,geography_code,{stat_name},obs_value'
    # url = root_url + api_url
    # dataset_df = pd.read_csv(url)

    last_record = 0
    # api_url = f'/api/v01/dataset/{id}.data.csv?uid=0xd9817610eb1bbb16a8e6d24954e88792f83ff1f3&measures=20100&select=date,geography_code,{stat_name},obs_value'
    # url = root_url + api_url
    # chunksize = 10 ** 6
    # with pd.read_csv(url, chunksize=chunksize) as reader:
    #     i = 0
    #     for chunk in reader:
    #         dest_file = f'./data/raw/api/{mnemonic}_{i:02}.csv'
    #         chunk.to_csv(dest_file)
    #         print(f"chunk {i} saved in {dest_file}")
    #         i += 1
    # try:
    #     dataset_df = pd.read_csv(url)
    # except:
    #     time.sleep(60)
    #     dataset_df = pd.read_csv(url)
    for i in range(1000):
        print(f"trying records {last_record} - {last_record + record_limit}")
        api_url = f'/api/v01/dataset/{id}.data.csv?uid=0xd9817610eb1bbb16a8e6d24954e88792f83ff1f3&measures=20100&select=date,geography_code,{stat_name},obs_value&recordlimit={record_limit}&recordoffset={last_record}'
        url = root_url + api_url

        try:
            batch_df = pd.read_csv(url)
        except:
            time.sleep(60)
            batch_df = pd.read_csv(url)

        display(batch_df.head())

        if len(batch_df) == 0:
            break

        dest_file = f'./data/raw/api/{mnemonic}_{i:02}.csv'
        batch_df.to_csv(dest_file)
        print(f"chunk {i} saved in {dest_file}")

        # dataset_df = pd.concat([dataset_df, batch_df])
        last_record += record_limit

    # for oa in oa21:
    #     api_url = f'/api/v01/dataset/{id}.data.csv?geography={oa}&measures=20100&select=date,geography_code,{stat_name},obs_value'
    #     url = root_url + api_url
    #     oa_df = pd.read_csv(url)
    #     dataset_df = pd.concat([dataset_df, oa_df])

    # dataset_df.to_csv(f'./data/raw/api/{mnemonic}.csv')
    # print(f"dataset saved in ./data/raw/api/{mnemonic}.csv")
# Out:
# downloading c2021ts007a
# trying records 0 - 1000000
#    DATE GEOGRAPHY_CODE       C2021_AGE_19_NAME  OBS_VALUE
# 0  2021      E00060274                   Total        274
# 1  2021      E00060274  Aged 4 years and under         26
# 2  2021      E00060274       Aged 5 to 9 years         26
# 3  2021      E00060274     Aged 10 to 14 years         27
# 4  2021      E00060274     Aged 15 to 19 years         15
# chunk 0 saved in ./data/raw/api/c2021ts007a_00.csv
# trying records 1000000 - 2000000
#    DATE GEOGRAPHY_CODE    C2021_AGE_19_NAME  OBS_VALUE
# 0  2021      E00068884  Aged 50 to 54 years         36
# 1  2021      E00068884  Aged 55 to 59 years         14
# 2  2021      E00068884  Aged 60 to 64 years          6
# 3  2021      E00068884  Aged 65 to 69 years          5
# 4  2021      E00068884  Aged 70 to 74 years          1
# chunk 1 saved in ./data/raw/api/c2021ts007a_01.csv
# trying records 2000000 - 3000000
#    DATE GEOGRAPHY_CODE    C2021_AGE_19_NAME  OBS_VALUE
# 0  2021      E00000222  Aged 10 to 14 years         32
# 1  2021      E00000222  Aged 15 to 19 years         28
# 2  2021      E00000222  Aged 20 to 24 years         29
# 3  2021      E00000222  Aged 25 to 29 years         24
# 4  2021      E00000222  Aged 30 to 34 years         52
# chunk 2 saved in ./data/raw/api/c2021ts007a_02.csv
# trying records 3000000 - 4000000
